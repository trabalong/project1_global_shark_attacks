# %%
import pandas as pd

import pylab as plt

import seaborn as sns

import numpy as np

import sys

import re

import warnings
warnings.simplefilter('ignore')

sys.path.append(r'C:\Users\Gaspar\Desktop\project1_global_shark_attacks\src')

from src import getGraphic, getDic

# %%
df_original = pd.read_csv('../data/attacks.csv', encoding = 'latin1')

df = df_original.copy()

pd.set_option('max_columns', None)

#Let's rename columns names for avoid spaces, uppercases, points, etc.

df.columns=[c.lower().replace(' ','_').replace(':','').replace('.','_').replace('(','').replace(')','').replace('/','') for c in df.columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             8702 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   float64
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex_                    5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal_yn                5763 non-null   object
#  13  time                    2948 non-null   object
#  14  species_                3464 non-null   object
#  15  investigator_or_source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href_formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  case_number_1           6302 non-null   object
#  20  case_number_2           6302 non-null   object
#  21  original_order          6309 non-null   float64
#  22  unnamed_22              1 non-null      object
#  23  unnamed_23              2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
df.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#           species_          investigator_or_source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case_number_1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   case_number_2  original_order unnamed_22 unnamed_23
# 0    2018.06.25          6303.0        NaN        NaN
# 1    2018.06.18          6302.0        NaN        NaN
# 2    2018.06.09          6301.0        NaN        NaN
# 3    2018.06.08          6300.0        NaN        NaN
# 4    2018.06.04          6299.0        NaN        NaN

# %%
getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
subset_util = list(df.columns)[1:-3]

getGraphic(df[subset_util]);

# %%
#Estos son las filas con todos los valores nulos

df[subset_util].isnull().all(1).sum()
# Out:
# 19421

# %%
#Hemos eliminado y guardado las filas nulas para trabajar con el resto

df_rowsnull = df[df[subset_util].isnull().all(1)]

index_rowsnull = list(df_rowsnull.index)

df.drop(index_rowsnull, axis = 0, inplace = True)

# %%
df_rowsnull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19421 entries, 6302 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             2401 non-null   object
#  1   date                    0 non-null      object
#  2   year                    0 non-null      float64
#  3   type                    0 non-null      object
#  4   country                 0 non-null      object
#  5   area                    0 non-null      object
#  6   location                0 non-null      object
#  7   activity                0 non-null      object
#  8   name                    0 non-null      object
#  9   sex_                    0 non-null      object
#  10  age                     0 non-null      object
#  11  injury                  0 non-null      object
#  12  fatal_yn                0 non-null      object
#  13  time                    0 non-null      object
#  14  species_                0 non-null      object
#  15  investigator_or_source  0 non-null      object
#  16  pdf                     0 non-null      object
#  17  href_formula            0 non-null      object
#  18  href                    0 non-null      object
#  19  case_number_1           0 non-null      object
#  20  case_number_2           0 non-null      object
#  21  original_order          7 non-null      float64
#  22  unnamed_22              0 non-null      object
#  23  unnamed_23              0 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 3.7+ MB

# %%
getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      case_number         date    year        type             country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex_  age  \
# 0               Julie Wolfe    F   57
# 1           Adyson McNeely     F   11
# 2               John Denges    M   48
# 3                      male    M  NaN
# 4            Gustavo Ramos     M  NaN
# ...                     ...  ...  ...
# 6297                   male    M  NaN
# 6298                  Ahmun    M  NaN
# 6299  Coast Guard personnel    M  NaN
# 6300        Jules Patterson    M  NaN
# 6301                   male    M   15
#
#                                                  injury fatal_yn  \
# 0     No injury to occupant, outrigger canoe and pad...        N
# 1                            Minor injury to left thigh        N
# 2          Injury to left lower leg from surfboard skeg        N
# 3                             Minor injury to lower leg        N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT        N
# ...                                                 ...      ...
# 6297                                              FATAL        Y
# 6298                                              FATAL        Y
# 6299                                              FATAL        Y
# 6300                                              FATAL        Y
# 6301  FATAL. "Shark bit him in half, carrying away t...        Y
#
#                time         species_                 investigator_or_source  \
# 0             18h00      White shark                       R. Collier, GSAF
# 1     14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 2             07h45              NaN         K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                         B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                              A .Kipper
# ...             ...              ...                                    ...
# 6297            NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298            NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299            NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300            NaN              NaN                    The Sun, 10/20/1938
# 6301            NaN              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number_1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case_number_2  original_order unnamed_22 unnamed_23
# 0       2018.06.25          6303.0        NaN        NaN
# 1       2018.06.18          6302.0        NaN        NaN
# 2       2018.06.09          6301.0        NaN        NaN
# 3       2018.06.08          6300.0        NaN        NaN
# 4       2018.06.04          6299.0        NaN        NaN
# ...            ...             ...        ...        ...
# 6297       ND.0005             6.0        NaN        NaN
# 6298       ND.0004             5.0        NaN        NaN
# 6299       ND.0003             4.0        NaN        NaN
# 6300       ND.0002             3.0        NaN        NaN
# 6301       ND.0001             2.0        NaN        NaN
#
# [6302 rows x 24 columns]

# %%
dict(df['country'].value_counts())
# Out:
# {'USA': 2229,
#  'AUSTRALIA': 1338,
#  'SOUTH AFRICA': 579,
#  'PAPUA NEW GUINEA': 134,
#  'NEW ZEALAND': 128,
#  'BRAZIL': 112,
#  'BAHAMAS': 109,
#  'MEXICO': 89,
#  'ITALY': 71,
#  'FIJI': 62,
#  'PHILIPPINES': 61,
#  'REUNION': 60,
#  'NEW CALEDONIA': 53,
#  'CUBA': 46,
#  'MOZAMBIQUE': 45,
#  'SPAIN': 44,
#  'INDIA': 40,
#  'EGYPT': 38,
#  'CROATIA': 34,
#  'JAPAN': 34,
#  'PANAMA': 32,
#  'SOLOMON ISLANDS': 30,
#  'IRAN': 29,
#  'JAMAICA': 27,
#  'FRENCH POLYNESIA': 25,
#  'GREECE': 25,
#  'HONG KONG': 24,
#  'INDONESIA': 23,
#  'ENGLAND': 23,
#  'PACIFIC OCEAN': 17,
#  'ATLANTIC OCEAN': 17,
#  'COSTA RICA': 17,
#  'BERMUDA': 16,
#  'VIETNAM': 15,
#  'TONGA': 15,
#  'SRI LANKA': 14,
#  'VANUATU': 14,
#  'MARSHALL ISLANDS': 13,
#  'FRANCE': 13,
#  'CANADA': 12,
#  'SOUTH ATLANTIC OCEAN': 12,
#  'TURKEY': 12,
#  'IRAQ': 12,
#  'VENEZUELA': 11,
#  'UNITED KINGDOM': 11,
#  'SENEGAL': 11,
#  'KENYA': 10,
#  'NEW GUINEA': 10,
#  'MAURITIUS': 10,
#  'ECUADOR': 9,
#  'TAIWAN': 9,
#  'COLUMBIA': 9,
#  'CARIBBEAN SEA': 8,
#  'TANZANIA': 8,
#  'SCOTLAND': 8,
#  'MADAGASCAR': 8,
#  'CHILE': 8,
#  'SOUTH KOREA': 8,
#  'THAILAND': 8,
#  'SAMOA': 8,
#  'SIERRA LEONE': 8,
#  'SEYCHELLES': 7,
#  'NORTH PACIFIC OCEAN': 7,
#  'ISRAEL': 7,
#  'CHINA': 7,
#  'DOMINICAN REPUBLIC': 7,
#  'YEMEN ': 7,
#  'INDIAN OCEAN': 7,
#  'LIBYA': 6,
#  'BARBADOS': 6,
#  'OKINAWA': 6,
#  'NICARAGUA': 6,
#  'NEW BRITAIN': 6,
#  'SOMALIA': 6,
#  'KIRIBATI': 6,
#  'SINGAPORE': 6,
#  'PALAU': 5,
#  'MALAYSIA': 5,
#  'MALTA': 5,
#  'AZORES': 5,
#  'TURKS & CAICOS': 5,
#  'MID ATLANTIC OCEAN': 5,
#  'SAUDI ARABIA': 5,
#  'BURMA': 4,
#  'NORTH ATLANTIC OCEAN': 4,
#  'PERSIAN GULF': 4,
#  'EL SALVADOR': 4,
#  'URUGUAY': 4,
#  'SUDAN': 4,
#  'GRENADA': 4,
#  'HONDURAS': 4,
#  'GUAM': 4,
#  'NIGERIA': 4,
#  'RUSSIA': 4,
#  'MONTENEGRO': 3,
#  'CEYLON': 3,
#  'TRINIDAD & TOBAGO': 3,
#  'MARTINIQUE': 3,
#  ' TONGA': 3,
#  'BELIZE': 3,
#  'GUINEA': 3,
#  'AMERICAN SAMOA': 3,
#  'PORTUGAL': 3,
#  'Fiji': 3,
#  'TUNISIA': 3,
#  'LEBANON': 3,
#  'GUYANA': 3,
#  'MICRONESIA': 3,
#  'HAITI': 3,
#  'LIBERIA': 3,
#  'CAPE VERDE': 3,
#  'YEMEN': 2,
#  'UNITED ARAB EMIRATES': 2,
#  'WEST INDIES': 2,
#  'EGYPT ': 2,
#  'ICELAND': 2,
#  'CRETE': 2,
#  'SOUTHWEST PACIFIC OCEAN': 2,
#  'SOUTH PACIFIC OCEAN': 2,
#  'JOHNSTON ISLAND': 2,
#  'NORWAY': 2,
#  'CAYMAN ISLANDS': 2,
#  'CENTRAL PACIFIC': 2,
#  'UNITED ARAB EMIRATES (UAE)': 2,
#  'ST HELENA, British overseas territory': 2,
#  'PACIFIC OCEAN ': 2,
#  'NAMIBIA': 2,
#  'TOBAGO': 2,
#  'ANTIGUA': 2,
#  'MEDITERRANEAN SEA': 2,
#  'SAN DOMINGO': 1,
#  'RED SEA?': 1,
#  'REUNION ISLAND': 1,
#  'CYPRUS': 1,
#  'IRELAND': 1,
#  'KUWAIT': 1,
#  'ASIA?': 1,
#  'MONACO': 1,
#  'FALKLAND ISLANDS': 1,
#  'INDIAN OCEAN?': 1,
#  'PARAGUAY': 1,
#  'EQUATORIAL GUINEA / CAMEROON': 1,
#  'ALGERIA': 1,
#  'Coast of AFRICA': 1,
#  'TASMAN SEA': 1,
#  'GHANA': 1,
#  'AFRICA': 1,
#  'PERU': 1,
#  'GREENLAND': 1,
#  'SWEDEN': 1,
#  'COOK ISLANDS': 1,
#  'ROATAN': 1,
#  'BRITISH NEW GUINEA': 1,
#  'ANDAMAN ISLANDS': 1,
#  'Between PORTUGAL & INDIA': 1,
#  'TUVALU': 1,
#  'DJIBOUTI': 1,
#  'SYRIA': 1,
#  'GEORGIA': 1,
#  'BAHREIN': 1,
#  'OCEAN': 1,
#  'KOREA': 1,
#  'ITALY / CROATIA': 1,
#  'COMOROS': 1,
#  'CURACAO': 1,
#  'SLOVENIA': 1,
#  'BRITISH ISLES': 1,
#  'WESTERN SAMOA': 1,
#  'BANGLADESH': 1,
#  'SOUTH CHINA SEA': 1,
#  'ANGOLA': 1,
#  'NORTHERN ARABIAN SEA': 1,
#  'EGYPT / ISRAEL': 1,
#  'MEXICO ': 1,
#  'Seychelles': 1,
#  'GRAND CAYMAN': 1,
#  'ST. MAARTIN': 1,
#  'Sierra Leone': 1,
#  'GULF OF ADEN': 1,
#  'BRITISH VIRGIN ISLANDS': 1,
#  'NEVIS': 1,
#  'MALDIVES': 1,
#  'PALESTINIAN TERRITORIES': 1,
#  'DIEGO GARCIA': 1,
#  'ST. MARTIN': 1,
#  'PUERTO RICO': 1,
#  'ARUBA': 1,
#  'RED SEA': 1,
#  'FEDERATED STATES OF MICRONESIA': 1,
#  'ADMIRALTY ISLANDS': 1,
#  'ARGENTINA': 1,
#  'MID-PACIFC OCEAN': 1,
#  'BAY OF BENGAL': 1,
#  'SOLOMON ISLANDS / VANUATU': 1,
#  ' PHILIPPINES': 1,
#  'JAVA': 1,
#  'IRAN / IRAQ': 1,
#  'NORTHERN MARIANA ISLANDS': 1,
#  'NETHERLANDS ANTILLES': 1,
#  'GUATEMALA': 1,
#  'SUDAN?': 1,
#  'BRITISH WEST INDIES': 1,
#  'THE BALKANS': 1,
#  'NORTH ATLANTIC OCEAN ': 1,
#  'MAYOTTE': 1,
#  'GABON': 1,
#  'ANDAMAN / NICOBAR ISLANDAS': 1,
#  'MALDIVE ISLANDS': 1,
#  'NICARAGUA ': 1,
#  'NORTH SEA': 1,
#  'RED SEA / INDIAN OCEAN': 1,
#  'CEYLON (SRI LANKA)': 1}

# %%
# Country will be unknown if null

df['country'].fillna('unknown', inplace = True)

getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
df['area'][df['area'].isnull()] = 'Some area from ' + df['country']

getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
dict(df['area'].value_counts())
# Out:
# {'Florida': 1037,
#  'New South Wales': 486,
#  'Queensland': 311,
#  'Hawaii': 298,
#  'California': 290,
#  'KwaZulu-Natal': 213,
#  'Western Cape Province': 195,
#  'Western Australia': 189,
#  'South Carolina': 160,
#  'Eastern Cape Province': 160,
#  'South Australia': 104,
#  'North Carolina': 101,
#  'Victoria': 90,
#  'Pernambuco': 74,
#  'Texas': 73,
#  'Torres Strait': 70,
#  'North Island': 67,
#  'New Jersey': 52,
#  'Tasmania': 41,
#  'South Island': 40,
#  'Some area from unknown': 35,
#  'New York': 30,
#  'Oregon': 29,
#  'Some area from BAHAMAS': 27,
#  'Abaco Islands': 23,
#  'Northern Territory': 23,
#  'Central Province': 22,
#  'Havana Province': 19,
#  'Virginia': 19,
#  'South Province': 17,
#  'Gaza': 16,
#  'Massachusetts': 16,
#  'Puerto Rico': 16,
#  'Madang Province': 16,
#  'Alabama': 15,
#  'Some area from FIJI': 15,
#  'New Ireland Province': 15,
#  'Veracruz': 15,
#  'Some area from AUSTRALIA': 14,
#  'Georgia': 14,
#  'Some area from NEW CALEDONIA': 14,
#  'Guerrero': 13,
#  'Luzon Island': 13,
#  'Khuzestan Province': 13,
#  'Some area from JAMAICA': 12,
#  'North Province': 12,
#  'Quintana Roo': 12,
#  'Adriatic Sea': 12,
#  'Malampa Province': 11,
#  'Tyrrhenian Sea': 11,
#  'Louisiana': 11,
#  'Rio de Janeiro': 11,
#  'Mediterranean Sea': 11,
#  'Some area from ATLANTIC OCEAN': 11,
#  'Grand Bahama Island': 10,
#  'Baja California': 10,
#  'Some area from EGYPT': 10,
#  'Basrah': 9,
#  ' Primorje-Gorski Kotar County': 9,
#  'Eastern Province': 9,
#  'Tamil Nadu': 9,
#  'Bougainville (North Solomons)': 9,
#  'Red Sea': 9,
#  'Some area from SOLOMON ISLANDS': 9,
#  'Some area from INDIA': 9,
#  'Society Islands': 9,
#  'Some area from REUNION': 9,
#  'Maputo Province': 8,
#  'Admiralty Islands, Manus Province': 8,
#  'Some area from BRAZIL': 8,
#  'Milne Bay Province': 8,
#  'Canary Islands': 8,
#  'Some area from PHILIPPINES': 8,
#  'Binh Dinh Province': 8,
#  'West Bengal': 8,
#  'Kingston Parish': 8,
#  'New Britain': 8,
#  'Morobe Province': 8,
#  'Some area from MEXICO': 8,
#  'Viti Levu Island': 8,
#  'Delaware': 7,
#  'Maryland': 7,
#  'Some area from HONG KONG': 7,
#  'Andros Islands': 7,
#  'South Sinai Peninsula': 7,
#  'Mirs Bay ': 7,
#  'Rhode Island': 7,
#  'Sicily': 7,
#  'Aden': 7,
#  'Some area from CARIBBEAN SEA': 7,
#  'West New Britain Province': 7,
#  'Some area from PACIFIC OCEAN': 7,
#  'Galapagos Islands': 7,
#  'Caribbean Sea': 7,
#  'Karun River': 7,
#  'Some area from TANZANIA': 6,
#  'Cap Vert Peninsula': 6,
#  'Coast Province': 6,
#  'Bimini Islands': 6,
#  'Some area from PAPUA NEW GUINEA': 6,
#  'Loyalty Islands': 6,
#  'Ehime Prefecture': 6,
#  'Connecticut': 6,
#  'Some area from BERMUDA': 6,
#  'Tuamotus': 6,
#  'Guantanamo Province': 6,
#  'Hamilton': 6,
#  'Bali': 6,
#  'New Providence Island': 6,
#  'Inhambane Province': 6,
#  'Shatt-al-Arab River': 6,
#  'Some area from CUBA': 6,
#  'Some area from AZORES': 5,
#  'Some area from VIETNAM': 5,
#  'Tamaulipas': 5,
#  'Western Province': 5,
#  'Maranhão': 5,
#  'Western Area': 5,
#  'Limpopo River': 5,
#  'Madang': 5,
#  'Some area from TURKEY': 5,
#  'Mississippi': 5,
#  'Some area from ENGLAND': 5,
#  'Some area from ITALY': 5,
#  'Some area from SINGAPORE': 5,
#  'Exuma Islands': 5,
#  'US Virgin Islands': 5,
#  "Vava'u": 5,
#  'Some area from SOUTH AFRICA': 5,
#  'Some area from GREECE': 5,
#  'Taveuni': 5,
#  'Some area from MADAGASCAR': 5,
#  'Nova Scotia': 4,
#  'Guerro': 4,
#  'New Territories': 4,
#  'Some area from CROATIA': 4,
#  'Some area from MAURITIUS': 4,
#  'Banaadir Region': 4,
#  'Vanua Levu': 4,
#  'Some area from SPAIN': 4,
#  'Some area from PANAMA': 4,
#  'Sardinia': 4,
#  'Sinai Peninsula': 4,
#  'Tuscany': 4,
#  'Cornwall': 4,
#  'Vita Levu': 4,
#  '22ºN, 88ºE': 4,
#  'Catalonia': 4,
#  'Colima': 4,
#  'Saint-Denis': 4,
#  'Zadar County': 4,
#  'Some area from USA': 4,
#  'Eleuthera': 4,
#  'Some area from INDIAN OCEAN': 4,
#  'Saint-Paul': 4,
#  'Some area from VENEZUELA': 4,
#  'Saint-Gilles': 4,
#  'Some area from SOUTH KOREA': 4,
#  'Cook Islands': 4,
#  'Some area from SRI LANKA': 4,
#  'New Ireland Province, Bismarck Archipelago': 4,
#  'Liguria': 4,
#  'Devon': 3,
#  'Westmoreland Parish': 3,
#  'Mombasa': 3,
#  'Vera Cruz': 3,
#  'Cádiz': 3,
#  'Saint-Pierre': 3,
#  'Santiago de Cuba Province': 3,
#  'Zamboanga del Sur Province': 3,
#  'Corfu Island': 3,
#  'Saint-Leu': 3,
#  'Some area from MARTINIQUE': 3,
#  'Eniwetok Atoll': 3,
#  'Gulf of Panama': 3,
#  'St. Johns Reef': 3,
#  'Some area from INDONESIA': 3,
#  'Tutuila Island': 3,
#  'Yasawa Islands': 3,
#  'Some area from CHILE': 3,
#  'Red Sea State': 3,
#  'Westerm Australia': 3,
#  'Cocos Island': 3,
#  'Some area from CEYLON': 3,
#  'Some area from COSTA RICA': 3,
#  'Java': 3,
#  'Louisiade Archipelago': 3,
#  'La Libertad': 3,
#  'Bahia': 3,
#  'Abau Sub District, Central Province': 3,
#  'Vava\x92u': 3,
#  "Grand'Anse": 3,
#  'Calabria': 3,
#  ' Split-Dalmatia Count,': 3,
#  'Some area from JAPAN': 3,
#  'Western Caroline Islands': 3,
#  'Primorje-Gorski Kotar County ': 3,
#  'Lake Nicaragua (fresh water)': 3,
#  'Some area from NEW ZEALAND': 3,
#  'Guerrrero': 3,
#  'St. Andrew Parish': 3,
#  'Guadalcanal Province': 3,
#  'Trinidad': 3,
#  'New York ': 3,
#  'Some area from NORTH PACIFIC OCEAN': 3,
#  'Istria County': 3,
#  'Viti Levu': 3,
#  'Guanacaste': 3,
#  'Isle of Wight': 3,
#  'Upolu Island': 3,
#  'Some area from MOZAMBIQUE': 3,
#  'Northern Taiwan': 3,
#  'Vitu Levu': 3,
#  'Sinaloa': 3,
#  'Manila': 3,
#  'Okayama Prefecture': 3,
#  'Tuamotos': 3,
#  'Some area from MID ATLANTIC OCEAN': 3,
#  'Alicante': 3,
#  'Some area from SAMOA': 3,
#  'Saint-Gilles-les-Bains': 3,
#  'Some area from SOUTH ATLANTIC OCEAN': 3,
#  'Hong Kong': 3,
#  'Canal Zone': 2,
#  'Some area from SOUTHWEST PACIFIC OCEAN': 2,
#  'Oaxaca': 2,
#  'Duke of York Islands': 2,
#  'Berry Islands': 2,
#  'Torres Strait ': 2,
#  'Out Islands': 2,
#  'Phoenix Islands': 2,
#  '1000 miles west of Hawaii': 2,
#  'Honiara': 2,
#  'Alinglaplap Atoll': 2,
#  'Lau Group': 2,
#  'San Blas Islands': 2,
#  'Nueva Esparta': 2,
#  'Southland': 2,
#  'Cheshire': 2,
#  'Victoria ': 2,
#  'Some area from SOUTH PACIFIC OCEAN': 2,
#  'East Sepik': 2,
#  'New Georgia': 2,
#  'Rio Grande de Norte': 2,
#  'Some area from IRAQ': 2,
#  'East Java': 2,
#  'Miyako Island': 2,
#  'Some area from JOHNSTON ISLAND': 2,
#  'Villa Clara Province': 2,
#  'Miyako': 2,
#  'Gulf Province': 2,
#  'Some area from COLUMBIA': 2,
#  'Sea of Japan': 2,
#  'Great Exuma Island': 2,
#  'Newfoundland': 2,
#  'Eastern  Province': 2,
#  'Some area from CHINA': 2,
#  'New Ireland': 2,
#  ' Split-Dalmatia County': 2,
#  'East New Britain Province': 2,
#  'Ralik Archipelago': 2,
#  'Dorset': 2,
#  'St Michael Parish': 2,
#  'Paget': 2,
#  'English Channel': 2,
#  'Some area from OKINAWA': 2,
#  'Saint-Philippe': 2,
#  'Off Libya': 2,
#  'Ligurian Sea': 2,
#  'Kadavu': 2,
#  'Cat Cay': 2,
#  'Colon Province': 2,
#  'Between Hawaii & Wake Island': 2,
#  'Anzoategui': 2,
#  'Colón Province': 2,
#  'Limón Province': 2,
#  'Some area from SIERRA LEONE': 2,
#  'Valencia': 2,
#  'Saint-Joseph': 2,
#  'Some area from CENTRAL PACIFIC': 2,
#  'Venice Province': 2,
#  'Eastern Caroline Islands': 2,
#  'Montserrado': 2,
#  'Tongapatu Group': 2,
#  'North Carolina ': 2,
#  'Inhambe Province': 2,
#  'Orissa': 2,
#  'Near Puntarenas': 2,
#  'Some area from CRETE': 2,
#  'Some area from WEST INDIES': 2,
#  'Some area from SENEGAL': 2,
#  'Some area from GUAM': 2,
#  'Some area from SEYCHELLES': 2,
#  'Some area from BELIZE': 2,
#  'Palawan': 2,
#  'Saint-Benoit': 2,
#  'Rocha': 2,
#  'Malaga': 2,
#  'Corfu': 2,
#  'Praslin': 2,
#  'Caicos Bank': 2,
#  'Matanzas Province (north coast)': 2,
#  'Some area from DOMINICAN REPUBLIC': 2,
#  'Gilbert Islands': 2,
#  'Veracruz ': 2,
#  'Some area from FRANCE': 2,
#  'Some area from SOMALIA': 2,
#  'Makira-Ulawa Province': 2,
#  'Hoogly River': 2,
#  'Off the coast of West Africa': 2,
#  'Some area from TAIWAN': 2,
#  'Luzon': 2,
#  'Cumberland': 2,
#  'Taitung ': 2,
#  'Western Area ': 2,
#  'Ionian Sea': 2,
#  'Hua Hin': 2,
#  'Alagoas': 2,
#  'Some area from BURMA': 2,
#  'Holquin Province': 2,
#  'New Providence District': 2,
#  'Ascension Island': 2,
#  'Washington': 2,
#  'Dodecanese Islands': 2,
#  'South Devon': 2,
#  'Grand Terre': 2,
#  'Palmyra Atoll': 2,
#  'Grand Canary Island': 2,
#  'Bora Bora': 2,
#  'Some area from MEDITERRANEAN SEA': 2,
#  "Côte d'Azur ": 2,
#  'Some area from GUINEA': 2,
#  'd\x92Étang-Salé': 2,
#  'Some area from BARBADOS': 2,
#  'West End': 2,
#  'Maharashtra': 2,
#  'Sussex': 2,
#  'Some area from TOBAGO': 2,
#  'East coast': 2,
#  'Wakayama Prefecture': 2,
#  'Rangoon': 2,
#  'Some area from LEBANON': 2,
#  "Nuku'alofa": 2,
#  'Some area from THAILAND': 2,
#  'Saint-Benoît': 2,
#  'Camaguey Province': 2,
#  'Northwest of Papua New Guinea': 1,
#  'Southwest coast': 1,
#  'Some area from ROATAN': 1,
#  'Bardestrand': 1,
#  'Socotra Islands': 1,
#  'Munxar Reef': 1,
#  'Las Perlas archipelago': 1,
#  'Some area from Between PORTUGAL & INDIA': 1,
#  'Some area from SOLOMON ISLANDS / VANUATU': 1,
#  'Between Hawaii and U.S.A.': 1,
#  'Off South American coast': 1,
#  'Kerala': 1,
#  '40 miles south of Naples ': 1,
#  'Some area from PORTUGAL': 1,
#  '300 miles east of Luzon': 1,
#  ' North Carolina': 1,
#  'In transit between Tinian and Leyte': 1,
#  'Northern Java': 1,
#  'Tel Aviv': 1,
#  'Off Thessaly': 1,
#  'Piraeus': 1,
#  'Magarita or Cubagua Islands': 1,
#  '04.05N-13.23W': 1,
#  'Bernardino Strait near Gulf of Leyte': 1,
#  'Off Samar Island in the Gulf of Leyte': 1,
#  'Ratak ': 1,
#  'Pacific Ocean': 1,
#  'Nice & Marseilles': 1,
#  'Near the Fiji Islands': 1,
#  'Makora-Ulawa Province': 1,
#  'Midway Atoll': 1,
#  'Skagerrak arm of the North Sea': 1,
#  'Southern Cyprus': 1,
#  'Some area from REUNION ISLAND': 1,
#  'Panama Bay (Pacific Ocean)': 1,
#  'Paraiba': 1,
#  'Cape Coast': 1,
#  'In Convoy OB 274': 1,
#  'Rivers State': 1,
#  'Trelawney Province': 1,
#  'Some area from NORWAY': 1,
#  'Quezon': 1,
#  'Off coast of Ecuador': 1,
#  'Provence': 1,
#  'Some area from ANTIGUA': 1,
#  'Bocas del Toro': 1,
#  'North of Pernambuco, Brazil': 1,
#  'St. Anne': 1,
#  'St Helena': 1,
#  'Moluccas': 1,
#  'Some area from FALKLAND ISLANDS': 1,
#  'Off Cape Haitien': 1,
#  'Some area from GREENLAND': 1,
#  'Panama City': 1,
#  '(Southwestern Pacific)': 1,
#  'Cay Sal Bank': 1,
#  'Camiguin Island': 1,
#  'Rio San Juan': 1,
#  'West of Ceylon (Sri  Lanka)': 1,
#  '300 miles east of St. Thomas (Virgin Islands)': 1,
#  'Some area from CANADA': 1,
#  'Some area from BAY OF BENGAL': 1,
#  'Ryukyu': 1,
#  'Dar-es-Salaam ': 1,
#  '"Head of the Gulf"': 1,
#  '330 to 350 miles east of Wake Island': 1,
#  'Curacao': 1,
#  'Milne Bay  Province': 1,
#  'Teramo': 1,
#  'Some area from RED SEA?': 1,
#  'Island of Volos': 1,
#  'Genoa  Province': 1,
#  'Some area from GUATEMALA': 1,
#  'Amirante Islands': 1,
#  'Kadavu Island Group': 1,
#  'Toamasina Province': 1,
#  'Mindoro Occidental': 1,
#  'Riau Province': 1,
#  'Bikini Atoll': 1,
#  'Negros ': 1,
#  'Between New Ireland & New Britain': 1,
#  'South Korea': 1,
#  'Buenos Aires Province': 1,
#  'South shore ': 1,
#  'Slovenia': 1,
#  'Liguaria': 1,
#  'Nagasaki Prefecture': 1,
#  'Isle of Man': 1,
#  'Wake Island': 1,
#  'Isles del Rosario': 1,
#  'Muala': 1,
#  'Illinois': 1,
#  'Ba Ria-Vung Tau  Province': 1,
#  'Moala Island': 1,
#  '18S / 50E': 1,
#  'Imperia Province': 1,
#  'Port Louis Province': 1,
#  'Bay of Maputu': 1,
#  "35º39 : 165º8'": 1,
#  'Shatt-el-Arab River': 1,
#  'Kwajalein': 1,
#  'Bocas del Toro Province': 1,
#  'Carpathian Sea': 1,
#  'Saipan': 1,
#  'Bandar Ma\x92shur sea inlet': 1,
#  'Adana Province': 1,
#  'Attica': 1,
#  'Between Kwajalein Atoll & Johnston Island': 1,
#  'Rocha ': 1,
#  'Shat-Al-Arab River': 1,
#  'Calvados Archipelago': 1,
#  'Gulf of Tadjoura': 1,
#  'Cyrenaica': 1,
#  'Northern Province': 1,
#  'Syracuse': 1,
#  'Sofala Province': 1,
#  'Los Roques  Islands': 1,
#  'Western Viscayas': 1,
#  'Singapore Harbor': 1,
#  'Jakarta Harbour': 1,
#  'Southern Province': 1,
#  'Savona': 1,
#  'Some area from BAHREIN': 1,
#  'Sago Prefecture': 1,
#  'Malaita Province': 1,
#  ' La Libertad': 1,
#  'Naples Province': 1,
#  'Taranto': 1,
#  'Salerno Province': 1,
#  'Salerno': 1,
#  'CUBA': 1,
#  'Bay of Campeche': 1,
#  'Sanma Province': 1,
#  ' Manila Bay': 1,
#  '60 miles north of San Domingo in the West Indies': 1,
#  'Turtle Bogue': 1,
#  'Halifax': 1,
#  'Andaman Islands': 1,
#  'Woodlark Islands': 1,
#  'Leyte': 1,
#  'Misamis Oriental': 1,
#  'Some area from NEW GUINEA': 1,
#  'Strait of Messina': 1,
#  'Cape Haitien': 1,
#  'Cavite Province, Luzon': 1,
#  'Some area from PARAGUAY': 1,
#  'East Yorkshire': 1,
#  'Lucy': 1,
#  'Line Islands': 1,
#  'Off Ireland': 1,
#  'Demerara County': 1,
#  'Galica': 1,
#  '150 miles offshore': 1,
#  'Cyclades archipelago': 1,
#  'Tiburon Peninsula': 1,
#  'Mount Lebanon': 1,
#  '2 to 3 miles off Taboguilla Island, Pacific Ocean': 1,
#  'Vancouver': 1,
#  'Between Hastings & Fairlight, Sussex': 1,
#  'Valencia ': 1,
#  'Brittany': 1,
#  'Bay of Monaco': 1,
#  'South of the Equator ': 1,
#  'Sants-Montjic': 1,
#  'Colon': 1,
#  'Some area from PERSIAN GULF': 1,
#  'Norfolk Island': 1,
#  'Somewhere between Philadelphia and Hiogo, Japan': 1,
#  'Sfax': 1,
#  'Andalucia': 1,
#  '30 nm from Singapore': 1,
#  'Between Perth & Colombo': 1,
#  'Zambesi River': 1,
#  'Gujarat': 1,
#  'South Atlantic Ocean': 1,
#  'Lukovo': 1,
#  'Georges Bank': 1,
#  'Cortés': 1,
#  'Chatham Islands': 1,
#  'Málaga ': 1,
#  'Balearics': 1,
#  'Gulf of California': 1,
#  ' New Jersey': 1,
#  'Some area from KUWAIT': 1,
#  "Côte d'Azur  ": 1,
#  'Maldonado coast': 1,
#  'Viti Levu group': 1,
#  '5aint-Denis': 1,
#  'Trieste': 1,
#  'Galicia': 1,
#  'Some area from GEORGIA': 1,
#  'Lagos ': 1,
#  'Essequibo': 1,
#  'Western Banks': 1,
#  'Apolima Strait': 1,
#  'Gran Canaria': 1,
#  'Some area from SYRIA': 1,
#  'Gulf of Suez': 1,
#  'Golfo di Genova in the Ligurian Sea': 1,
#  'Some area from FRENCH POLYNESIA': 1,
#  'Northern Peloponnese': 1,
#  'Between Australia & USA': 1,
#  'Arran': 1,
#  'Some area from ANDAMAN ISLANDS': 1,
#  'Argyllshire': 1,
#  'Suez Canal': 1,
#  'Queensland ': 1,
#  'Bonin Islands': 1,
#  'Fernando Po Island': 1,
#  'Mangaia Island': 1,
#  'Bayelsa State': 1,
#  'Corfu ': 1,
#  'Basrah City': 1,
#  'Nicoya Peninsula': 1,
#  'Lower San Juan River': 1,
#  ' Nusa Tenggara': 1,
#  'Tongatapu': 1,
#  'Maluku Province': 1,
#  'Some area from PERU': 1,
#  'Norfolk': 1,
#  'Some area from AFRICA': 1,
#  'North China': 1,
#  'Some area from NAMIBIA': 1,
#  'Ascension Bay': 1,
#  'Carabobo': 1,
#  'Between Noumea & Sydney': 1,
#  'Some area from ALGERIA': 1,
#  'Bay of Bengal': 1,
#  'Ancona Province': 1,
#  'Island of St. Thomas': 1,
#  'Western Papuan Gulf': 1,
#  'Bwagaoia': 1,
#  'Conakry Region': 1,
#  'Argyll': 1,
#  'Salinas Bay': 1,
#  'Some area from ISRAEL': 1,
#  'Porto Seguro': 1,
#  'Some area from HONDURAS': 1,
#  'Santiago Island': 1,
#  'Some area from TUVALU': 1,
#  'Cienfuegos Province': 1,
#  'Some area from INDIAN OCEAN?': 1,
#  'Black River': 1,
#  'Niua ': 1,
#  'French Southern Territories': 1,
#  'Lomaiviti Provine': 1,
#  'Bay of Fundy': 1,
#  'Off the coast of South America': 1,
#  'Barlavento Islands': 1,
#  'Some area from GUYANA': 1,
#  'Harare Province': 1,
#  'Sumatra': 1,
#  'Istanbul': 1,
#  'Elqui Province': 1,
#  'South Island?': 1,
#  'Some area from ITALY / CROATIA': 1,
#  'Herzliyah': 1,
#  'Alpes Maritime': 1,
#  'Northern (Oro) Province': 1,
#  'Edinburgh': 1,
#  'Makira-Uluwa Province': 1,
#  'Eastern Catalona': 1,
#  '300 miles east of Mauritius': 1,
#  'Khánh Hòa Province': 1,
#  'Foveaux Strait': 1,
#  'Fishing Grounds': 1,
#  'New Ireland, Bismarck Archipelago': 1,
#  'Taranto province': 1,
#  'Open sea': 1,
#  'Between Somalia & Yemen': 1,
#  'Territory of Cocos (Keeling) Islands': 1,
#  'Oslo Fjord': 1,
#  'Kent': 1,
#  'Bird Island': 1,
#  'Providenciales': 1,
#  'Muhafazat Hadramawt': 1,
#  'Cook islans': 1,
#  'Surigao del Norte': 1,
#  'Ambergris Caye': 1,
#  'Shanghai': 1,
#  'Kentucky': 1,
#  'Guam': 1,
#  '300 miles from Antigua': 1,
#  '800 miles from land': 1,
#  '600 nm west of the Canary Islands': 1,
#  'Simpson Bay': 1,
#  'East Wall': 1,
#  'Inner Islands': 1,
#  'Marovo Lagoon': 1,
#  'Green Bay': 1,
#  'Tokyo Bay': 1,
#  'Northern Bahamas': 1,
#  'Merizo': 1,
#  'Rio Grande Do Sul': 1,
#  'Dubai': 1,
#  'Eastern Cape  Province': 1,
#  'Bocas': 1,
#  'Fife': 1,
#  'Some area from NEVIS': 1,
#  'Catalunya': 1,
#  'Off Green Island': 1,
#  'North Region': 1,
#  'Batangas province': 1,
#  'Strait of Malacca': 1,
#  'Batanes Provine': 1,
#  'North Devon': 1,
#  'San Carlos': 1,
#  'Cabo San Lucas': 1,
#  'Easter Ross': 1,
#  'Some area from LIBERIA': 1,
#  "South Ch'ungch'ong Province": 1,
#  'Izo Islands': 1,
#  "L'Etang-Sale": 1,
#  'Phang nga Province': 1,
#  'Ralik Chain': 1,
#  'Grand Baie': 1,
#  "L' Etang Salé-les-Bains": 1,
#  'Southern Japan': 1,
#  'Marches region': 1,
#  'Transvaal': 1,
#  'Beaufonds': 1,
#  'Chatham Islands ': 1,
#  'Bay Islands': 1,
#  'South Sinai, Gulf of Aqaba': 1,
#  'Missouri': 1,
#  '12 miles off the north coast': 1,
#  'Saint-Paul ': 1,
#  'Chatham Islands, east of New  Zealand': 1,
#  'Some area from NORTHERN ARABIAN SEA': 1,
#  'Clearwater Bay': 1,
#  'Aichi Prefecture': 1,
#  'Worcestershire': 1,
#  'Minerva Reef': 1,
#  'Alaska': 1,
#  'New Brunswick': 1,
#  'New Mexico': 1,
#  'Santa Isabel Province': 1,
#  'Conservatória District': 1,
#  'South Carolina ': 1,
#  'Kuril Islands in the Pacific': 1,
#  'South Island, near Karitane north of Dunedin': 1,
#  'Northlands': 1,
#  'Pearl Islands': 1,
#  'Johnston Atoll': 1,
#  'Baatan': 1,
#  'North Pacific coast': 1,
#  'Caroline Islands': 1,
#  'KwaZulu-Natal between Port Edward and Port St Johns': 1,
#  'Some area from TURKS & CAICOS': 1,
#  'Cikobia Island (north of Vanua Levu)': 1,
#  'Rayong Province': 1,
#  'Off the western coast of peninsular Malaysia': 1,
#  'Off Vanua Levu': 1,
#  'Antsiranana Province': 1,
#  'Some area from MALTA': 1,
#  'Altagracia Province': 1,
#  'Saint-Andre': 1,
#  'Bimini': 1,
#  'Alicante Province': 1,
#  'Kochi Prefecture': 1,
#  'Isla Provedencia': 1,
#  'Suez': 1,
#  'Boa Vista Island': 1,
#  'Santa Catarina State': 1,
#  'Grand Cayman': 1,
#  'Jeju Province': 1,
#  'Balneário Camboriú': 1,
#  'Fujairah Emirate': 1,
#  'Some area from ARUBA': 1,
#  'Phuket': 1,
#  'Some area from PUERTO RICO': 1,
#  'Le Port': 1,
#  'Rangiroa': 1,
#  'Central Tuamotu': 1,
#  'Great Exuma': 1,
#  'Baja California Sur': 1,
#  'Sharjah, ': 1,
#  'New Providence ': 1,
#  'Alifu Alifu Atoll': 1,
#  'New Providence': 1,
#  'Boi Island, Victoria': 1,
#  'Fernando de Noronha': 1,
#  'Sepang': 1,
#  'Some area from LIBYA': 1,
#  'Pamplemousses ': 1,
#  ' Upolu Island': 1,
#  'Shizuoka Prefecture': 1,
#  'Castellón': 1,
#  'Red Sea Protectorate': 1,
#  '40 miles off Grand Bahama Island': 1,
#  'Majorca': 1,
#  'Tabasco': 1,
#  'Anjouan': 1,
#  'Ibiza Island': 1,
#  'Marquesas': 1,
#  'Granada': 1,
#  'Cargados Carajos Shoals (St. Brandon)': 1,
#  'Moorea': 1,
#  'Antofagasta Province': 1,
#  'Santa Elena': 1,
#  'East New Britain': 1,
#  'Bois-Blanc ': 1,
#  'Moray': 1,
#  'Samaná Province': 1,
#  'Primorsky Krai': 1,
#  'Peter the Great Bay, Khasan, Primorsky Krai (Far East)': 1,
#  'Telyakovsky Bay, Khasan,  Primorsky Krai (Far East)': 1,
#  'Sucre': 1,
#  'Middle Caicos': 1,
#  'San Andrés archipelago': 1,
#  'Kedah': 1,
#  'Umm al Qaywayan Province': 1,
#  ' Loyalty Islands': 1,
#  'Saint Gilles ': 1,
#  'Maine': 1,
#  "Ha'api ": 1,
#  "St John's": 1,
#  'Tabuk Province': 1,
#  'Some area from ST. MARTIN': 1,
#  'British Colombia': 1,
#  'Atsumi peninsula': 1,
#  'Wallis and Futuna': 1,
#  'Baie de Sainte-Marie': 1,
#  'Some area from CAYMAN ISLANDS': 1,
#  'Okinawa Prefecture': 1,
#  '740 miles SE of Tarawa Atoll': 1,
#  'Southern District': 1,
#  'Bay of Biscay': 1,
#  'Some area from DIEGO GARCIA': 1,
#  'Some area from PALESTINIAN TERRITORIES': 1,
#  'Santa Cruz Island': 1,
#  'St. Catherine': 1,
#  'Mercury Islands': 1,
#  'Delta': 1,
#  'Inner Hebrides': 1,
#  'Saint Leu': 1,
#  'Trois-Bassins': 1,
#  'Tafea Province': 1,
#  'Kagoshima Prefecture': 1,
#  'Costa Blanca': 1,
#  'Western District': 1,
#  'Sandaun Province': 1,
#  'Anatolia': 1,
#  'United Arab Emirates': 1,
#  'Wake Island (EnenKio)': 1,
#  '19S, 178?E': 1,
#  'Pennsylvania': 1,
#  '9.35N 79.35W': 1,
#  'Roncador Bank': 1,
#  'Enroute from Suez to Aden (Yemen)': 1,
#  ' Lau Province': 1,
#  '180 miles southeast of Okinawa': 1,
#  'Cap-Vert Peninsula': 1,
#  'Delagoa Bay': 1,
#  'In the English Channel ': 1,
#  'Cook Strait': 1,
#  'Unknown, treated at Wick, SCOTLAND': 1,
#  'Corregidor Island': 1,
#  '33N, 68W': 1,
#  '25 km off the coast of Iran & 483km from mouth of Persian Gulf': 1,
#  '165  miles from Bermuda': 1,
#  'Shefa Province': 1,
#  'Western Luzon Island': 1,
#  'Santo Domingo': 1,
#  'San Blas coast': 1,
#  'Thessaly': 1,
#  'Lomaiviti  Island Group': 1,
#  'Rodrigues': 1,
#  'Manus Island': 1,
#  'Pinas Bay': 1,
#  'Grand Turk Island': 1,
#  'Off coast of West Africa': 1,
#  'Sharon': 1,
#  'Antalya Province': 1,
#  'Northern District': 1,
#  'Cyclades': 1,
#  'Off the Coromandel Peninsula, North Island': 1,
#  '10ºS, 142ºE': 1,
#  'Kwajalein Atoll': 1,
#  'East Flores': 1,
#  'Casamance': 1,
#  'Madang (WO)': 1,
#  'Between Timor & Darwin, Australia': 1,
#  'Ahirkapi coast': 1,
#  'Primorje-Gorski Kotar County': 1,
#  'Taipei Hsien': 1,
#  'Ibaraki Prefecture': 1,
#  'South Pacific Ocean': 1,
#  '1,000 miles east of Hawaii': 1,
#  'Yucatan Channel': 1,
#  'Abau Subdistrict,Central Province': 1,
#  'New Britain, Bismarck Archipelago': 1,
#  'Estuaire Province': 1,
#  'Near Dakar, Cap Vert Peninsula': 1,
#  'Near the Andaman & Nicobar Islands': 1,
#  'Mozambique Channel': 1,
#  'Tyrrenian Sea': 1,
#  'Congreve Channel': 1,
#  'St. Thomas Bay': 1,
#  'Madeira': 1,
#  'Between Comores & Madagascar': 1,
#  'Some area from ANDAMAN / NICOBAR ISLANDAS': 1,
#  'South Chungcheong Province': 1,
#  'Pacific coast': 1,
#  ' Kikori River mouth': 1,
#  'St. Georges ': 1,
#  'Northwest of Viti Levu': 1,
#  'Rigo subdistrict': 1,
#  'Masbate': 1,
#  '400 miles southeast of Sri Lanka': 1,
#  'Lomaiviti Province': 1,
#  'Leyte Island': 1,
#  'Hokkaido Prefecture': 1,
#  'North Palawan': 1,
#  'Queaon': 1,
#  'Istria': 1,
#  'PANAMA': 1,
#  'In the Gulf Stream ': 1,
#  'Mersin Province': 1,
#  'Guyamas': 1,
#  'Between England & South Africa': 1,
#  'Mindanao': 1,
#  'Ysabel Island': 1,
#  'South Coast, East New Britain': 1,
#  'Walkers Cay': 1,
#  'Some area from TUNISIA': 1,
#  'Florida Straits': 1,
#  'Gulf of Lyons': 1,
#  'Some area from IRAN': 1,
#  'Andikira Fokithes': 1,
#  'Central Philippines': 1,
#  'Northwest Italy': 1,
#  'North & South Carolina': 1,
#  'Kumamoto Prefecture': 1,
#  'Biserta': 1,
#  'Between Southampton & Canary Islands': 1,
#  'Chungnam': 1,
#  'Eronogo Region': 1,
#  'Coquimbo': 1,
#  'Pagasitikos Gulf': 1,
#  "St. Mary's Parish": 1,
#  'Romblon Province': 1,
#  'Lamu Archipelago': 1,
#  'Los Vilos': 1,
#  'Between Honiara & Isabel Island': 1,
#  'Between DR and Puerto Rico': 1,
#  'Mindoro': 1,
#  'Saint-Louis': 1,
#  'On the Kowloon penisula, south of Sai Kung': 1,
#  'West Africa': 1,
#  'Wakaya Island': 1,
#  'Mexico / Caribbean Sea': 1,
#  'Antarctic Ocean': 1,
#  'La Saline-les-Bains': 1,
#  'Tavenui': 1,
#  "L'Etang-Salé": 1,
#  'Kowloon Peninsula': 1,
#  'Port Shelter': 1,
#  'Laucala Island': 1,
#  'Sainte-Marie': 1,
#  'Sainte-Suzanne': 1,
#  'Valpariso Province': 1,
#  'Viscayan Sea': 1,
#  'Manfredonia ': 1,
#  'Tokyo Prefecture': 1,
#  'Some area from NORTH ATLANTIC OCEAN': 1,
#  'Island of Kos': 1,
#  "Ha'api": 1,
#  'Johor': 1,
#  'Mafia Island': 1,
#  'Rombion Province': 1,
#  'Some area from TONGA': 1,
#  'Brindisi Province': 1,
#  'Kagawa Prefecture': 1,
#  'Mugla Province': 1,
#  'Gibraltar': 1,
#  'Bay of Maputo': 1,
#  'North Sumatra': 1,
#  "250 miles southwest of O'ahu, Hawaii": 1,
#  'West coast': 1,
#  'Near Bougainville (North Solomons)': 1,
#  'East of the Gulf of Aqaba': 1,
#  'San Blas': 1,
#  'Caribbean Coast': 1,
#  'Puntarenas Province': 1,
#  'Lomaloma, Lau': 1,
#  'Magdalena Department': 1,
#  'Moro Gulf': 1,
#  'Madeira Islands': 1,
#  'Clarendon': 1,
#  'Some area from SOUTH CHINA SEA': 1,
#  'Ho Ha Wan Marine Park': 1,
#  'Southern Thailand': 1,
#  'Golfo de Venezia': 1,
#  'South China Sea 200 miles from Hong Kong': 1,
#  'Reggio Calabria Province': 1,
#  'Genoa Province': 1,
#  'Ganges-Brahmaputra delta': 1,
#  'Florida ': 1,
#  'Aulong Island': 1,
#  'Some area from PACIFIC OCEAN ': 1,
#  'Antibes': 1,
#  'Illeginni Atoll': 1,
#  'Between Beira & Maputo': 1,
#  'Namonuito Atoll': 1,
#  'Western Caroline Islands (North Pacific Ocean)': 1,
#  '200 nm southeast of Manila': 1,
#  'Some area from ASIA?': 1}

# %%
df['location'][df['location'].isnull()] = 'unknown'

getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
dict(df['location'].value_counts())
# Out:
# {'unknown': 540,
#  'New Smyrna Beach, Volusia County': 163,
#  'Daytona Beach, Volusia County': 30,
#  'Ponce Inlet, Volusia County': 20,
#  'Melbourne Beach, Brevard County': 18,
#  'Myrtle Beach, Horry County': 17,
#  'Durban': 16,
#  'Boa Viagem, Recife': 14,
#  'Isle of Palms, Charleston County': 14,
#  'Ponce Inlet, New Smyrna Beach, Volusia County': 12,
#  'Cocoa Beach, Brevard County': 12,
#  'Palm Beach, Palm Beach County': 11,
#  'Ahvaz, on the Karun River': 11,
#  'Piedade': 11,
#  'Ormond Beach, Volusia County': 11,
#  'Mossel Bay': 11,
#  'Cocoa Beach, Brevard  County': 11,
#  'Sydney': 10,
#  'Singer Island, Riviera Beach, Palm Beach County': 10,
#  'Nahoon': 10,
#  'Sydney Harbor': 10,
#  'Xai Xai': 10,
#  'Brisbane River': 9,
#  'Boa Viagem Beach, Recife': 9,
#  'North Beach, Durban': 9,
#  'Near Thursday Island': 9,
#  'Florida Keys, Monroe County': 9,
#  'Juno Beach, Palm Beach County': 9,
#  'Havana Harbor': 9,
#  'Jacksonville Beach, Duval County': 9,
#  'Nahoon, East London': 9,
#  'Sanibel Island, Lee County': 8,
#  'Amanzimtoti': 8,
#  'Country Club Beach, Durban': 8,
#  'False Bay': 8,
#  'Quy Nhon ': 8,
#  'Moreton Bay': 8,
#  'Florida Keys': 8,
#  'Vero Beach, Indian River County': 8,
#  'Port Said': 8,
#  'Thursday Island': 8,
#  'Pensacola Bay, Escambia County': 7,
#  'Bunbury': 7,
#  'Charleston': 7,
#  'Ross River, Townsville': 7,
#  'Jacksonville, Duval County': 7,
#  'Port Alfred': 7,
#  'Riviera Beach, Palm Beach County': 7,
#  'Folly Beach, Charleston County': 7,
#  'Plettenberg Bay': 7,
#  'Acapulco': 6,
#  'Great Barrier Reef': 6,
#  'Coogee': 6,
#  'Jupiter, Palm Beach County': 6,
#  'Panama City, Bay County': 6,
#  'Brisbane': 6,
#  'Key West, Monroe County': 6,
#  'South Beach, Durban': 6,
#  'Bondi': 6,
#  'Wollongong': 6,
#  'Jensen Beach, Martin County': 6,
#  'Gulf Shores, Baldwin County': 6,
#  'Townsville': 6,
#  'Back Beach, Durban': 5,
#  'Oreti Beach': 5,
#  'Daytona Beach Shores, Volusia County': 5,
#  'Macassar': 5,
#  'Huntington Beach, Orange County': 5,
#  'South Padre Island': 5,
#  'East London': 5,
#  'Fort Lauderdale, Broward County': 5,
#  'Galveston': 5,
#  'La Jolla, San Diego County': 5,
#  'Kingston Harbor': 5,
#  'Playalinda Beach, Canaveral National Seashore, Brevard County': 5,
#  'Noumea': 5,
#  'Winkelspruit': 5,
#  'Emerald Isle, Carteret County': 5,
#  'Newcastle': 5,
#  'Nassau': 5,
#  'North Myrtle Beach, Horry County': 5,
#  'Arniston': 5,
#  'Port Elizabeth': 5,
#  'Margate': 5,
#  'Palm Beach': 5,
#  'Jensen Beach, Martin County ': 5,
#  'Darwin': 5,
#  'Playalinda Beach, Brevard County': 5,
#  'Albany': 5,
#  'Muizenberg': 5,
#  'Isipingo': 5,
#  'Guadalupe Island': 5,
#  'Cojimar': 5,
#  'Flagler Beach, Flagler County': 5,
#  'Wrightsville Beach, New Hanover County': 5,
#  'Ocean Reef Park, Singer Island, Palm Beach County': 5,
#  'Charleston Harbor, Charleston County': 4,
#  'Venice Beach, Los Angeles County': 4,
#  'San Onofre, San Diego County ': 4,
#  'Balian': 4,
#  'East of the Ras Tanura-Jubail area ': 4,
#  "Sullivan's Island": 4,
#  'New Smyrna Beach': 4,
#  'Atlantic City, Atlantic County': 4,
#  'Olowalu, Maui': 4,
#  'Evans Head': 4,
#  'Pawleys Island, Georgetown County': 4,
#  'Inyoni Rocks, Amanzimtoti': 4,
#  'Maui': 4,
#  'Byron Bay': 4,
#  'Geraldton': 4,
#  'Hartenbos': 4,
#  'San Onofre State Beach, San Diego County': 4,
#  'Parramatta River': 4,
#  'Lake Macquarie': 4,
#  'Santa Monica, Los Angeles County': 4,
#  'Paiva': 4,
#  'South Jetty, New Smyrna Beach, Volusia County': 4,
#  'Moonstone Beach, Humboldt County': 4,
#  'Copacabana Beach, Rio de Janiero': 4,
#  'Battery Beach, Durban': 4,
#  'Cape Vidal': 4,
#  'Rottnest Island': 4,
#  "Second Beach, Port St. John's": 4,
#  'Avon, Hatteras Island, Outer Banks, Dare County': 4,
#  'Palm Beach County': 4,
#  'Nahoon Beach, East London': 4,
#  'Cronulla': 4,
#  'Marathon, Monroe County': 4,
#  'Kei River Mouth': 4,
#  'Lennox Head': 4,
#  'Tomales Point, Marin County': 4,
#  'Scottburgh': 4,
#  'Port Phillip Bay': 4,
#  'St. Francis Bay': 4,
#  'Tahiti': 4,
#  'Tampico': 4,
#  'Indiatlantic, Brevard County': 4,
#  'Dyer Island': 4,
#  'Indialantic, Brevard County': 4,
#  'Richards Bay': 4,
#  'Dillon Beach, Marin County': 4,
#  'Avoca Beach': 4,
#  'Floridana Beach, Brevard County': 4,
#  'Hilton Head Island, Beaufort County': 4,
#  'Villa del Mar Beach, Veracruz': 4,
#  'Shatt-al-Arab River': 4,
#  'Bethune Beach, Volusia County': 4,
#  'Marineland, Sydney': 4,
#  'Ocean Isle, Brunswick County': 4,
#  "Port St. John's": 4,
#  'Stockton Beach, Newcastle': 4,
#  'Piedade Beach, Recife': 4,
#  'Piedade, Recife': 4,
#  'Streaky Bay': 4,
#  'North Topsail Beach, Onslow County': 4,
#  'Kanaha Beach, Maui': 3,
#  'Sunshine Beach': 3,
#  'Ponte Vedra Beach, St Johns County': 3,
#  'Taludig': 3,
#  'Kiawah Island, Charleston County': 3,
#  'Brighton': 3,
#  'Tiger Shores Beach, Martin County': 3,
#  'Newport Beach, Orange County': 3,
#  'Mobile Bay': 3,
#  'Boca Raton, Palm Beach County': 3,
#  'Tybee Island, Chatham County': 3,
#  'Coligny Beach, Hilton Head, Beaufort County': 3,
#  'Holden Beach. Brunswick County': 3,
#  'San Francisco Bay': 3,
#  'Hutchinson Island, St. Lucie County': 3,
#  'Holden Beach, Brunswick County': 3,
#  'Rijeka': 3,
#  'Tallow Beach, Byron Bay': 3,
#  'Grand Cay': 3,
#  'Cape Recife': 3,
#  'Long Beach, Los Angeles County': 3,
#  'Mermaid Waters': 3,
#  'New Smyrna Beach,  Volusia County': 3,
#  'Off Charleston': 3,
#  'Mocambo': 3,
#  'Boca Grande, Lee County': 3,
#  'Melkbosstrand': 3,
#  'Middleton Beach': 3,
#  'Off Lodestone Reef, Great Barrier Reef, north of Townsville': 3,
#  'Stuart Beach, Martin County': 3,
#  'Virginia Beach, Princess Anne County': 3,
#  'North Bondi': 3,
#  'Jeffreys Bay': 3,
#  'Broome': 3,
#  'Santa Barbara County': 3,
#  'Playa Grande': 3,
#  'Seal Island, False Bay': 3,
#  'Franklin Point, San Mateo County': 3,
#  'Maroubra Beach': 3,
#  'Maroubra': 3,
#  'Newcastle Beach': 3,
#  'Rewa River': 3,
#  'Galveston Island': 3,
#  "Ho'okipa Beach, Pa'ia, Maui": 3,
#  'Near Moreton Island in Moreton Bay': 3,
#  'Fort Lauderdale': 3,
#  'Lori Wilson Park, Cocoa Beach, Brevard  County': 3,
#  'Second Beach, Port St. Johns': 3,
#  'Port Edward': 3,
#  'Kau District': 3,
#  'Kihei, Maui': 3,
#  'Pensacola, Escambia County': 3,
#  'Ormond Beach / Daytona Beach, Volusia County': 3,
#  'Masonboro Island, New Hanover County': 3,
#  'Sodwana': 3,
#  'Brunswick Heads': 3,
#  "Long Island near Madang, about 500 km (310 miles) north of the South Pacific nation's capital of Port Moresby": 3,
#  'Port Melbourne': 3,
#  'Near Mabuiag Island': 3,
#  'Miami Beach, Miami-Dade County': 3,
#  'Cottesloe Beach': 3,
#  'Ponce de Leon Inlet, Volusia County ': 3,
#  'Vilano Beach, St.  Johns County': 3,
#  'Manila Bay': 3,
#  'Kauai': 3,
#  'Fremantle': 3,
#  'Green Island': 3,
#  'Mustang Island, near Port Aransas': 3,
#  'Hollywood Beach, Broward County': 3,
#  'Newcastle ': 3,
#  'Cottesloe Beach, Perth': 3,
#  'Pablo Beach, Jacksonville, Duval County': 3,
#  'Grenville': 3,
#  'Ponte Vedra, St. Johns County': 3,
#  'Jervis Bay': 3,
#  'Pigeon Point, San Mateo County': 3,
#  'Bimini': 3,
#  'Hermosa Beach, Los Angeles County': 3,
#  'Bunkers, Humboldt Bay, Eureka, Humboldt County': 3,
#  'Botany Bay, Sydney': 3,
#  'Bonza Bay': 3,
#  'Cape St. Francis': 3,
#  'Glenelg': 3,
#  'Mtunzini': 3,
#  'Habili Gafar': 3,
#  'Farallon Islands': 3,
#  'Madang': 3,
#  "St. Augustine, St. John's County": 3,
#  'Queenscliff': 3,
#  'Lizard Island': 3,
#  'Matsuyama': 3,
#  'Hawkesbury River': 3,
#  'Fernandina Beach, Nassau County': 3,
#  'Fingal Beach': 3,
#  'Pula': 3,
#  'Mogadishu': 3,
#  'Fort Mills': 3,
#  'Adelaide': 3,
#  'Millers Point': 3,
#  'Port Moresby': 3,
#  'St. Lucie County': 3,
#  'Condado Beach, San Juan': 3,
#  'Barachois': 3,
#  'Umtentweni': 3,
#  'Imperial Beach, San Diego County': 3,
#  'Manuelita': 3,
#  'Coral Bay': 3,
#  'Folly Island, near Charleston': 3,
#  'Colombo Harbor': 3,
#  'Badu Island': 3,
#  'LaMercy': 3,
#  'Sharpes Beach, Ballina': 3,
#  'San Miguel Island, Santa Barbara County': 3,
#  'Bashamir': 3,
#  'Tiger Beach': 3,
#  'Revolcadero Beach, Acapulco': 3,
#  'Coco Beach, Dar-es-Salaam': 3,
#  'Crescent Beach, St. Johns County': 3,
#  'Winchester Bay': 3,
#  'Malibu, Los Angeles County': 3,
#  'Palm Island': 3,
#  'Umkomaas': 3,
#  'Green Turtle Cay': 3,
#  'Ardrossan': 3,
#  'Gijana, 150 km inland': 3,
#  "Pearl Harbor, O'ahu": 3,
#  'Pollock Beach, Port Elizabeth': 2,
#  'Kempsey': 2,
#  'Gonubie River Mouth': 2,
#  'Port Shepstone': 2,
#  'Bridgeport, Fairfield County': 2,
#  'Pollock Beach': 2,
#  'Arlington Reef near Cairns': 2,
#  'Mavericks, Half Moon Bay, San Mateo County': 2,
#  'New Smyrna  Beach, Volusia County': 2,
#  'Cape San Blas, Gulf County': 2,
#  'Moreton Island': 2,
#  "Marciana Marina, Isola d'Elba": 2,
#  "Leftovers, near Waimea Bay, O'ahu": 2,
#  'Newcastle Harbor': 2,
#  'Mordialloc': 2,
#  'Cap de la Marianne': 2,
#  'Clearwater Beach, Pinellas County': 2,
#  'St. Lucia': 2,
#  'Lane Cove River, Sydney Harbor (Estuary)': 2,
#  'Middle Harbour, Sydney ': 2,
#  'Off Manila': 2,
#  'Davenport Landing, Santa Cruz County': 2,
#  'Weymouth': 2,
#  'Rangiroa': 2,
#  'Surf Beach, Lompoc, Santa Barbara County': 2,
#  'Struisbaai': 2,
#  'Boca Ciega Bay, Pinellas County': 2,
#  'Jensen Beach Park, Martin County': 2,
#  'Makena Landing, Maui': 2,
#  'Yeppoon, near Ross Creek': 2,
#  'Neptune Beach, Duval County': 2,
#  'Makena, Maui': 2,
#  'Mooloolaba': 2,
#  'Throsby Creek, Newcastle': 2,
#  'Silverstrand': 2,
#  'Mullaloo Beach, Perth': 2,
#  'Alexandria': 2,
#  "I'le Ouen": 2,
#  'Kidd\x92s Beach': 2,
#  'Gladstone': 2,
#  'Santa Cruz': 2,
#  'Port Royal': 2,
#  'Glengariff': 2,
#  'Carolina Beach, New Hanover County': 2,
#  'Point Conception, Santa Barbara County': 2,
#  'Melkbaai, False Bay': 2,
#  'Fort Pierce, St Lucie County': 2,
#  'Byron Bay ': 2,
#  'Kirra Beach, Coolangatta': 2,
#  'Florida Straits': 2,
#  'Folly Beach': 2,
#  "Johnstone's Bay, Sydney": 2,
#  'Honokowai, Maui': 2,
#  'Umdhloti': 2,
#  "King's Beach, Port Elizabeth": 2,
#  'St Augustine Beach, St Johns County': 2,
#  'Oamaru': 2,
#  "Ka'a'awa, Oahu": 2,
#  'South Aroo Island': 2,
#  'Rocket Hut Beach, Durban': 2,
#  'Lieu-dit Cayenne': 2,
#  'Struis Bay': 2,
#  'South of Ponce de Leon Jetty, New Smyrna Beach, Volusia County': 2,
#  'Vera Cruz Harbor': 2,
#  'Off Rottnest Island': 2,
#  'Maroubra Bay': 2,
#  'Off Bengasi': 2,
#  'San Francisco Bay (or San Leandro Bay), near cannery, Alameda County': 2,
#  'Solana Beach, San Diego County': 2,
#  'Uvongo': 2,
#  "Hilo, Hawai'i": 2,
#  'Avalon': 2,
#  'Batt Reef': 2,
#  'Bondi Beach, Sydney': 2,
#  'Danger Point': 2,
#  'Alderman Islands': 2,
#  'Bellambi Reef': 2,
#  '600 miles northwest of Honolulu': 2,
#  'Crowdy Head': 2,
#  'The Narrows': 2,
#  'North Head, Sydney Harbour': 2,
#  'Off Inhaca Island': 2,
#  'Port Kennedy Beach': 2,
#  'Praia Sepulveda': 2,
#  'Queensberry Bay': 2,
#  'Saldanha Bay': 2,
#  'New Orleans': 2,
#  'Elwood': 2,
#  'Linda Mar Beach, Pedro Point, San Mateo County': 2,
#  'Ross Creek': 2,
#  'Mustang Island, Nueces County': 2,
#  'Sea Girt, Monmouth County': 2,
#  'Crescent Head': 2,
#  'Outer Barrier Reef near Port Douglas': 2,
#  'Victoria Bay': 2,
#  'Praia do Pina': 2,
#  'Anse Lazio ': 2,
#  'Manukau Harbor, 6 miles south of Auckland': 2,
#  'Parry Island': 2,
#  'Tweed Heads': 2,
#  'Marsascala': 2,
#  'Lauderdale-by-the-Sea, Broward County': 2,
#  'Sirius Cove, Sydney Harbor': 2,
#  'Point Lonsdale': 2,
#  'East Nakanai, Talasea': 2,
#  'Iron Cove, Sydney': 2,
#  'Jupiter Inlet': 2,
#  'Crescent Beach St. Johns County': 2,
#  "Miller's Point": 2,
#  'Boucan-Canot': 2,
#  'Topsail Island, Pender County': 2,
#  'Santa Maria Island, Manatee County': 2,
#  'Gadsden Point, Tampa Bay': 2,
#  'Suva Harbor': 2,
#  'The Lizard': 2,
#  'Mona Vale': 2,
#  'Aliwal Shoal': 2,
#  'Matawan Creek, 10 miles from the sea, Monmouth County': 2,
#  'Tampa Bay, Hillsborough County': 2,
#  'St. Augustine, St Johns County': 2,
#  'Turtle Beach, Siesta Key, Sarasota County': 2,
#  'Sigatoka': 2,
#  'Warrnambool': 2,
#  'Ras Nasrani, Sharm el-Sheikh': 2,
#  'Paukukalo, Maui': 2,
#  'Coral Bay, Sharm el-Sheikh': 2,
#  'Spring Lake, Monmouth County': 2,
#  'Currumbin': 2,
#  'Barrow Point, 100 miles north of Cooktown, Queensland': 2,
#  'Keawakapu Beach, Maui': 2,
#  'Barra de Jangada': 2,
#  'Naples': 2,
#  'Sharm el-Sheikh ': 2,
#  'Monastery Beach, Carmel Bay, Monterey County': 2,
#  'Mornington Island, Gulf of Carpentaria': 2,
#  'Sheepshead Bay, Brooklyn': 2,
#  'Miami': 2,
#  'Hibberdene': 2,
#  'Garden City Beach, Horry County': 2,
#  'Lyman Beach, Kailua-Kona': 2,
#  'Seven Shillings Beach, Middle Harbor, Sydney (Estuary)': 2,
#  'French Cay': 2,
#  'Noordhoek': 2,
#  'Southeast Farallon Island, Farallon Islands': 2,
#  'Kieta': 2,
#  'Shell Island Panama City Beach, Bay County': 2,
#  'Shark Bay': 2,
#  'Palm Beach Inlet, Palm Beach County': 2,
#  'Hula': 2,
#  'Flinders Island': 2,
#  'Honiara': 2,
#  'Off North Keppel Island, off Yeppoon': 2,
#  'Ocean City (offshore)': 2,
#  'Lorok Bay': 2,
#  'Barrier Reef near Innisfail': 2,
#  'Sea Bright, Monmouth County': 2,
#  'Between Wake & Johnston Islands': 2,
#  'Gordon\x92s Bay': 2,
#  'Savanna-la-Mar': 2,
#  'Georges River': 2,
#  'Redhead Beach, Newcastle': 2,
#  'San Juan': 2,
#  'Ocracoke, Hyde County': 2,
#  'Ponce de Leon Inlet, Volusia County': 2,
#  "Between 'Ata and Tongapatu": 2,
#  'South Cape Bay': 2,
#  'Kahana Beach, Maui': 2,
#  'Sebastian Inlet, Brevard County': 2,
#  'LaJolla, San Diego County': 2,
#  'Loggerhead Park, Juno Beach, Palm Beach County': 2,
#  'Great Astrolabe Reef': 2,
#  'Strandfontein': 2,
#  'Praia da Marcela, São Marcos Bay': 2,
#  'Gay\x92s Corner, Bulimba Reach of Brisbane River': 2,
#  'Marina State Beach, Monterey County': 2,
#  'Singour, 60 miles south of Madang': 2,
#  'Merewether Beach, Newcastle': 2,
#  'Punta Del Chifre Beach, Olinda': 2,
#  'Pigeon Island': 2,
#  'Klamath River, Del Norte County': 2,
#  'North Pier, Durban': 2,
#  'Broken Head': 2,
#  'Round Island Park, Indian River County': 2,
#  'Monterey Bay, Monterey County': 2,
#  'Sharp Peak, Sai Kung Peninsula, New Territories': 2,
#  'Safaga': 2,
#  'North Jetty, Fort Pierce Inlet State Park, St. Lucie County': 2,
#  'Geelong': 2,
#  'Fish Hoek': 2,
#  'Santa Rosa, Cozumel': 2,
#  'Krk Island': 2,
#  'Elliot Key': 2,
#  'Ponta do Ouro': 2,
#  'Municipal Beach, West Palm Beach, Palm Beach County': 2,
#  'Sargent Beach, Matagorda County': 2,
#  'North Beach, St. Lucie County': 2,
#  'Santa Barbara Channel': 2,
#  'Lanai': 2,
#  'Greenmount Beach': 2,
#  'Surf City, Topsail Island, Pender County': 2,
#  'Norfolk': 2,
#  'Cottesloe, Perth': 2,
#  'Kilindini': 2,
#  'Lighthouse Beach': 2,
#  'Bethune Beach, south of New Smyrna Beach, Volusia County': 2,
#  'City Beach, Perth': 2,
#  'Near Key West': 2,
#  'Savona': 2,
#  'English Bay': 2,
#  'Blue Planet Aquarium, Ellesmere Port': 2,
#  'Long Island': 2,
#  'Carlisle Bay': 2,
#  'Stretto di Messina': 2,
#  'Outer Harbor': 2,
#  'Floreat Beach': 2,
#  'Santa Cruz, Santa Cruz County': 2,
#  'Haulover Beach, Miami-Dade County': 2,
#  'Algoa Bay': 2,
#  'Island Rock': 2,
#  'Pepper Park Beach, St. Lucie County': 2,
#  'Seabrook Beach': 2,
#  'Ballito': 2,
#  'Glencairn, False Bay': 2,
#  'San Diego, San Diego County': 2,
#  'Swan River': 2,
#  'Salt Rock ': 2,
#  'Midway Island, Northwestern Hawaiian Islands': 2,
#  'Kilindini Harbor, Mombasa': 2,
#  'Paradise Reef': 2,
#  'Brooker Island , Calvados Chain': 2,
#  'South Padre Island, Cameron County': 2,
#  'Perth? (Margaret River District)': 2,
#  'Emerald Isle Pier (near Morehead City), Carteret County': 2,
#  'Hanna Park, Jacksonville, Duval County': 2,
#  'Parramata River': 2,
#  'Umhlanga Rocks': 2,
#  'King\x92s Beach': 2,
#  'Boynton Beach, Palm Beach County': 2,
#  'Piedade Beach': 2,
#  'Gracetown': 2,
#  'Cabo Frio': 2,
#  'Salmon Creek, Sonoma County': 2,
#  'Rio de Janeiro, Guanabara Bay': 2,
#  'Brooklyn': 2,
#  'Oak Island, Brunswick County': 2,
#  'Daytona Beach Shores': 2,
#  'Rockaway': 2,
#  "Off Makapauu Point, O'ahu": 2,
#  'St. Helena Island, Beaufort County': 2,
#  'Pancake Creek': 2,
#  'near Ahvaz, 275 km from the sea': 2,
#  'Esperance': 2,
#  'Port Jackson': 2,
#  'Rodanthe, Dare County': 2,
#  '30 nautical miles offshore': 2,
#  'Stinson Beach, Marin County': 2,
#  'Ocean City, Cape May County': 2,
#  'New Smyrna Beach / Waveland, Volusia County': 2,
#  "Jeffrey's Bay": 2,
#  'South of Ponce Inlet, New Smyrna Beach, Volusia County': 2,
#  'Guadalcanal': 2,
#  "Miller's Point, False Bay": 2,
#  "Surfer's Paradise": 2,
#  'Staten Island, Richmond County': 2,
#  'Butliwan Village, 15 miles north of Rabaul': 2,
#  'Tombo Island in the Sierra Leone River': 2,
#  'Delray Beach, Palm Beach County': 2,
#  'Pelican Beach Park, Satellite Beach, Brevard County': 2,
#  'Destin, Okaloosa County': 2,
#  'Off Royal Residence': 2,
#  'Atlantic Beach, Emerald Isle, Carteret County': 2,
#  'Fort Pierce Inlet, St Lucie County': 2,
#  'Port Wakefield': 2,
#  'Freetown': 2,
#  'Morehead, Carteret County': 2,
#  'Shatt-al Arab River': 2,
#  'Ceduna': 2,
#  'Trinity Beach, Cairns': 2,
#  'Off Stradbroke Island': 2,
#  'Boucan Canot': 2,
#  '2 km from Macassar, False Bay': 2,
#  'Koumac': 2,
#  'Tamsui Beach': 2,
#  'Manus Island': 2,
#  'Whitehaven': 2,
#  'Lighthouse Beach, Ballina': 2,
#  'Vera Cruz': 2,
#  'Lennox Head, Ballina': 2,
#  'Merimbula': 2,
#  'Absecon, Atlantic County': 2,
#  'Rewa ': 2,
#  'Clifton': 2,
#  'Kingscliffe Beach, south of Tweed Heads': 2,
#  'East Ballina': 2,
#  'St. Petersburg, Pinellas County': 2,
#  'Mpande': 2,
#  'Brickfield Bay, Auckland Harbour': 2,
#  'Bondi Beach': 2,
#  'Matanzas': 2,
#  'Karridene': 2,
#  "Knobby's Beach, Newcastle": 2,
#  'Maria River, Port Macquarie, 12 miles from river mouth': 2,
#  "Kahala, O'ahu": 2,
#  'Flinders, Mornington Penisula': 2,
#  'Heron Island': 2,
#  'Enewetak Atoll': 2,
#  'Ponte Vedra Beach, St. Johns County': 2,
#  'Antibes': 2,
#  'Hanalei Bay, Kauai': 2,
#  '68 miles east of Wallis Island': 2,
#  'South West Rocks': 2,
#  'Koror': 2,
#  'Playa Mocambo': 2,
#  'Off Algeciras': 2,
#  'Puna': 2,
#  'Southport': 2,
#  'Makemo Atoll': 2,
#  'Daytona Beach, Volusia County ': 2,
#  'Currumbin Rock': 2,
#  'Wailea Beach, Maui': 2,
#  'Scarborough': 2,
#  'Darwin Harbour': 2,
#  'Clarence Heads': 2,
#  'Hamelin Bay': 2,
#  'Triabunna': 2,
#  'Durban Harbor': 2,
#  'Freeport': 2,
#  'Fiume': 2,
#  ' Chennai (formerly Madras)': 2,
#  'Tuticorin': 2,
#  'Mona Vale, near Sydney': 2,
#  'Seven Mile Beach, Gerroa': 2,
#  'St. Clair Beach, Dunedin': 2,
#  'Tongaat': 2,
#  'Madras': 2,
#  'Middleton Point, Fleurieu Peninsula': 2,
#  'Port Phillip': 2,
#  'Candeias': 2,
#  'Paia Bay, Maui': 2,
#  'Fish Hoek, False Bay': 2,
#  'Ensenada': 2,
#  'Carter Cay': 2,
#  'Bodega Rock, Sonoma County': 2,
#  'Stono Inlet, near Charleston, Charleston County': 2,
#  'Trieste': 2,
#  'South of Ponce Inlet, Volusia County': 2,
#  'Kowie River Mouth, Port Alfred': 2,
#  'Atlantic Beach, Duval County': 2,
#  'Jekyll Island, Glynn County': 2,
#  'Shrewsbury River, Highlands, Monmouth County': 2,
#  'Sandy Hook Bay, Highlands, Monmouth County': 2,
#  'Gonubie': 2,
#  'Clarence River': 2,
#  'St. George\x92s Strand': 2,
#  'Port Royal Harbour': 2,
#  'Bronte Beach': 2,
#  "Barber\x92s Point, O'ahu": 2,
#  'Manly': 2,
#  'Shatt-al-Arab River near Abu al Khasib': 2,
#  'Lika-Senj, Pag Island': 2,
#  'Sarasota County': 2,
#  'Amherst': 2,
#  'Hobe Sound, Martin County': 2,
#  'Mustang Island, Corpus Christi': 2,
#  'Shelly Beach, near Port Macquarie': 2,
#  'Durban ': 2,
#  'Ellis Beach, 20 miles from Cairns': 2,
#  'Sai Noi Beach': 2,
#  'Off Tripoli': 2,
#  'Stewart Island': 2,
#  'Volusia County': 2,
#  'Mission Beach, San Diego County': 2,
#  'South Point, Gracetown': 2,
#  'Robberg Beach, Plettenberg Bay': 2,
#  'Cape Point': 2,
#  "Kealia Beach, Kaua'i": 2,
#  'Yorkey\x92s Knob Beach near Cairns': 2,
#  'Bermagui': 2,
#  'Delray Beach': 2,
#  'Boqueron': 2,
#  'Middle Bight': 2,
#  'Patrick Air Force Base, Brevard County': 2,
#  'Off Masonboro Island, New Hanover County': 2,
#  'Walkers Cay': 2,
#  'Jeffrey\x92s Bay': 2,
#  'Pismo Beach, San Luis Obispo County': 2,
#  'Hobe Sound, Palm Beach County': 2,
#  'Brazos': 2,
#  "White Plains Beach, Barbers Point, O'ahu": 2,
#  'Bar Beach, Newcastle': 2,
#  'the pearling beds': 2,
#  'Pina, Recife': 2,
#  'Tararu, Thames': 2,
#  'Darling Harbor, Sydney': 2,
#  'Magnetic Island': 2,
#  'Maryborough': 2,
#  'Inyoni Rocks, South Coast': 2,
#  'Wategos Beach, Byon Bay': 2,
#  'Santa Catalina Island, Los Angeles County': 2,
#  'Cape Canaveral, Brevard County': 2,
#  'White Plains Beach, Oahu': 2,
#  'Mereweather Beach': 2,
#  'Cape Jervis': 2,
#  'Shelly Beach': 2,
#  'Ravine Mula': 2,
#  'Julian Rocks, Byron Bay': 2,
#  "Maile Beach, O'ahu": 2,
#  'Fripp Island, Beaufort County': 2,
#  'Island J4H': 2,
#  'Yellow Sands Point': 2,
#  'Sydney Harbour': 2,
#  'Trigg Beach': 2,
#  'Hesamabad area of Shushtar, 420 km from the sea': 2,
#  'Gansbaai': 2,
#  'North Brighton, Botany Bay': 2,
#  'Kahului, Maui': 2,
#  'South Jetty, Port Elizabeth': 2,
#  "Moloka'i": 2,
#  'Goulburn Island': 1,
#  'Port Kilindeni / Mombasa Harbor': 1,
#  'Dodnduwa': 1,
#  "Waikiki, O'ahu": 1,
#  'Port Hughes, 100 miles from Adelaide in Spencer Gulf': 1,
#  'Burleigh Heads, Brisbane': 1,
#  'Monrovia': 1,
#  'Maritzoan, east coast of Namatanai': 1,
#  'Thursday Island Harbour, Queensland': 1,
#  'Elba Island': 1,
#  '300 yards west of mouth of the Chagres River': 1,
#  'Cape Levêque': 1,
#  'North of Walkers Cay': 1,
#  'Yeppoon': 1,
#  'Splash Rock, Port Edward': 1,
#  'Palm Beach North, 5 miles north of Burleigh Heads, Brisbane': 1,
#  'Mo\x9a?eni?ka Draga': 1,
#  'Off bank of Ntshala River, Morgan Bay': 1,
#  '5 miles south of Sussex Inlet at mouth of Berara Lake': 1,
#  'Water Island': 1,
#  'Native Beach, Durban': 1,
#  'Staten Island': 1,
#  'MaKakatana River': 1,
#  'On rock near Yacht Club': 1,
#  'Manam Island': 1,
#  'Mito': 1,
#  'South Werribee Beach': 1,
#  'Heda Oya Estuary': 1,
#  'Cosenza': 1,
#  'South Beach, Fort Pierce, St Lucie County': 1,
#  'Kirra': 1,
#  "Cooper's Point": 1,
#  'Off Port Elizabeth breakwater': 1,
#  'Longboat Key, Sarasota, Sarasota County': 1,
#  'Atascadero Beach, Morro Bay, San Luis Obispo County': 1,
#  'Off Scotts': 1,
#  'Voh, near meatworks': 1,
#  'Caleta Beach, Acapulco': 1,
#  'Galveston Bay': 1,
#  'Between  Cuba  & Costa Rica': 1,
#  'Rock Harbor, Key Largo, Monroe County': 1,
#  'Near Lautoka': 1,
#  'Mangalia Reef above Touho ': 1,
#  'Hunga Island': 1,
#  'Salter Path, Atlantic Beach, Carteret County': 1,
#  '275 miles northeast of Miami': 1,
#  'Key Biscayne': 1,
#  'North of Northeast Samoa': 1,
#  'Bulu, Talasea': 1,
#  'Beach 103rd Street, Rockaway ': 1,
#  "Sprizze, Isola d'Elba": 1,
#  'Piraeus, Athens': 1,
#  'Kombe, Talasea': 1,
#  'Nasigilatu (Near Malasanga, Finschhafen, in the Huon Gulf)': 1,
#  'Near Port Arthur': 1,
#  'Scotburgh': 1,
#  'Albenga': 1,
#  'Kahakuloa, Maui': 1,
#  'Off Cape of Pi-tou': 1,
#  '9 miles north of Turtle Beach, Siesta Key, Sarasota County': 1,
#  "Peterson's Beach, Sarina": 1,
#  'Kurnell, Botany Bay ': 1,
#  '1 mile off Miami Beach': 1,
#  'Sarasota, Sarasota County': 1,
#  '8 miles off St. Marks, Wakulla County': 1,
#  '50 miles off Port La Libertad': 1,
#  'Miami Seaquarium, Virginia Key, Miami, Miami-Dade County': 1,
#  'Tea Gardens, north of Newcastle': 1,
#  'King Reef off Park Rynie': 1,
#  'Korem, Finschhafen ': 1,
#  'Seaholme': 1,
#  'Ariakeno Bay': 1,
#  'Siesta Key, Sarasota County': 1,
#  'Port Louis': 1,
#  'Umgeni River Mouth': 1,
#  'Kimuta, Renard Island': 1,
#  "Waiau, Pearl Harbor, O'ahu": 1,
#  'Rockaway Beach': 1,
#  '200 miles east of Savannah': 1,
#  'Bohol': 1,
#  'Boat Harbour, north of Cronulla': 1,
#  'Pago Pago Bay': 1,
#  'A village a short distance from Hesamabad': 1,
#  'Windy Hill Beach': 1,
#  'Port Augusta': 1,
#  'Usimado-no-Seto': 1,
#  'Occupasstuxet  (Patuxent) Cove': 1,
#  'Budva': 1,
#  'Volupai, Talasea': 1,
#  'Telegraph Bay': 1,
#  'Miramar Beach, 46 km south of Mar de Plata, Buenos Aires ': 1,
#  'Manzanillo': 1,
#  'Fourchu, Cape Breton Island': 1,
#  'Opatija': 1,
#  '½ mile offshore & 9 miles north of Fort Pierce': 1,
#  'Off Rossel Island, Louisiade Archipelago': 1,
#  'Between Straits of Malacca and Sri Lanka': 1,
#  'Enuk Island ': 1,
#  'Schnapper Rock, Kirton Point': 1,
#  'Long Reef, Collaroy': 1,
#  '1.5 miles off shore': 1,
#  'Kalautu Village, Baibara at the mouth of Oibada River': 1,
#  'Zuma Beach, Santa Monica, Los Angeles County': 1,
#  'Low Island, Manus': 1,
#  'Tully, North Queensland': 1,
#  '60 miles offshore ': 1,
#  "East Moloka'i": 1,
#  'Kaula Rock near Niihau ': 1,
#  'Mikura-jima Island, 150 miles south of Tokyo': 1,
#  'Naghir Island': 1,
#  'The Entrance, near Gosford': 1,
#  'Southern part ': 1,
#  'Chicago (Lake Michigan)': 1,
#  'Coff\x92s Harbor': 1,
#  'Finale Ligure': 1,
#  'Darnley Island, Torres Strait': 1,
#  'Wyargine Point, Edwards Beach, Balmoral Beach, Sydney': 1,
#  'off yacht Serenade': 1,
#  'A ford known as Brodies Coffin in St. Lucia Bay': 1,
#  'Southwest of Cartegena': 1,
#  'Vanagiri, Madras (Chennai), Bay of Bengal': 1,
#  'Lavongai': 1,
#  'Oomura Bay': 1,
#  'Near tuna cannery in Pago Pago Harbor': 1,
#  'Kila Beach, Port Moresby': 1,
#  'Off Fleetwood': 1,
#  '150 miles off Cape Henry': 1,
#  'Singapore Harbor': 1,
#  'Sugarloaf Bay, Middle Harbor, Sydney': 1,
#  'Lou Island, south of Manus Island': 1,
#  'Kalamata': 1,
#  'Hadrian\x92s (Haidana?) Island, near Port Moresby': 1,
#  "Wailupe, O'ahu": 1,
#  'Abau': 1,
#  'Near Madang Town': 1,
#  'Wewak': 1,
#  'Fitzroy Island': 1,
#  'Elbow Beach': 1,
#  'Pacific Grove, Monterey County': 1,
#  'Wamberal': 1,
#  'Kabiman, West coast': 1,
#  'Woodman\x92s Point': 1,
#  'Between Punta Grossa & Koper': 1,
#  'Off Chioggia': 1,
#  'Trinidad Bay, Humboldt County': 1,
#  'Hus Island ': 1,
#  'Kérkira': 1,
#  'Windang, near the entrance to Lake Illawarra': 1,
#  'Cave at Shell Harbour': 1,
#  'Salerno': 1,
#  'North Auckland': 1,
#  'Kapakapa ': 1,
#  'Amalfi': 1,
#  'Isle de Gorée': 1,
#  '400 miles off the le': 1,
#  '1.5 miles south of  San Felice Circeo ': 1,
#  'Paga Point or Fishermans Island, Port Moresby': 1,
#  'Ocean baths, Kissing Point Beach ': 1,
#  'Beira': 1,
#  'Catembe ': 1,
#  'Samo Plantation, east coast ': 1,
#  'Momote, Manus Island': 1,
#  'West Breakwater, Monrovia / Freeport': 1,
#  'Paga Point, Port Moresby ': 1,
#  'Fitzroy River near Rockhampton': 1,
#  'Owendo': 1,
#  'Samarai Island': 1,
#  'Miami, Miami-Dade County': 1,
#  'Port St. Johns': 1,
#  'Fort Pierce, St. Lucie County': 1,
#  'Torre del Greco, Naples': 1,
#  'Havana': 1,
#  'Outer edge of Hikueru, one of the Central Tuamotu atolls': 1,
#  "Kapehu Beach, Laupahoehoe, Hawai'i": 1,
#  'In Los Angeles \x96 Honolulu yacht race': 1,
#  'Samarai Island (south end)': 1,
#  'near Band Misan in Shustar, 420 km from the sea': 1,
#  'Mailu area  ': 1,
#  'Cartegena': 1,
#  'Hesamabad': 1,
#  'Torre Colimena': 1,
#  'Duke of York Island': 1,
#  'North coast': 1,
#  'Near Southport': 1,
#  'Wilkes Islet Lagoon (Pacific Ocean north of the Marshall Islands)': 1,
#  'Cowes': 1,
#  'Cronulla, near Sydney': 1,
#  'Portsea Beach, near entrance to Port Phillip Bay': 1,
#  'Pacific Grove, Monterey Bay, Monterey County': 1,
#  'Pioneer River near Mackay': 1,
#  "Between Ala Moana Channel & Kewalo Basin, O'ahu": 1,
#  'Riva Trigoso': 1,
#  'San Juan River': 1,
#  'Nelson\x92s Rock': 1,
#  'Cape Douglas': 1,
#  'Portsea Beach, near Melbourne': 1,
#  'Kahuli, Buka Island': 1,
#  'Wynyard': 1,
#  'Largs Bay': 1,
#  'Geyser Bank': 1,
#  'Lalaura Village': 1,
#  'Genova, S. Nazaro, Punta Vagno': 1,
#  'Chain Rocks, Amanzimtoti': 1,
#  'Aquadilla': 1,
#  'Suakin Harbor, Suakin Island': 1,
#  'Off Trivandrum (west coast)': 1,
#  'between Filfla Island and Wied iz-Zurrieq': 1,
#  'Yule Island': 1,
#  "Fisherman's Island, near Port Moresby": 1,
#  'Boyup Brook': 1,
#  'Van Ness Municipal Pier, San Francisco': 1,
#  'Venezuelan aircraft lost': 1,
#  'Mona Island, 40 miles west of the mainland ': 1,
#  'Off Santa Monica, Los Angeles County': 1,
#  'Panacea, Wakulla County': 1,
#  'Giulianova': 1,
#  "Fishman's Island (near Port Moresby, PNG) ": 1,
#  'Off Funchal': 1,
#  'Junk Bay': 1,
#  'Oceanside, San Diego County': 1,
#  "Baker's Haulover, Miami Beach": 1,
#  'East of Station Pier, Port Melbourne': 1,
#  '30 miles from Port Moresby': 1,
#  'Bel Air, Dakar': 1,
#  'Savuli Reef': 1,
#  'Nailou Village, Tunuloa Natewa Bay': 1,
#  'Palliser Bay, Whatarangi (east of Wellington)': 1,
#  'West of Pukerua Bay, Wellington': 1,
#  'Hokio Beach, near Levin': 1,
#  'Ngatuka Bay, near Picton': 1,
#  'Puntarenas': 1,
#  '70 miles from Suva': 1,
#  '20 m from shore at Strand': 1,
#  'Southeast Farallon Island': 1,
#  'Tuvuca Isalnd': 1,
#  'Metro coast': 1,
#  'White Island': 1,
#  'Catfish Rock, between Salt Rock & Shaka\x92s Rock': 1,
#  'Figtree Ledge, Hervey Bay': 1,
#  'Next to West Street groyne, Durban': 1,
#  'Woolgoolga, Coffs Harbour': 1,
#  'Umvoti': 1,
#  '55 miles south of Adelaide': 1,
#  'Pomio': 1,
#  'Charteris Bay, Lyttleton Harbour': 1,
#  'Kukipi, 150 miles west of Port Moresby in the Lakekamu River area': 1,
#  'Dravuwalu, Totoya Island': 1,
#  'Surfers Paradise Beach near Victor Harbour': 1,
#  'Inshore side of reef near Madang': 1,
#  'Achutupu, a small island ner Ailigandi': 1,
#  'Near US Air Force Base at Elgin, Okaloosa County': 1,
#  'Port Lavaca, Calhoun County': 1,
#  'Dana Point, San Clemente, Orange County': 1,
#  'Between Palm  & Salerno Inlets, Martin County': 1,
#  'South of Hurghada': 1,
#  "Island of Paam'a": 1,
#  'Buka Island': 1,
#  'Port Jervis': 1,
#  'Off Sing Village, Buka Island': 1,
#  'Lady Julia Percy Island': 1,
#  'Fingal Beach, near Tweed Heads': 1,
#  'North Solitary Island, 8 miles from Wolli': 1,
#  'Avalon Beach, near Mandurah, 50 miles south of Perth': 1,
#  'Naviti': 1,
#  'Tamsui Beach, Taipai': 1,
#  '5 miles south of Palm Beach': 1,
#  '2 miles off Jupiter, Palm Beach County': 1,
#  'Saidaiji': 1,
#  'Off Achutuppu Island near Ailigandi': 1,
#  "3 days out of Old Saybrook, Connecticut, 37.04'N, 67.57'W, Southern fringe of Gulf Stream": 1,
#  'A reef off New Hanover (Northern end)': 1,
#  'Southern end': 1,
#  '2 miles south of Castle Island Harbour entrance to Hamilton': 1,
#  'Near Rabaul': 1,
#  'Tovu, Totoya Island': 1,
#  'Off Mondello Lighthouse': 1,
#  'Mermaid Beach': 1,
#  '8 miles south of Elliot Key, Miami-Dade County': 1,
#  'Circeo, Secca del Quadro': 1,
#  'Limpopo River, 547 km from the sea': 1,
#  'Korolevu (South coast between Nadi & Suva)': 1,
#  'Shark tank at Oceanographic Research Institute': 1,
#  'Carrickalinga Head': 1,
#  'Swartklip': 1,
#  'Off Kisma': 1,
#  'Off Bermuda': 1,
#  'Sisi  (west coast of island)': 1,
#  '2 miles off Santa Catalina Island': 1,
#  'Long Cay': 1,
#  'Off the passenger liner Stirling Castle': 1,
#  '2 km north of Apollonia': 1,
#  'Selection Reef, Umdhloti': 1,
#  'Ucagiz': 1,
#  'Kufulu Point': 1,
#  '6 miles north of Palm Beach': 1,
#  'Robbesteen': 1,
#  'Off Andy Bowie Park, Padre Island, near Port Isabel': 1,
#  'Manasquan, Ocean County': 1,
#  'Pekinberui Village, Tabar Island': 1,
#  'Circeo, Secca del Faro': 1,
#  ...}

# %%
df['activity'].fillna('Unknown activity near water', inplace = True)
    
getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
dict(df['activity'].value_counts())
# Out:
# {'Surfing': 971,
#  'Swimming': 869,
#  'Unknown activity near water': 544,
#  'Fishing': 431,
#  'Spearfishing': 333,
#  'Bathing': 162,
#  'Wading': 149,
#  'Diving': 127,
#  'Standing': 99,
#  'Snorkeling': 89,
#  'Scuba diving': 76,
#  'Body boarding': 61,
#  'Body surfing': 49,
#  'Swimming ': 47,
#  'Kayaking': 33,
#  'Treading water': 32,
#  'Pearl diving': 32,
#  'Fell overboard': 32,
#  'Boogie boarding': 29,
#  'Free diving': 29,
#  'Windsurfing': 19,
#  'Walking': 17,
#  'Boogie Boarding': 16,
#  'Shark fishing': 15,
#  'Floating': 14,
#  'Fishing ': 13,
#  'Canoeing': 13,
#  'Surf skiing': 12,
#  'Surf-skiing': 12,
#  'Surf fishing': 12,
#  'Rowing': 12,
#  'Kayak Fishing': 11,
#  'Fishing for sharks': 11,
#  'Freediving': 10,
#  'Sponge diving': 10,
#  'Scuba Diving': 10,
#  'Fell into the water': 9,
#  'Sitting on surfboard': 9,
#  'Diving for trochus': 9,
#  'Sailing': 9,
#  'Paddle boarding': 8,
#  'Sea disaster': 8,
#  'Playing': 7,
#  'Floating on his back': 7,
#  'Boating': 7,
#  'Diving for abalone': 7,
#  'Skindiving': 7,
#  'Free diving for abalone': 7,
#  'Surf skiing ': 7,
#  'Spearfishing ': 7,
#  'Surfing (sitting on his board)': 7,
#  'Sea Disaster': 6,
#  'Shipwreck': 6,
#  'Fishing for mackerel': 6,
#  'Murder': 6,
#  'Stand-Up Paddleboarding': 6,
#  'Spearfishing on Scuba': 6,
#  'Kite Surfing': 6,
#  'Hard hat diving': 5,
#  'Freedom swimming': 5,
#  'Paddleskiing': 5,
#  'Surfing ': 5,
#  'Kayaking / Fishing': 5,
#  'Dangling feet in the water': 5,
#  'Boat': 5,
#  'Fishing on a boat': 5,
#  'Kite surfing': 5,
#  'Scuba diving (but on surface)': 4,
#  'Jumping': 4,
#  'Jumped into the water': 4,
#  'Splashing': 4,
#  'Freedom Swimming': 4,
#  'Wade Fishing': 4,
#  'Lifesaving drill': 4,
#  'Feeding sharks': 4,
#  'Spearfishing / free diving': 4,
#  'Seine netting': 4,
#  'Scuba diving (submerged)': 4,
#  'Body-boarding': 4,
#  'Skin diving': 4,
#  'Diving for coins': 4,
#  'Tagging sharks': 4,
#  'Paddling on surfboard': 4,
#  'Boat swamped': 4,
#  'Fishing boat': 4,
#  'Clamming': 4,
#  'Spearfishing (free diving)': 3,
#  'Sitting on gunwale of boat': 3,
#  'Jumped overboard ': 3,
#  'Unknown': 3,
#  'Knocked overboard': 3,
#  'Wade fishing': 3,
#  'Standing in knee-deep water': 3,
#  'SCUBA diving': 3,
#  'Crayfishing': 3,
#  'Shell diving': 3,
#  'Fishing for bluefish': 3,
#  'Surfing, paddling seawards': 3,
#  'Swimming after his hat': 3,
#  'boat capsized': 3,
#  'Spearing fish': 3,
#  'Escaping from Alacatraz': 3,
#  'Crabbing': 3,
#  'Diving for sponges': 3,
#  'Bathing ': 3,
#  'Suicide': 3,
#  'Floating on a raft': 3,
#  'Competing in the Woodvale Atlantic Rowing Race': 3,
#  'Wreck of the schooner Pohoiki ': 3,
#  'Jumped overboard': 3,
#  'Free diving & spearfishing': 3,
#  'Fishing for kob': 3,
#  'Fishing for snapper': 3,
#  'Spearfishing / Scuba diving (at surface)': 3,
#  'Sculling': 3,
#  'Walking out of the water after surfing': 3,
#  'Wade-fishing': 3,
#  '.': 3,
#  'Playing in the surf': 3,
#  'Paddling': 3,
#  'Hookah diving for abalone': 3,
#  'Scuba diving for abalone': 3,
#  'Feeding fish': 3,
#  'Fishing for squid': 3,
#  'Body Boarding': 3,
#  'Shark watching': 3,
#  'Their 9 m launch was run down by a 25,000-ton Japanese freighter  on the night of 3-11-1977 & they drifted, clinging to an icebox for 2 days': 3,
#  'Diving ': 3,
#  'Kayak fishing': 3,
#  'SUP': 3,
#  'Sitting in the water': 2,
#  'Body surfing / treading water': 2,
#  'Fishing for prawns': 2,
#  'Splashing ': 2,
#  'Shark tagging': 2,
#  'Beach seine netting': 2,
#  'Boat with 5 men capsized while returning to the Amerique': 2,
#  'Standing / Surfing': 2,
#  'Sitting in shallows': 2,
#  'Shark diving': 2,
#  'Kayaking ': 2,
#  'Kite boarding': 2,
#  'Hookah diving for sea urchins': 2,
#  'Swimming ashore from capsized boat': 2,
#  'Free diving, Spearfishing': 2,
#  'Surfing, collided with shark': 2,
#  'Standing in waist-deep water': 2,
#  'Launching rowboat through the surf': 2,
#  'Free-diving': 2,
#  'Fishing (Seining)': 2,
#  'Dived for a coin': 2,
#  'Washing': 2,
#  'Bathing in river': 2,
#  'Attempting to kill a shark with explosives': 2,
#  'Fishing from surf ski': 2,
#  'Teasing a shark': 2,
#  'Diving for beche-de-mer': 2,
#  'Spearfishing using Scuba': 2,
#  'Cage Diving': 2,
#  'Swimming alongside NOAA research vessel Discoverer': 2,
#  'Swimming / Wading': 2,
#  'Swimming from the New Venture ': 2,
#  'Netting shrimp': 2,
#  'Diving for trochus shell': 2,
#  'Boat capsized, swimming ashore': 2,
#  'Diving from canoe': 2,
#  'Five men on makeshift raft after their 10 m fishing boat  capsized and sank in rough seas. Survivors rescued after  7.5 hours in the water': 2,
#  'Fishing for lobsters': 2,
#  'Playing in the water': 2,
#  'HMAS Parramatta torpedoed & sunk by the U-559': 2,
#  'Swimming / escaping imprisonment ': 2,
#  'Air disaster': 2,
#  'Transatlantic Rowing': 2,
#  'Fishing for whiting': 2,
#  'Diving for beche-de-mer ': 2,
#  'Diving for lobsters': 2,
#  'Finning the shark that bit him': 2,
#  'Swimming or surfing': 2,
#  'Aircraft crashed into sea': 2,
#  'Swimming, ducking for shells in water 0.9 m deep': 2,
#  'Cleaning fish': 2,
#  'Floating in inner tube': 2,
#  'Diving for crayfish': 2,
#  'Collecting shells': 2,
#  'Spearfishing Competition': 2,
#  'Rowing ': 2,
#  'Kite Boarding': 2,
#  'Jet skiing': 2,
#  'Free diving / Spearfishing': 2,
#  'The Christie V sank on 11/6/1988, survivors were adrift on a dinghy': 2,
#  'Swimming / snorkeling': 2,
#  'U.S. Airforce C124 enroute from Hickham Air Base to Japan went down. The 3 survivors fashioned raft from mailbags  & were rescued 3 days after the crash.': 2,
#  '"Flying Tiger" transport plane went down with 5 men onboard': 2,
#  'Spearfishing / Scuba diving': 2,
#  'Diving around anchored liner': 2,
#  'Shooting sharks ': 2,
#  'fishing boat exploded & sank': 2,
#  'Free diving / spearfishing': 2,
#  'Surfing (lying prone on his board)': 2,
#  'Cruising': 2,
#  'Standing ': 2,
#  'Fishing for tuna': 2,
#  'Diving?': 2,
#  'S2N Navy scout plane went down, E.H. Almond & Lieut A.G. Reading in water': 2,
#  'Thrown overboard': 2,
#  'Fishing for cod': 2,
#  'Spearfishing / Free diving': 2,
#  'Floating on back': 2,
#  'Kitesurfing': 2,
#  'Air Disaster': 2,
#  'Scuba diving & spearfishing': 2,
#  'Diving off jetty': 2,
#  'Swimming near jetty': 2,
#  'Washing his feet': 2,
#  'Hoisting shark aboard fishing boat': 2,
#  'Kiteboarding': 2,
#  'Ocean racing': 2,
#  'Diving into water': 2,
#  'boat capsized during filming': 1,
#  'Sailing from Gingood, Misamis Oriental to Sagay (normally a 2-day voyage) capsized with 6 on board, three men were taken by sharks when they attempted to swim to shore.': 1,
#  "Sitting in 3' of water": 1,
#  "Fishing, caught a 15' shark & took it onboard": 1,
#  'Free diving for trochus ': 1,
#  'Ditched aircraft, 3 men in the water. Swam for 31 hours': 1,
#  'The 6015-ton British ship Empire Avocet was torpedoed by the German submarine U-125. ': 1,
#  'Fishing for perch': 1,
#  'The troopship Britannia was sunk by the German raider Thor': 1,
#  'Swimming along side N.E.L. vessel Saluda': 1,
#  'Esso Bolivar was torpedoed & shelled by the German submarine U-126': 1,
#  'His ship, the US destroyer Duncan DD 485, had been  sunk by crossfire from Japanese warships. He was wearing a kapok lifejacket & using 2 aluminum powder tins for floatation  ': 1,
#  'Swimming on sandbar adjacent to channel': 1,
#  'Plane crashed in water, men in life raft': 1,
#  'Dutch merchant ship Zaandam torpedoed  by the U-174 amidships, sank & dozens of survivors took to rafts & boats. One man, Izzi, who drifted 83 days on a raft related that sharks attacked many men in the water when the ship went down': 1,
#  'Hurricane & Tidal Wave': 1,
#  'Swimming to shore from capsized sailboat': 1,
#  'Standing on his hands': 1,
#  "Fishing from 32' boat": 1,
#  'The Pacquebot Laconia, enroute to Liverpool with 600 Italian prisoners onboard, was torpedoed by the German submarine  U-156 and only 2 rafts were launched before the ship went down. Unable to board an overcrowded raft, he was swimming.': 1,
#  "Captured Allied soldiers were squeezed into 3' bamboo pig baskets & fed to waiting sharks": 1,
#  'British cruiser Dunedin torpedoed & sunk by the U-124': 1,
#  'H.M.S. Cornwall & H.M.S.Dorsetshire sunk by Japanese dive bombers. Officers & men in the water formed a circle with 60 of their dead in the center for 36 hours': 1,
#  "Diving for trochus  from dinghy when seized by shark 6' below the surface": 1,
#  'Yacht of Michael Howell capsized': 1,
#  'Ditched plane in the sea & were adrift on a rubber life raft. ': 1,
#  "Days before the surrender of Singapore, the 3 men escaped to Sumatra where they acquired a 17' dinghy. After 125 days at sea they drifted back to Sumatra": 1,
#  'Torpedoed & burning British  light cruiser with a crew of 450 men': 1,
#  'The SS Potlach was torpedoed & sunk by the U-153 on 27-Jun-1942. ': 1,
#  'German raider Kormoran was sunk in an engagement with HMAS Sydney': 1,
#  'On life raft tethered to lifeboat. A seaman put hand over side to rinse a cup': 1,
#  'SS Ethel Skakel foundered in Central America Hurricane of 1941': 1,
#  'Adrift on life raft': 1,
#  'Swimming at edge of channel': 1,
#  'Plane forced down, 3 men on rubber life raft. Put hand over side to feel drift of boat ': 1,
#  'Diving from lugger': 1,
#  'Jumped overboard from torpedoed Panamanian freighter': 1,
#  'A 210-ton brig was sunk by a Japanese submarine. Some of the survivors were machine-gunned & some were taken by sharks': 1,
#  'Japanese aircraft shot down. He was one of two survivors rescued by the U.S. destroyer Mugford': 1,
#  'Swimming. Passer-by, Len Bedford, heard him shriek , saw shark leap from the water & swimmer disappeared': 1,
#  'Swimming outside the safety enclosure attempting to retrieve a tennis ball drifting toward midstream ': 1,
#  'Fishing from launch, fell into net with shark': 1,
#  'Hardhat diving from Japanese pearling lugger, Reiyo Maru': 1,
#  'The schooner Elizabeth, bound from Bluefields, Nicaragua to the river port of San Carlos foundered': 1,
#  'Disappeared 11 days earlier, probable homicide victim': 1,
#  'Hardhat diving': 1,
#  'Swimming, naked': 1,
#  'Canoe capsized by shark': 1,
#  'Watching seine netters with friends, one of whom picked up a netted shark': 1,
#  'Put foot inside a landed & supposedly dead shark': 1,
#  'In rubber dinghy with Captain Eddie Rickenbacker for 21 days. ': 1,
#  'Fishing for bluefish, shark leapt into dory': 1,
#  'Fishing with dynamite, afterwards in water retrieving catch': 1,
#  'Two canoes with 14 aboard blown to sea in a storm. While adrift for 3 week, one person fell overboard and was killed by a shark': 1,
#  'Pleasure boating': 1,
#  'Diving from the lugger San, operated by the Protector of the Aborigines': 1,
#  'Refused permission to cross on the ferry, he was swimming across the river': 1,
#  'Rescuing seaman after ship sunk by German raider': 1,
#  'Swimming ashore after launch capsized': 1,
#  "12 of the Penang's crew were returning to the ship when their 12' dinghy capsized": 1,
#  "Holding shark's tail ": 1,
#  'Diving, attempting to retrieve body of drowning victim wedged between rocks': 1,
#  'Fishing for the shark that killed George Lundberg': 1,
#  'Wreck of a sampam': 1,
#  'Trochus diving, but floating on surface': 1,
#  'Swept overboard': 1,
#  'Diving for beche-de-mer from lugger': 1,
#  'Swimming crawl stroke': 1,
#  'Fishing, catching snoek, Thyrsites atun': 1,
#  'Fell overboard, hanging onto lifebuoy': 1,
#  'Diving for trochus , but swimming on surface': 1,
#  'Among 31 survivors of crew from the sampan Fukulya Maru (which reached Thursday Island in rowing boat) was a man whose arm had been bitten off by shark. The sampan wrecked west of McArthur island ': 1,
#  'Diving from dinghy for trochus shell': 1,
#  "Fishing, removing gaff from shark's mouth": 1,
#  'Swimming alongside warship   Tsingt-ao': 1,
#  'Swimming to anchored boat': 1,
#  'Adrift on raft after their ship was sunk by an Axis raider ': 1,
#  'Splashing in water ': 1,
#  'Slipped off rocks and fell into the water': 1,
#  'Swimming in hip-deep water': 1,
#  'Standing on sandbank': 1,
#  'Collecting fish in military trap when bitten by captured shark that had been shot by soldiers with Garten': 1,
#  'Swimming in waist-deep water ': 1,
#  'Free diving for lobster': 1,
#  'Dived into sea from launch & bitten immediately': 1,
#  'Dived into the water': 1,
#  'male': 1,
#  'Standing in water with child in her arms': 1,
#  'Free diving for trochus shell, swimming to dinghy': 1,
#  'Spearfishing & had just speared a ulua': 1,
#  'Japanese freighter Bokuyo Maru burned & sank': 1,
#  'Freediving for trochus shell (submerged)': 1,
#  'Swimming & splashing': 1,
#  'Dress diving, filming shark & pulling it through the water for a motion picture scene': 1,
#  'Taken as he dived into the water': 1,
#  'Swimming (lead swimmer in race)': 1,
#  'Touching the mouth of a supposedly dead shark': 1,
#  'Washed off freighter Huncliff by a freak wave': 1,
#  'Surfing (pneumatic surfboard)': 1,
#  'Hauling in net with shark in it': 1,
#  'Pearl diving, but standing in the water': 1,
#  'Bathing/Swimming': 1,
#  'Put foot inside mouth of supposedly dead shark': 1,
#  'Scooping prawns': 1,
#  'She was on a ship that was torpedoes & was in the water awaiting rescue': 1,
#  'Tzenny Chandris, a Greek freighter laden with scrap iron, foundered in heavy weather': 1,
#  'Fishing, shark caught in his net': 1,
#  'Explosion & sinking of the USS Juneau after being torpedoed by the submarine  I-85': 1,
#  'Anti-Aircraft cruiser USS Atlanta (CL,-05) travelling in convoy after the Battle of Midway, encountered a Japanese flotilla  (Battle of Guadalcanal) &, heavily damaged by gunfire, she was lost off Lunga Point. Victim was swimming when bitten.': 1,
#  'Fishing from market fishboat Sea Spray': 1,
#  'Aircaft exploded': 1,
#  'Swimming or wading out  to warn bathers that a shark had been seen': 1,
#  'Crouching in the water': 1,
#  'Fishing from shore': 1,
#  'Fishing / cleaning fish, dived into water to retrieve a lost fish': 1,
#  'Bathing alongside ship': 1,
#  'Pearl diving from lugger Whyalla': 1,
#  'Grabbed shark & threw it on deck': 1,
#  'Fishing trawler Flavio Gioia ': 1,
#  'Closed circuit diving (submerged). Diving to recover jettisoned packets of opium for police': 1,
#  'Tuna fishing, standing on stern platform that was submerged by waves': 1,
#  'Spearfishing, hunting crayfish': 1,
#  'Fishing  (trawling)': 1,
#  'American freighter Mormackite, bound from Buenos Aires for Baltimore, capsized & sank in heavy seas': 1,
#  'Swimming near canoe': 1,
#  'Dived overboard & was swimming near stern of trawler': 1,
#  'Crossing the bay at the ford': 1,
#  'Hunting lobsters in 2.4 m of water': 1,
#  'Royal Hawaiian skymaster DC-6B aircraft went down with  58 passenger & crew': 1,
#  'Accidentally dragged overboard from the sampan Holokahana into school of yellowfin tuna': 1,
#  'Retrieving bait box that had fallen overboard': 1,
#  'Boat exploded': 1,
#  'Diving, recovering fish killed by dynamite': 1,
#  'Spearfishing, speared a small shark': 1,
#  'Went to aid of child being menaced by the shark': 1,
#  'Fishing for white sharks': 1,
#  'Fishing, standing in water next to purse net': 1,
#  'Fishing, standing in water washing fish': 1,
#  'Swimming on surface': 1,
#  'Spearfishing, carrying fish on spear': 1,
#  'Fishing for trout ': 1,
#  'Landing hooked shark in boat': 1,
#  'Swimming from fishing boat setting nets': 1,
#  'Body surfing & treading water': 1,
#  'Fishing, setting nets': 1,
#  'Lying prone on surfboard': 1,
#  'Bitten while cutting shark from net': 1,
#  'Went over side of boat at trochus ground': 1,
#  "Adrift on a 4'  raft for 32 days": 1,
#  'Swimming in midriver near sewage outlet & 400 m from a slaughterhouse': 1,
#  'Rowing toward snapper grounds': 1,
#  "Competing in U/W endurance record, standing beside drum in 10' of water": 1,
#  'Swimming with speared fish': 1,
#  'Fishing, holding fish': 1,
#  'Swimming between  anchored  pearling luggers': 1,
#  '3 men & 2 boys picked up wearing life jackets and with inner tube': 1,
#  'Competing in spearfishing championship & towing dead fish': 1,
#  'M.V. Tropical sank. Sole survivor rode oil drums for 8 days without food or water.': 1,
#  'Attempting to net shark in shark channel': 1,
#  'Air/Sea Disaster Pan-American Airlines Stratocruiser with 44 people onboard crashed into the sea': 1,
#  'Fishing, walking in river to cast': 1,
#  'Fishing (trolling)': 1,
#  'Placed hand in disemboweled shark\x92s jaws': 1,
#  'Helmet diving in Miami Seaquarium': 1,
#  'Spearfishing / swimming on surface': 1,
#  'Fishing, holding fish in his left hand': 1,
#  'Swimming with goggles': 1,
#  'Paddling in knee-deep water': 1,
#  'Swimming, towing the shark': 1,
#  'Spearfishing, had fish on his spear': 1,
#  'Boat stopped to repair electric pump': 1,
#  '"Climbing up to ship after repairing the stern in water"': 1,
#  'Skindiving for specimens': 1,
#  'Dynamiting fish': 1,
#  'Fishing from boat, Kaimamla': 1,
#  'Swimming, attacked at  surf carnival': 1,
#  'Spearfishing or fishing': 1,
#  'Swimming near breakwater': 1,
#  'Hunting turtle': 1,
#  'Spearfishing & lassoed shark': 1,
#  'Fishing for pompano': 1,
#  'Removing shark from net ': 1,
#  'Swimming off yacht': 1,
#  'Attempting to set underwater endurance record': 1,
#  'Free diving, working on U/W scenes for motion picture': 1,
#  'Free diving for sinkers': 1,
#  'Air/Sea Disaster': 1,
#  'Longling fishing': 1,
#  'Line fishing from Lakotoi, saw shoal of fish, dived overboard, had speared second fish & surfaced for air': 1,
#  'Free diving for crayfish': 1,
#  'Swimming near pier': 1,
#  'Climbing back on ship': 1,
#  'Skindiving, fish at belt': 1,
#  "Spearfishing, holding 5' speared fish": 1,
#  'Shipwrecked; adrift on raft for 2 days & 2 nights': 1,
#  'cargo ship Southern Isle sank at 04h00': 1,
#  'Body found on deserted luxury yacht, 38\x92 Christine': 1,
#  'Playing on rock, slipped & fell into the water': 1,
#  'Fell overboard from US Navy PC boat': 1,
#  'Japanese POW ship Arisan Maru with 1800 American prisoners of war on board bound for slave labor camps was torpedoed by an American submarine': 1,
#  'Parachuted into Pacific': 1,
#  'USS Johnston DD 557 sunk on 10/24/1944 in the Battle off Samara. Crewmen were swimming beside a raft.': 1,
#  'USS Hoel DD 533 sunk on 10/24/1944 in the Battle off Samar. 2 crewmen were swimmng alongside a floater net &': 1,
#  'USS Gambier Bay CVE-73  shelled & sunk  at 09h57 on 10/24/1944, by Japanes fleet enroute to attack the Allied landing force at Leyte.': 1,
#  'Swimming near life raft': 1,
#  'Bathing with her mother': 1,
#  '90 European civilians, many women & children, were placed on the deck of a Japanese submarine that submerged when it was well offshore': 1,
#  'Adrift on raft': 1,
#  'American cruiser Indianapolis torpedoed & sunk by the Japanese submarine I-58': 1,
#  'American minesweeper USS YMS-350 lost in a typhoon - swimming to shore': 1,
#  'American minesweeper USS YMS-472 foundered in a typhoon - swimming to shore': 1,
#  'Bitten after dhow shipwrecked': 1,
#  'Jumping in swells': 1,
#  'Fishing, probably with a net': 1,
#  'Swimming after a tennis ball': 1,
#  'Pearl diving from lugger': 1,
#  'Washed overboard by swell': 1,
#  'B-24 aircraft crashed  into the sea': 1,
#  'Attempting to ride a shark': 1,
#  'Small boat swamped, 4  people swimming to shore but he fell behind the other 3 and vanished': 1,
#  'On 6-Nov-1942, the German submarine U-68 sank the City of Cairo 5 days from Cape Town, survivors took to lifeboats & rafts. On the 15th day, a fireman jumped over the stern & was taken by sharks': 1,
#  'Thrown from destroyer when shell hit': 1,
#  'U-177 torpedoed & sank the troopship Nova Scotia': 1,
#  'Dog paddling or standing': 1,
#  'The USS Wahoo torpedoes & sank the Japanese troop transport Buyo Maru': 1,
#  'Known as The Battle of the Bismarck Sea :  8 Japanese destroyers guarding a convoy of 8 transports were attacked by 129 Allied fighters, 207 bombers & 3 squadrons of the Royal Australian Air Force. ': 1,
#  'The 3540-ton Alfonso Penna was torpedoed & sunk by the Italian submarine Barbarigo': 1,
#  'The 21,516-ton troopship Empress of Canada torpedoed and sunk by the Italian submarine Leonardo da Vinci': 1,
#  'ship torpedoed 400 miles off the African coas. Man was clinging to hatch cover': 1,
#  'Fell overboard from USS Ward': 1,
#  'Hospital Ship Centaur torpedoed & sunk by the Japanese submarine I-177': 1,
#  'B-24 crashed during a search mission. Survivors in raft for 47 days ': 1,
#  'Treading water after survivng crash of the US Navy airship K-74 that was hit by the German submarine U-134': 1,
#  'Flying Fortress bomber aircraft went down after daytime raid on Naples. He was swimming on the surface': 1,
#  'Dived overboard to check propeller of US Navy motor torpedo boat': 1,
#  'The 6711-ton American freighter & troop transport Cape San Juan was torpedoed by the Japanese submarine I-21': 1,
#  'Swimming with board': 1,
#  'The Cuban freighter Libertad was torpedoed and sunk by the German submarine U-129': 1,
#  "Swimming near jetty with 2' piece of wood": 1,
#  'Moving shark from tuna vessel when boat rolled, placing both man & shark in chest-deep water': 1,
#  'Diving (Hookah)': 1,
#  'Survived crash of two-engine  C-46 transport plane carrying 62 migrant workers from Puerto Rico to USA ': 1,
#  'Helmet diving, collecting trochus shell': 1,
#  'Spearfishing, but walking carrying fish on end of speargun': 1,
#  'Bending over': 1,
#  'Defecating in water beneath the docks': 1,
#  'Sitting on side of dinghy mending a net': 1,
#  'Fishing, one of three fishermen swept into the sea by a large wave ': 1,
#  'Fishing, sitting in stern of small boat, feet dangling in the water': 1,
#  'Sea Disaster, sinking of the fishing  launch Mavis': 1,
#  'Goggle-diving for seaweeds, but standing in water': 1,
#  "Lying on the bottom of a 16' dinghy": 1,
#  'Swept off deck of S.S.Frontenac enroute from West Indies to US': 1,
#  'Jerked overboard while pole fishing for tuna': 1,
#  'Paddling a canoe': 1,
#  'Paddling a surfboat': 1,
#  'Spearfishing (but treading water on the surface)': 1,
#  'Fishing, casting in the surf': 1,
#  'Fell off surf ski': 1,
#  'Swept out to sea while fishing': 1,
#  'Sea Disaster, sinking of the motorship Wingate': 1,
#  'Free diving or wading back to shore': 1,
#  'Fishing in waist-deep water': 1,
#  'Air/Sea Disaster involving C-54 Air Force Transport No. 2686 with 37 on board': 1,
#  'Fishing / diving': 1,
#  'Fishing, holding fish in right hand': 1,
#  'Underwater photography': 1,
#  'C47 aircraft carrying 5,000 lbs of ice ditched in the sea': 1,
#  'Bringing hooked, harpooned shark onboard boat': 1,
#  'Spearing a shark': 1,
#  'Bathing or washing': 1,
#  'Leicester abandoned in a hurricane': 1,
#  '2 messboys (Jeppsen) & Tony Latona (13) were playing on the afterdeck of the Danish ship Grete Maersk. Jeppsen fell overboard, Latona threw a lifebelt then jumped in to help him. Ship didn\x92t notice they were missing': 1,
#  'No details': 1,
#  'Treading water, waiting for a wave': 1,
#  'Swimming close to wharf': 1,
#  'Fishing, on a boat': 1,
#  'Lifesaving exhibition': 1,
#  'Bathing in water 0.9 m deep': 1,
#  'Examining netted shark, that had been shot': 1,
#  'A 75-ton  Japanese fishing ship was sunk by  Chinese Nationalist gunboat, shipwrecked men were clinging to debris': 1,
#  'Swimming near shore': 1,
#  'Catching a turtle': 1,
#  "Bathing in 3' to 4' of water": 1,
#  'On expedition filming a feature movie & standing on tripod': 1,
#  'The steamship Bonnie Dundee lost in collision': 1,
#  'Escaping from blackbirding vessel': 1,
#  'Body found floating next to his ship': 1,
#  'Washed overboard from the barque Mary Eady': 1,
#  'Bathing in 2 feet of water': 1,
#  'Washed off raft': 1,
#  'Wreck of the Union Steamship Company 982-ton iron steamer Kafir': 1,
#  'Jumped overboard after murdering 2 shipmates': 1,
#  'Floating with life buoy after pilot launch capsized': 1,
#  'Swimming to retrieve a flannel': 1,
#  'Boat of the Resolution capsized in the breakers': 1,
#  'Traveling by boat': 1,
#  'Floating, holding onto an oar after dory capsized': 1,
#  'During "an exhibition" he was tied in sack & thrown overboard ': 1,
#  'Fell overboard from the Selim': 1,
#  'Clinging to shipwrecked junk': 1,
#  'Restraining a beached shark': 1,
#  'Fell overboard & rescuer': 1,
#  'Fell overboard from the steamship Chala': 1,
#  'Salvaging a shipwreck': 1,
#  'Fleet of canoes caught by a squall and charged by sharks.': 1,
#  'Fell or jumped overboard from the liner Rhynland': 1,
#  'Painting a ship': 1,
#  'Bathing near whaling ship (bark A. R. Tucker of New Bedford, Massachusetts)': 1,
#  'Reaching for life preserver': 1,
#  'Standing / Bathing': 1,
#  'Coming ashore on a hawser': 1,
#  'Dragging a shark': 1,
#  'Wreck of the Aphrodite': 1,
#  'Boarding a ship': 1,
#  'Swimming alongside the schooner Catherine Wilcox': 1,
#  'boat from ship Josephine capsized in squall': 1,
#  'Swimming to avoid capture': 1,
#  'boat from the Austrian ship Elizabeth': 1,
#  'Bathing close inshore': 1,
#  'A junk foundered': 1,
#  'Net fishing': 1,
#  'Bathing / standing': 1,
#  'Adrift on a raft ': 1,
#  'Wreck of the 150-ton brig Maria': 1,
#  'Burning of the S.S. Missouri': 1,
#  'yachting accident': 1,
#  'Diving alongsidethe steamship Ranelagh ': 1,
#  'Swimming after harpooned whale capsized boat': 1,
#  'Fell overboard from sponge vessel': 1,
#  'Swimming to shore after boat capsized by a squall': 1,
#  'Fleeing across a river': 1,
#  'Fishing for sharks when he became entangled in net & fell overboard': 1,
#  'Sea Disaster, canoes capsized in storm': 1,
#  'Attempting to rescue shipmate': 1,
#  'Swimming, after boat swamped': 1,
#  'Dress diving': 1,
#  ' a canoe was pursuing a schooner that had forcibily abducted 5 young girls': 1,
#  'Riding a horse': 1,
#  'Fishing boat with 4 men on board was rammed & capsized by  a shark, throwing all occupants into the water': 1,
#  'Murdered': 1,
#  'Swimming after falling overboard from the sealing ship Vesper': 1,
#  'His balloon crashed in the harbor': 1,
#  'Canoe swamped': 1,
#  'HMS Victoria collided with the HMS Camperdown': 1,
#  'A barque wrecked': 1,
#  'Abandoning burning steamship Don Juan': 1,
#  'small boat': 1,
#  'Treading for clams': 1,
#  'Parachuted from balloon': 1,
#  'He drowned when boat capsized': 1,
#  'Sea disaster, wreck of the sloop Sara': 1,
#  'Sea disaster : Wreck of the Taiaroa': 1,
#  'Oystering': 1,
#  'Fishing from shore, washed into the sea': 1,
#  'Swimming after being washed overboard': 1,
#  'Netting menhaden, sharks caught in net': 1,
#  'British ship Macedon was thrown on her beam ends by a sudden squall': 1,
#  'The passenger ship Kapuna was run down the ore carrier Ada Melmore': 1,
#  'Rowing a dinghy': 1,
#  'Sea disaster, wreck of the Alfred Watts': 1,
#  'Cleaning the side of a ship': 1,
#  'Crossing inlet in a boat, seen fighting sharks with his oar, sharks smashed boat': 1,
#  'Fell oveboard from steamer Wanderer': 1,
#  'Crossing the river mouth': 1,
#  'The cutter yacht Cutty Sark sank': 1,
#  'The Dwarka foundered': 1,
#  'Probabable drowning': 1,
#  'The steamships Thingvalla and Geiser collided': 1,
#  'Working on the bridge when he fell into the river': 1,
#  'Launching a boat': 1,
#  'Swimming, caught in strong backwash & disappeared': 1,
#  'Trying to catch a wounded bird': 1,
#  'A dhow capsized': 1,
#  'Crossing river on a raft': 1,
#  "Skin diving. Grabbed shark's tail; shark turned & grabbed diver's ankle & began towing him to deep water": 1,
#  'Attempting to drive shark from area': 1,
#  'yachtsman in a zodiac': 1,
#  'Helmet diving': 1,
#  'Free diving for sponges': 1,
#  'Fishing?': 1,
#  'Net-fishing': 1,
#  'Collecting fish ': 1,
#  'Swimming from capsized pirogue': 1,
#  'Fishing for basking sharks': 1,
#  'Swimming to canoe': 1,
#  'Swimming/': 1,
#  'Shipwrecked Persian Fleet': 1,
#  'Washing his pig in preparation for a religious ceremony': 1,
#  'Ascending from a dive': 1,
#  'Man fell overboard from ship. Those on board threw a rope to him with a wooden block & were pulling him to the ship': 1,
#  'Ship lay at anchor & man was working on its rudder': 1,
#  'Free diving, collecting sand dollars': 1,
#  'Fishing from a small boat & put his hand in the water while holding a dead fish': 1,
#  'Swimming alongside the SS Kearsarge': 1,
#  'Standing, washing rear wheels of his ambulance in ankle-deep water': 1,
#  '4 men were bathing': 1,
#  'Crew swimming alongside their anchored ship': 1,
#  'Swimming around anchored ship': 1,
#  'Swimming in pool formed by construction of a wharf': 1,
#  'Wooden fishing boat': 1,
#  'Aircraft ditched in the sea, swimming ashore': 1,
#  'Spent 8 days in dinghy': 1,
#  'Carrying a supposedly dead shark by its mouth': 1,
#  'Fishing in ankle-deep water': 1,
#  'Swimming naked near a date palm where many dates fell into the water': 1,
#  'A group of survivors on a raft for 17-days': 1,
#  'Fishing, wading with string of fish': 1,
#  'Shark fishing, knocked overboard': 1,
#  'Lashing logs together when he fell into the water': 1,
#  'Swimming near anchored ship': 1,
#  'Testing movie camera in full diving dress': 1,
#  'Swimming with fish attached to  belt': 1,
#  'Swimming in section of river used for washing clothes & cooking utensils': 1,
#  'Went overboard': 1,
#  'Fell overboard from a frigate & was swallowed by a shark. The captain fired a gun at the shark, and "the creature cast the man out of his throat."': 1,
#  'Washing himself': 1,
#  'Fell overboard from the Sobella': 1,
#  'Wreck of the Sovereign': 1,
#  'Hilo': 1,
#  'Attempting to rescue woman seized by shark': 1,
#  'Vessel capsized, wading ashore carrying an oar': 1,
#  'Wreck of the steamship Birkenhead': 1,
#  'Swimming from capsized boat': 1,
#  'He was fighting a shark when his boat capsized & he disappeared': 1,
#  'Commercial Salvage Diving': 1,
#  'Fell overboard from the Malacca': 1,
#  'Dropped overboard': 1,
#  'ship William Penn grounded & broke apart': 1,
#  'Jumped overboard while intoxicated': 1,
#  'In boat being towed by ship, Karnak': 1,
#  '43-ton schooner Irene capsized & sank': 1,
#  'Gloucester fishing schooner run down': 1,
#  'Deserting the bark Nazarene': 1,
#  'Bathing alongside the American ship Thomas W. Sears': 1,
#  'Boat of a Hawaiian brig was stove in by  whale': 1,
#  'Wreck of the Tweed': 1,
#  'Wreck of the USS Somers': 1,
#  'Jumped into river': 1,
#  'Boat capsized': 1,
#  "a corsair's boat was overturned": 1,
#  "Standing on landed shark's tail": 1,
#  'Conch diver': 1,
#  'HBM Magpie foundered in a squall': 1,
#  'British ship, Britannia,  was loading lumber. He was bathing': 1,
#  'Wreck of the schooner Driver': 1,
#  'Fell overboard from the ship Gem': 1,
#  'Washing a dog': 1,
#  'Fishing from dory, shark upset boat & he fell into the water': 1,
#  'Boat capsized, clinging to line': 1,
#  'American schooner Orator capsized  ': 1,
#  'Hooking into a whale': 1,
#  'Attempting to rescue crew after whale upset their boat': 1,
#  'Accidentally thrown overboard & treading water while awaiting rescue': 1,
#  'Unknown, but it was said to be the "First known attack in Sydney Harbour"': 1,
#  'Washed off catamaran in the surf': 1,
#  'Harassing a shark': 1,
#  'Fell from yardarm of British ship Rover': 1,
#  'Swimming / floating on his back': 1,
#  'Fishing, hauling in fishing gear': 1,
#  "Bathing in 5' of water": 1,
#  'Freediving, inspecting Kaunakakai wharf construction after blasting & dredging ': 1,
#  'seaplane Columbus ditched in the sea': 1,
#  'Dismantling cable buoys of the cable ship All America': 1,
#  'After rowing skiff was holed by shark, he was attempting to swim ashore': 1,
#  'Diving for pearl': 1,
#  'Dry shelling': 1,
#  'Fishing, standing in waist-deep water': 1,
#  'Had just dived into water & was swimming': 1,
#  'Floating, after falling or jumping off the Standard Oil tanker Frederick W. Weller': 1,
#  "Fell from his father's back into the water": 1,
#  'Fishing, fell in water & swimming strongly to shore': 1,
#  'Removing shark from a net': 1,
#  'Inebriated, woke from sleep and fell off deck into the water ': 1,
#  'The Ward liner Esperanza stranded during a gale & she leapt overboard to rescue her dog which had been swept overboard.': 1,
#  'Diving for coins tossed from passenger ship': 1,
#  "Diving, repairing water main at depth of 90'": 1,
#  'Bathing in waist-deep water': 1,
#  'Swimming to mail boat': 1,
#  'Bathing in knee-deep water': 1,
#  'Wading to dinghy, carrying his son': 1,
#  'Shark hoisted on board liner Tahiti': 1,
#  'Wading (shrimping)': 1,
#  'Diving for pearls': 1,
#  'Swimming beside launch': 1,
#  'Ship Mariston torpedoed & sunk': 1,
#  'Swimming to shore from the Medic': 1,
#  'Stuffing a shark into an automobile': 1,
#  'Swimming, towing an empty barrel': 1,
#  'Wreck of the tug Magellan': 1,
#  'Steamer Una wrecked with 75 laborers onboard. Survivors took to rafts & lifeboats.': 1,
#  'Cutter capsized': 1,
#  'Dived into a school of baitfish': 1,
#  'Knocked into the water': 1,
#  '"Swimming vigorously"': 1,
#  'Small vessel with 13 men on board capsized crossing the bar and 6 men drowned.  The 7 survivors were swimming to shore': 1,
#  'Sitting in a boat': 1,
#  'Floating face down': 1,
#  'Boat capsized, swimming to shore': 1,
#  'Harpooned shark': 1,
#  'The coastwise steamer San Basilio capsized in a typhoon': 1,
#  'Dived onto shark from floating stage': 1,
#  'Fell overboard from SS Ripley Castle': 1,
#  'Swimming, after sailboat capsized': 1,
#  'Gaffing & attempting to bring onboard a harpooned shark': 1,
#  'Removing shark from a trap': 1,
#  'Diving off pier & treading water': 1,
#  'Swimming / floating': 1,
#  'Thrown into water from fishing dinghy': 1,
#  'Swimming, carrying tin can with mail to steamer': 1,
#  'Fishing, hauling in net, shark in net': 1,
#  'Fishing with a cast net': 1,
#  'Fishing, boat capsized': 1,
#  'Fishing, had just speared a ulua': 1,
#  'Swimming to shore after a squall  capsized their motorized shark fishing boat': 1,
#  'Fell overboard?': 1,
#  'Swimming a quarter mile offshore': 1,
#  'Diving off wharf': 1,
#  'Diving for trochus from lugger': 1,
#  'Collecting fish by lamplight in gully': 1,
#  'Working near fish traps': 1,
#  'Fishing with dynamite': 1,
#  'Free diving with goggles': 1,
#  'Fishing schooner Jose Luis foundered': 1,
#  'Diving by wharf': 1,
#  'Swimming with dog near canning factory': 1,
#  'Jumped overboard and swimming': 1,
#  'Jumped out of canoe': 1,
#  'British patrol boat 1250-ton HMS  Valerian foundered in a hurricane': 1,
#  'Attempting to rescue drowning man': 1,
#  'Feeling the shark\x92s teeth': 1,
#  'Standing, collecting bananas': 1,
#  'Riding horseback across the creek': 1,
#  'Italian liner Principessa Mafalda sank': 1,
#  'The steamer Tahiti collided with the ferry Greycliffe': 1,
#  'Retrieving meat from a cage in the water': 1,
#  'Bathing or body surfing ': 1,
#  'Sea Disaster, sinking of the  SS Vestris': 1,
#  'Hardhat diving ': 1,
#  'Wading, netting fish': 1,
#  'Diving for coins thrown from ship S.S. Moeraki': 1,
#  'Swimming between boats': 1,
#  'Diving for trepang': 1,
#  'Fell from wharf into water & attacked immediately': 1,
#  'Sea Disaster, wreck of the  SS Norwich City': 1,
#  'Taking wife to beach & about 1 m from the shore': 1,
#  'Swimming 10 m from shore': 1,
#  'Fishing, attempted to take a netted shark': 1,
#  "Ship's boat capsized in squall, captain & 2 sailors clinging onto hull": 1,
#  'Standing, gathering oysters': 1,
#  ' ': 1,
#  'Hunting seashells': 1,
#  'Taking catch from a fish weir in which the shark was snared': 1,
#  'Standing on ship deck': 1,
#  'Catching crabs': 1,
#  'Swimming, after falling overboard': 1,
#  'Diving on a wreck': 1,
#  'Lost his footing & fell overboard': 1,
#  'Fell overboard ': 1,
#  'Bathing alongside US Naval ship': 1,
#  'Harpooning turtles': 1,
#  'Jumped or fell overboard': 1,
#  'Swimming from naptha launch after a day of fishing': 1,
#  'Human head found in shark caught by British steamer Syria': 1,
#  'Floating or standing': 1,
#  'Washing horses': 1,
#  'The schooner Tahitienne foundered in a hurricane': 1,
#  'Hunting sharks': 1,
#  'Attempting to land a boat from the Hinemoa': 1,
#  'Swimming (recovering remains of Stilwell) ': 1,
#  'Loss of the schooner Nomad': 1,
#  '"Crossing the river"': 1,
#  '"Boat accident"': 1,
#  'Sea Disaster : Wreck of the Carrie E. Long': 1,
#  'Hunting seals': 1,
#  'Swimming ashore from a "filibuster"': 1,
#  'Wreck of the steamship Sultan of Bombay': 1,
#  'Wading after stray fish from seine netter\x92s catch': 1,
#  'Angling': 1,
#  'Attempting to escape by swimming to shore': 1,
#  'Hunting crayfish': 1,
#  'Trailing hand in the water': 1,
#  '13 men in the water after sailboat capsized & sank': 1,
#  'Sponge divers': 1,
#  'The cutter Francis Adams foundered': 1,
#  'boat from City of Naples capsized': 1,
#  'Swimming at side of small boat': 1,
#  'Swimming after their boat capsized': 1,
#  'Fell oveboard': 1,
#  'Net fishing, fell into the water': 1,
#  'Row boat (from the gunboat Elcano) was sinking, put finger in hole': 1,
#  'Fishing,  tarpon being chased by shark  leapt across his skiff, breaking it in half & Larkin became tangled in the net': 1,
#  'Swimming from foundered vessel': 1,
#  'Unknown, their unoccupied yawlboat was recovered': 1,
#  'Steamer Durao struck rock & filled, boats capsized, passengers & crew tried to swim to shore': 1,
#  'Shipwrecked pearling schooner': 1,
#  '3-masted steel barque Glenbank foundered during a cyclone': 1,
#  'Fell overboard & swimming': 1,
#  'Jumped overboard to rescue companion': 1,
#  'Fell overboard from steamship Rio Grande': 1,
#  'Washed overboard': 1,
#  'Hauling in net': 1,
#  'Floating in creek': 1,
#  'Washed into sea while picking opihi & attacked by 2 large sharks ': 1,
#  'Swimming ashore from swamped 13-ft boat': 1,
#  'Washing clothes': 1,
#  'Copra vessel with 19 on board was wrecked in a squall': 1,
#  'Skin diving for trepang but at surface next to the boat': 1,
#  'Clinging to overturned rowing boat': 1,
#  'Jumped overboard from Norwegian steamship Venator': 1,
#  'S.S. Ramos foundered in a hurricane. Captain & 14 crew in water-logged lifeboats. ': 1,
#  'Fell overboard from USS cruiser Tacoma': 1,
#  'Hard hat diving, laying some charge of powder': 1,
#  'Surf bathing': 1,
#  'Fishing, thrown into water by heavy sea, clinging to rocks at the water line': 1,
#  'Diving, retrieving fish caught in net ': 1,
#  'Reached out to disentangle rope & fell overboard': 1,
#  'Gathering fish stunned by dynamite': 1,
#  'native boats sunk in storm': 1,
#  'The British steamer Caribbee foundered': 1,
#  'The 168-ton Belmore foundered in heavy seas': 1,
#  'Fell overboard from P&O steamship Arabia': 1,
#  'On fishing boat & trailing hand in the water': 1,
#  'Fell from the jetty': 1,
#  'On December 28, 1908, an earthquake, followed by tsunamis, destroyed coastal towns in Silcily and southern Italy, killing more than 100,000 people': 1,
#  'Wreck of the 1308-ton Norwegian ship Auckland': 1,
#  'Diving (Helmet) for sponges': 1,
#  'Reported swept away by waves while gathering opihi': 1,
#  '1446-ton Norwegian barque Errol, bound from Peru to Newcastle with 22 on board wrecked. Survivors shelterd on the wreck of the Annasona. Subsequently the Master, his wife & 4 children perished along with several crew. Survivors (5) were rescued 7/12/1909': 1,
#  'Fell overboard while fishing for sharks': 1,
#  'Fell overboard from fishing schooner Halycon': 1,
#  'The 2379-ton French steamer La Seyne collied with British steamer Onda & sank in minutes. Passengers jumped overboard expecting to be picked up by Onda\x92s boats': 1,
#  'Slapped shark on tail as it swam by': 1,
#  'Light aircraft ditched at sea': 1,
#  'Cleaning hull of ship ': 1,
#  'Snorkeling \x96 hunting crayfish and abalone': 1,
#  'Wading / Surfing': 1,
#  'Floating on raft': 1,
#  'Walking / surfing': 1,
#  'Fishingat': 1,
#  'Body boarding or surfing': 1,
#  'Scuba diving (submerged riding a scooter)': 1,
#  'Spearfishing on scuba & transferring fish onto a stringer': 1,
#  'Swimming or paddle boarding': 1,
#  'Towing rubber dinghy': 1,
#  "Scientific research (Dr. Sonny Gruber's student)": 1,
#  'Swimming / surfing': 1,
#  'Surfing (or body boarding)': 1,
#  'Moving a shark in a net ': 1,
#  'Fishing / washing bait off hands': 1,
#  'Inflatable boat': 1,
#  'Paddle Skiing': 1,
#  'Swimming near pod of whales': 1,
#  'Body surfing or body boarding': 1,
#  'Fishing for octopus': 1,
#  'Spearfishing / night diving': 1,
#  'Body surfing, stood up on sandbar': 1,
#  'Watching seals': 1,
#  'Abalone diving using Hookah (near calving whales)': 1,
#  'Playing / standing': 1,
#  'Fell off aircraft carrier': 1,
#  'Diving, gathering shellfish': 1,
#  'Chumming for sharks': 1,
#  'Swimming with mask & snorkel': 1,
#  'Boeing 757 enroute from Porta Plata plunged into the sea': 1,
#  'Swimming in fish tank': 1,
#  'Dived naked into the water on a bet': 1,
#  'Fishing in knee-deep water': 1,
#  'Swimming breast stoke': 1,
#  'Shell Diving': 1,
#  'Tech diving ': 1,
#  'Free diving with a pod of dolphins': 1,
#  'Surfing / Swimming': 1,
#  'Swimming or snorkeling': 1,
#  'Attempting to attract dolphins': 1,
#  'Swimming, towing a kayak': 1,
#  'Spearfishing & diving for paua': 1,
#  'Adrift after ditching plane in the sea': 1,
#  'Attempting to catch a crocodile': 1,
#  'Swimming / Body surfing': 1,
#  'Standing / surfing': 1,
#  'Fell onto dead shark': 1,
#  'Shipwrecked': 1,
#  'Diving (shell maintenance)': 1,
#  'Diving for sea urchins': 1,
#  'Swimming back from anchored sailboat': 1,
#  "Sinking of the 40' Esperanza off St. Maartin with 36 refugees on board": 1,
#  'Batin': 1,
#  'Swimming after being swept into sea by a large wave': 1,
#  'Standing alongside surfboard': 1,
#  'Spearfishing, carrying his catch': 1,
#  'Hiking on the beach': 1,
#  'Floating face-down in knee-deep water': 1,
#  'Fell off banana boat': 1,
#  'Walking in shallows': 1,
#  'Wreck / Technical diving': 1,
#  'Surfing, fell off surfboard & stepped on the shark.': 1,
#  'Conducting research': 1,
#  'Swimming out to porpoises ': 1,
#  'Windsurfing, but sitting on his board': 1,
#  'Surfing / Wading': 1,
#  'Splashing / wading': 1,
#  'Adrift in a life jacket': 1,
#  'Wading in school of baitfish': 1,
#  'Swimming with dolphins': 1,
#  'Spearfishing & holding catch': 1,
#  "Lying prone in 2' of water": 1,
#  'Wading with surfboard': 1,
#  'Wading to shore after surfing': 1,
#  'Surfing, lying on surfboard': 1,
#  'Spearfishing, but swimming at surface': 1,
#  'Fishing for tarpon': 1,
#  'Canoe with 3 men onboard sank': 1,
#  'Feeding prawns to captive sharks': 1,
#  'Boogie boarding / wading': 1,
#  'Air Disaster - Piper aircraft crashed into the sea, killing all on board': 1,
#  'Spearfishing, holding mesh bag with speared fish': 1,
#  'Attempting to illegally enter the USA': 1,
#  'Abalone diving using Hookah (resting on the surface)': 1,
#  'On a float': 1,
#  '"Riding waves on a board"': 1,
#  'Observing a shark feeding on a carcass of a humpback whale': 1,
#  'Surfing with dolphins': 1,
#  'Swimming in strong current with 3 others when he disappeared': 1,
#  'Scuba diving, but swimming on surface': 1,
#  'Windsurfing (urinating on his board)': 1,
#  "Fell off surfboard 20' from shore": 1,
#  'Playing ': 1,
#  "Filming 5' blue shark": 1,
#  'Hookah diving for abalone (descending)': 1,
#  "Fishing, stepped on hooked shark's head": 1,
#  'Jumped off surfboard & landed on the shark': 1,
#  'Swimming in canal': 1,
#  'Wading, knocked down & swept away by large waves': 1,
#  "On board 51' fishing vessel One Ki": 1,
#  'Board sailing': 1,
#  'Free diving for trochus': 1,
#  'Lying on surfboard & paddling': 1,
#  'Resting on surfboard': 1,
#  'Snorkeling, possibly holding a fish': 1,
#  'Scuba diving, hand feeding sharks': 1,
#  'Spearfishing using scuba & trailing a string of bleeding fish': 1,
#  'The MV Dona Marilyn sank in Typhoon Unsang with the loss of 389 lives': 1,
#  "Diving in Sharkey's Reef restaurant\x92s aquarium": 1,
#  'The inter-island ferry Vula sank in heavy weather': 1,
#  'Swimming from shore to anchored sailboat': 1,
#  'Dropping anchor': 1,
#  'Scuba Diving for scallops': 1,
#  'Vessel caught fire & capsized, survivors in the water': 1,
#  'Ferry boat Dona Paz with 4431 passengers exploded & caught fire when she collided with an  oil tanker ': 1,
#  'Returning to shore, collided with shark': 1,
#  "Attempting to lasso shark's tail": 1,
#  'Fell overboard  from the Taiwanese fishing trawler Lien Cheng Feu ': 1,
#  'Drift fishing': 1,
#  'Lying atop surfboard': 1,
#  "Onboard 21' powerboat that capsized in rough seas": 1,
#  'pêcheur de bichiques': 1,
#  'Surfing / treading water': 1,
#  'Sittting in water with his child': 1,
#  'Spearfishing on scuba': 1,
#  'Free diving & spearfishing ': 1,
#  'Free diving / spearfishing, from paddleboard & floating on the surface': 1,
#  'Surfing (or sailboarding)': 1,
#  'Swimming behind sailboat': 1,
#  'Riding floatation device': 1,
#  'Stamding': 1,
#  'Surfing, paddling shorewards': 1,
#  'Hookah diving': 1,
#  'Playing volleyball with friends': 1,
#  'Swimming, after falling off towed kneeboard': 1,
#  'Removing shark from tank in nightclub ': 1,
#  'Freediving for seashells': 1,
#  'Jumped off rocks into white water': 1,
#  'Adrift on refugee raft': 1,
#  'Commercial diver (submerged or treading water)': 1,
#  'Murder victim': 1,
#  'Surfing, sitting on board': 1,
#  'Wind surfing': 1,
#  'Scuba diving for bivalves': 1,
#  'Sleeping in anchored boat': 1,
#  'Playing / jumping': 1,
#  'Scuba diving (ascending using scooter)': 1,
#  ...}

# %%
if df['sex_'].item == 'M': df['name'][df['name'].isnull()] = 'male'
    
elif df['sex_'].item == 'F': df['name'][df['name'].isnull()] = 'female'
    
else: df['name'][df['name'].isnull()] = 'Anonymous'
   
df['name'][(df['name']=='Unidentified') | (df['name']=='Unknown')] = 'Anonymous'
    
getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
dict(df['name'].value_counts())
# Out:
# {'male': 550,
#  'Anonymous': 230,
#  'female': 97,
#  'boy': 23,
#  '2 males': 16,
#  'boat': 14,
#  'child': 12,
#  'sailor': 10,
#  'males': 10,
#  'a sailor': 8,
#  'girl': 7,
#  'a pearl diver': 6,
#  'fisherman': 6,
#  'a soldier': 5,
#  'a native': 5,
#  'Arab boy': 4,
#  'black male': 4,
#  '2 fishermen': 4,
#  'John Williams': 3,
#  'Zulu male': 3,
#  'Andre Hartman': 3,
#  'aboriginal male': 3,
#  ' male': 3,
#  'Russian male': 3,
#  'M.C.': 3,
#  'woman': 3,
#  'native boy': 3,
#  '2 women': 3,
#  'unknown': 3,
#  'Japanese diver': 3,
#  'dinghy': 3,
#  'Gordon Harmer': 2,
#  'Hideo Ishida': 2,
#  'soldier ': 2,
#  'Greg Pickering': 2,
#  'Robert Martin': 2,
#  'John Hayes': 2,
#  'Michael Massey': 2,
#  'Hans Hass': 2,
#  'teen': 2,
#  'crew': 2,
#  'a native fisherman': 2,
#  ' 2 males': 2,
#  'Davies': 2,
#  'Japanese fisherman': 2,
#  'a pilot': 2,
#  'Rory O\x92Connor': 2,
#  'fishermen': 2,
#  '2 men': 2,
#  'Iona Asai': 2,
#  'native': 2,
#  'Mr. Meyer': 2,
#  'Anton Bosman': 2,
#  'Fijian girl': 2,
#  'male, a Japanese fisherman': 2,
#  'Coast Guard personnel': 2,
#  'William Black': 2,
#  'Andy Austin': 2,
#  'Indian male': 2,
#  'Charles Cook': 2,
#  'a school teacher': 2,
#  'Ken Howell': 2,
#  'Seth Mead': 2,
#  'Parang': 2,
#  'Thomas McDonald': 2,
#  'Rafael Hermes Thomas': 2,
#  '"a youth"': 2,
#  '3 males': 2,
#  'Gerjo Van Niekerk': 2,
#  'boat, occupant: Danie Schoeman': 2,
#  'Ali': 2,
#  'American male': 2,
#  'John Ford': 2,
#  'Gary Johnson': 2,
#  'Mathew Vickers': 2,
#  'Carey Ford': 2,
#  'skiboat, occupant: Danie Schoeman': 2,
#  'a local dignitary': 2,
#  'Theirry Mercredi': 2,
#  "12' dinghy": 2,
#  'Len Jones': 2,
#  'Kenny Burns': 2,
#  'John Bolling': 2,
#  'Indian female': 2,
#  'Morris M. Vorenberg': 2,
#  'Rodney Orr': 2,
#  'Fijian woman': 1,
#  'launch, occupant Clive Whitrow, Dick Kuhne & Jim Pergola': 1,
#  'Robert B. Winkler': 1,
#  'Kenneth Morris': 1,
#  'Barry Smith & Harold Walker': 1,
#  'dinghy, occupant: Don Ashton': 1,
#  'Ian Marks': 1,
#  'Duffie Fryling': 1,
#  'Christopher Holland': 1,
#  'All on board perished in the crash': 1,
#  '5 m skiboat': 1,
#  "24' yacht owened by  C.L. Whitrow": 1,
#  'David Beaver': 1,
#  'boat Sea Hawk, occupants: R. Roberts & 4 others': 1,
#  'Malcolm Robertson & Tom Hasler': 1,
#  'Nicaso Balanoba & Julian Dona': 1,
#  'Jeffrey Francis Sasche (or Sachse)': 1,
#  'Enrique Matao': 1,
#  "16' boat, occupant: W. Lonergan": 1,
#  'Mamerto Daanong, Tomas Inog & others': 1,
#  'Upad, a boy': 1,
#  'Julian Bain': 1,
#  'Ron Christmas': 1,
#  'male, airline pilot': 1,
#  'Trevor Ferdinands': 1,
#  'Rodney Jonklass': 1,
#  'Lindsay Phillips': 1,
#  'Kenneth William Murray': 1,
#  'Sek': 1,
#  'Miss Fillardo': 1,
#  "13' dinghy, occupant S. Smith, Leenee Dee & Marie Farmer": 1,
#  'Joyce Greig': 1,
#  'Stanley Arthur Mullen': 1,
#  'Crew of Anti-submarine Squadron 23': 1,
#  'John Gilles & Harry Dowswell': 1,
#  "12' open motor boat, occupants Jack Platt & Peter Keyes": 1,
#  'Doas Hehuni': 1,
#  "12' ski, occupants: Bill Dyer & Cliff Burgess ": 1,
#  'Souleymane S.': 1,
#  'plywood dinghy, occupants: Jack Deegan & Trevor Millett': 1,
#  'John Benjamin': 1,
#  'Manama Mari': 1,
#  'Laurie Ross ': 1,
#  'Mrs. Burman': 1,
#  'Julie Wolfe': 1,
#  'a Portuguese soldier': 1,
#  'James Hay': 1,
#  'Eric Suttie & Peter Murray': 1,
#  'Fanie Schreuder': 1,
#  'Peter John Neil': 1,
#  'Brian Derry, a Naval Rating': 1,
#  'John Grave': 1,
#  'Theodore C. Swienty': 1,
#  'George E. Rudd': 1,
#  'Raymond Vermaak': 1,
#  'Donald Battye or David James Battye': 1,
#  'Roland Gerbeau': 1,
#  "14' open boat: occupants Richard Crew & Bob Thatcher": 1,
#  'R.P. Straughan': 1,
#  'Leopoldo Sanchez, a messboy from the ship MV Maripaz': 1,
#  'James McKee': 1,
#  'Jeff McAuley': 1,
#  'Jimmy Pearson, a Torres Strait Islander': 1,
#  'Peter Holland': 1,
#  'Mirco Tapavica': 1,
#  'Pasinganlas': 1,
#  'Fishing boat. Occupants: Yunus Potur & Ali Durmaz': 1,
#  'John Leszczak': 1,
#  'Tahei Nakatani, a Japanese seaman from the fishing vessel Seiju Maru': 1,
#  'Angel B. Escartin': 1,
#  'Douglas Lawton': 1,
#  'Robert Lawton (brother & rescuer)': 1,
#  'Suzanne Dreufus': 1,
#  'Hilda Keller': 1,
#  "16' cabin cruiser with 35 hp outboard motor": 1,
#  'James Douglas Munn': 1,
#  'Barry Geldenhuys': 1,
#  'Sailor of tuna vessel Daisan-Tenyo-Maru': 1,
#  'Lytton Evans': 1,
#  'John Allman': 1,
#  '4.3 m skiff, occupant: Bob Shay': 1,
#  'Peter Gerard Spronk': 1,
#  'Sailor of tuna vessel No.12 Taiyo Marei': 1,
#  'William S. Weaver': 1,
#  'Charles Green': 1,
#  'Ernest Grover': 1,
#  'Albert Kogler, Jr.': 1,
#  "40' bonito boat": 1,
#  '15 shipwrecked passengers and crew were in the water': 1,
#  'Arthur Wright': 1,
#  'Ivan Chandler': 1,
#  'Lt. James C. Neal': 1,
#  'Gary Seymour': 1,
#  'Masami Fukushi': 1,
#  'Ron Cox': 1,
#  'French woman': 1,
#  'Narcisco Tomaz': 1,
#  '12 m fishing boat. Occupant: Henry Tervo': 1,
#  "12' boat. Occupants:  Capt. E.J. Wines, Maj. W. Waller & Larry Waller": 1,
#  'Robert Walker': 1,
#  'Dorothy Barbara Rawlinson': 1,
#  'Francisco Daguinot': 1,
#  'Etuate Waqa': 1,
#  'male, Fijian cook of vessel Andi Tui Lomaloma': 1,
#  'Don Ide': 1,
#  'Akira Tuchiya': 1,
#  'June Goldback': 1,
#  'King Scherer': 1,
#  'Tony Dicks': 1,
#  'T. McNeill': 1,
#  'Robert Pamperin': 1,
#  'Francisco R. Topete': 1,
#  'Yitzhak Steinberg': 1,
#  'Lobster fishermen x 2': 1,
#  "17' boat, occupant:  Richard Wade": 1,
#  'Teresea Britton (on raft) & a man (on floating debris)': 1,
#  'Elizabeth Fields': 1,
#  'Rudy Gietel': 1,
#  '15-foot boat: occupant Woodrow Smith': 1,
#  'boat, occupant Robert Agnew': 1,
#  'Verne S. Fleet': 1,
#  '4.3 m skiff: occupants: James L. Randles, Jr. & James Myers': 1,
#  'Karl Pollerer & Eric Eisesenid': 1,
#  'Charles H. Hill': 1,
#  'Mick Coleman': 1,
#  'Young Marine recruit': 1,
#  'Crew of aircraft: McGreevy, Beakley, Rosenthal, Ryan & Hodge': 1,
#  "20' boat of Frank Stocker": 1,
#  'Paul Walter': 1,
#  'Jacob Horn': 1,
#  'male from Lelepa Island': 1,
#  'Alfred Haen': 1,
#  'George \x93Jimmy\x94 Stevens, aborgine from the lugger Rebecca': 1,
#  'John Grayson Andrews': 1,
#  'Gaspar Rodrigues Correia': 1,
#  'John Parker  ': 1,
#  'Yusef Mohamed': 1,
#  'Glynn Wessels': 1,
#  'Martyn Steffens': 1,
#  'Margaret Hobbs': 1,
#  'Dan Argyll': 1,
#  '9 fishermen & pregnant woman': 1,
#  'Stanley Caberto': 1,
#  'surf patrol boat': 1,
#  'Sabit Plana': 1,
#  'Patrick Imhof': 1,
#  'Tony Frost': 1,
#  "35' motor launch, occupants: Bill Fulham & T. Fanning": 1,
#  'Graeme Arbuckle': 1,
#  'G.L. Morris': 1,
#  'Marik-Pokas': 1,
#  'W. Davidson': 1,
#  'Bill Hawkins': 1,
#  'William  J. Dandridge': 1,
#  'Manfred Gregor': 1,
#  '?brahim Karagöz': 1,
#  'I. Padden': 1,
#  'Bruno Junker': 1,
#  'Kazuhiho Kato': 1,
#  'Robert Sato': 1,
#  'William Lee Bailey': 1,
#  'David Vogensen': 1,
#  'a sailor from the Fukuichi Maru': 1,
#  'Pollione Perrini & Fioravante Perini ': 1,
#  '4.8 m  boat Peggy, occupants: John Oktober, L.A. van Zyl and 4 others': 1,
#  "Lifesavers' surf patrol boat": 1,
#  'John Davy & John Pierpoint': 1,
#  'surf boat, occupants: Ray Sturdy and 4 other fishermen': 1,
#  'Hitola Hekure': 1,
#  'Kes, a native boy': 1,
#  'boat of Dennis Kemp & 4 other occupants': 1,
#  'W.T. Luxton': 1,
#  '4.8 m skiboat, occupants: C. Cockroft & 3 men': 1,
#  'John Blane': 1,
#  'Brian Lawrence Martin': 1,
#  "17' fishing boat; occupants 2 men": 1,
#  'John Hansen': 1,
#  'Paul Dammann': 1,
#  'Norval J. "Tom" Green': 1,
#  "10' rowboat, occupant: John Stephensen": 1,
#  'Frank Glenn': 1,
#  'boy from Aitape, West Sepik': 1,
#  'Frank Lee Morris': 1,
#  'John William Anglin ': 1,
#  'Fred Mason': 1,
#  'Clifford Hoogvorst': 1,
#  'William McLeod': 1,
#  'John Till': 1,
#  '25-foot cutter': 1,
#  'Mrs. Beryl Grant': 1,
#  'Yagirua Agiramon': 1,
#  "12' boat of Alf Laundy": 1,
#  'Gary Raymond Hiscocks': 1,
#  'boat of Wally Gibbons': 1,
#  'Floyd Pair, Jr.': 1,
#  'Mr. Reynish & Mr. Meikle': 1,
#  'Reece Nielsen': 1,
#  'Jacobus Vermaak': 1,
#  'Robert Smith': 1,
#  'Domingos Zefanias Cumbe': 1,
#  'Norman McEwan': 1,
#  'Mr. Loloi, a constable': 1,
#  "17' fishing launch, occupants: A. Burkitt & C. Brooke": 1,
#  'Lance Maloney': 1,
#  'Earl Brewster': 1,
#  'Brian Dewar': 1,
#  'P. Wagener': 1,
#  'F. Mautin': 1,
#  'William Capel': 1,
#  'Richard Henn': 1,
#  'John Brodeur': 1,
#  '"a native"': 1,
#  'Clyde Trudeau': 1,
#  'Naval aviator': 1,
#  'Richard Chung': 1,
#  'E.S. Hobson ': 1,
#  ' Captain Jonathan Brown, pilot ': 1,
#  'Theldon Gore': 1,
#  'Raymond F. McAllister': 1,
#  'John Taylor Wilson': 1,
#  'B. Hooper ': 1,
#  'boat, occupants: 2 fishermen': 1,
#  'Lt Cmdr. Lawrence Ernest Scheer USN, pilot': 1,
#  'Fisheries trainee': 1,
#  'Russell  Saylor': 1,
#  'John Klaso': 1,
#  'Don Morrissey': 1,
#  'John William Jones, an Ensign in US Navy': 1,
#  'Ted Nelson  onboard fishing boat Wayfarer': 1,
#  'Frank I. Gilbert': 1,
#  'Mike Hely': 1,
#  "16' skiff, occupant: W.A. Starck, II": 1,
#  'Suzanne Marie Theriot': 1,
#  'Louis Goiran': 1,
#  'Eddie Dawkins': 1,
#  'Leonardo Mendoza': 1,
#  'Henry Hanson, Jr.': 1,
#  "Paul Timothy Lovette, Dr. Neal Beardsley, James C. Russell, Harold H. Mackie, Dale Howard & Diego J. Terres on 42' Navy craft, Marie": 1,
#  'William F. Fey': 1,
#  'Hans Yoachim Schapper': 1,
#  'boat (a whale chaser)': 1,
#  'Monte Gray': 1,
#  'an Aid Post orderly': 1,
#  'Elsworth Smith': 1,
#  '7.5 m boat, occupants: 8 men': 1,
#  'Ken O\x92Connell': 1,
#  'Kelvin Harvey': 1,
#  'Kath. O\x92Neill': 1,
#  'British sailor from the  F-107': 1,
#  'Mrs. Reg Fox': 1,
#  'Charles Peterson': 1,
#  'Albert Bailey': 1,
#  'Johannes J. Rickert': 1,
#  'James K. Stewart': 1,
#  'Brian Rodgers': 1,
#  'Kenneth Smith': 1,
#  'Geoffrey Zimmerman': 1,
#  'Clyde Buttery': 1,
#  'Gerry Greaves': 1,
#  'Joe Prosch': 1,
#  'Francisco Zimila': 1,
#  'Keith Davis': 1,
#  'Douglas  John Spooner': 1,
#  'Rolf Ericson': 1,
#  'Carl Derrick Benzoin': 1,
#  'Len McWhinney': 1,
#  'Sarah Peggy Sargent': 1,
#  'Joe Chaney ': 1,
#  'Harry Bicknell': 1,
#  'Lester McDougall': 1,
#  'Serame "Petrus" Sithole': 1,
#  'Mrs. Despo Snow-Christensen ': 1,
#  'Harold Riley': 1,
#  '5 people swimming for shore (pilot & 4 passengers)': 1,
#  'A.N.': 1,
#  'yacht Southerly Buster': 1,
#  'Steven Friedman': 1,
#  'Peter Hendricks': 1,
#  'African child (male)': 1,
#  'Arthur Hopkins': 1,
#  'Michael Land': 1,
#  'Robert Webb': 1,
#  'Michael Murphy': 1,
#  'dinghy, occupants: Willem & Jan Groenwald': 1,
#  'Roy A. Robinson, Sr.': 1,
#  'Julia Painting': 1,
#  'John Hamlin': 1,
#  'Bernard Bade': 1,
#  "25' cutter": 1,
#  'Ranji Lal': 1,
#  'Mr. M. King': 1,
#  'Arthur E. Taylor, a navy diver & member+G1053 of a 24-man demolition team': 1,
#  'Juan Suarez Morales': 1,
#  'Gerald Howard, on board sportsfishing boat Teresa A': 1,
#  'Wes Wiggins and 7 others on the boat, Sparetime': 1,
#  'Truman Jones ': 1,
#  ' Ben Tillman Homes': 1,
#  'a skill. Occupants George Lunsford & 2 companions': 1,
#  'Vittorio Speca': 1,
#  'Mr. Ristow': 1,
#  'Gerbacio Solano (or Salamo)': 1,
#  'Barry Wilson': 1,
#  'Shigeichi Kawamura': 1,
#  'Franco Podesta': 1,
#  'Soledad Castellanos     - or -       Norma Figeroa': 1,
#  'A.J. Eggink': 1,
#  'Bernard Montessier': 1,
#  'Charles Thomas': 1,
#  '3 fishermen': 1,
#  '4 people killed in the past week, others injured': 1,
#  'Vanda Pierri': 1,
#  'George Athanasenas': 1,
#  'Dr. E. Al Joske': 1,
#  'Luca Caputo': 1,
#  'Anna Wurn': 1,
#  'Arthur James Kenealey': 1,
#  'George Plowman': 1,
#  'Kiaploki, a male': 1,
#  'George Lewis': 1,
#  'Harold Tait': 1,
#  'Frank Olkulich, the local surf-ski champion': 1,
#  'Antonio De Almeida Pinto': 1,
#  'Lindsay  Munn': 1,
#  'Carlos do Amaral': 1,
#  'male, a Pan American pilot wearing a flourescent bathing suit': 1,
#  'John Holmes': 1,
#  'Alan Agnew': 1,
#  ' Toapindak (male)': 1,
#  '14-foot boat Sintra': 1,
#  'Arthur R. Satz': 1,
#  'Daniel Gonsalves': 1,
#  'Alan Stevenson, Jr.': 1,
#  'Sgt. Larry Charles  Graybill': 1,
#  'Al Diamond': 1,
#  'Bartolome Mangubat': 1,
#  'Len Kosky': 1,
#  'Jack Haynes': 1,
#  'Neil Tapp, cadet lifesaver': 1,
#  'Glen Stoddart': 1,
#  'Mrs. G. Rautenbach': 1,
#  "Mr. Abbas Jasem (Mr. Kasem Jasem's son)": 1,
#  'Severino': 1,
#  'Rosario Bianci': 1,
#  'Bernard Vieux': 1,
#  'Mr. Kasem Jasem': 1,
#  'Ramlen': 1,
#  'Ema Aquilera Prada': 1,
#  'Harold Souza': 1,
#  'Captain Forest M. Richel': 1,
#  'Helmut Scheidl': 1,
#  'Ernest Lamerton': 1,
#  'Ron Ware': 1,
#  'Rex Gallagher': 1,
#  'James S. Takeuchi': 1,
#  'Captain of cutter Hetabu': 1,
#  'Ensio Tiira & Fred Ericsson, deserters from the French Foreign Legion': 1,
#  'Michael Leech': 1,
#  'Mr. Nasser Seemrookh': 1,
#  'Mrs. D. F. Gunn': 1,
#  'Mr. Kaaby': 1,
#  'Susan Smith': 1,
#  "16' launch": 1,
#  'Thomas H. Durbridge': 1,
#  'Jose Gonzales': 1,
#  'David Crick, fisherman ': 1,
#  "12' to 14' dory, occupants: John D. Burns & John MacLeod": 1,
#  'Archie Nottingham': 1,
#  'Edward Sierks, skipper': 1,
#  'Alejandro Nodura': 1,
#  'Don M. Clark': 1,
#  'Richard Joseph Maguire': 1,
#  '"Lockie" Smith': 1,
#  'Albert Hampton': 1,
#  'Mary Passaris': 1,
#  'Japanese fishermen': 1,
#  'Raymond T. Gold': 1,
#  'Ted Roach': 1,
#  'R. Palmer, ship\x92s apprentice': 1,
#  'Giovanni Picarelli': 1,
#  'Robert Kay': 1,
#  'Domenico Murolo': 1,
#  'James Howard': 1,
#  'Brian Ware (rescuer)': 1,
#  'John W. Smith': 1,
#  'William Edward Brown': 1,
#  'Doug Miller': 1,
#  'Albert Battles, James Dean & 4 crew': 1,
#  'Ray Land': 1,
#  'Vince Wilson': 1,
#  'Don Dixon': 1,
#  'Noah Kalama': 1,
#  'Pfc. Donald Tasking': 1,
#  'Clide Osborne': 1,
#  'Francisco Edmund Blanc, a scientist from National Museum in Paris': 1,
#  'Ismail': 1,
#  'Abdul Hussain': 1,
#  'Roghai': 1,
#  'Ali Kaymaz': 1,
#  'Dimitris Parassakis ': 1,
#  'Jalem': 1,
#  'Metuela Mau': 1,
#  'Hans Vegsund': 1,
#  'Bret Jeppsen': 1,
#  'Abdul Imam (male)': 1,
#  'Eric Keys': 1,
#  'Arthur Strahan': 1,
#  'Olai': 1,
#  'Fijian': 1,
#  'Abdullah, a Malay diver': 1,
#  'male, a US soldier': 1,
#  '2 swimmers': 1,
#  'Robert L. Bottini': 1,
#  'Valentine Sichter': 1,
#  'Robert B. Campbell': 1,
#  'A canoe; occupants Harry Goodson & Douglas Barnes': 1,
#  'Leo Vincent  Ryan': 1,
#  'Irrwala': 1,
#  'Desmond Quinlan, lifesaver': 1,
#  'Brian Love': 1,
#  'Johan Loekstad, a Norwegian seaman': 1,
#  'Hendrie Nkwazi': 1,
#  'Harry Sheen': 1,
#  'Albert Pride': 1,
#  'Keith Huskisson': 1,
#  'Heinrich Stapelberg': 1,
#  'Ken Davidson': 1,
#  'Brian Lanse': 1,
#  "40' fishing cutter": 1,
#  'Mark Majors III': 1,
#  'David Lloyd': 1,
#  'Clive Dumayne': 1,
#  'George Carter': 1,
#  'a dock worker': 1,
#  'Langston Pereira': 1,
#  'Aboobaker': 1,
#  'Neil Drake': 1,
#  'D. Martin': 1,
#  'Gilbert S. Hotta': 1,
#  'Peter Szott': 1,
#  'Warren Rathgen': 1,
#  'Brian Von Berg': 1,
#  'Mr. N. Wright': 1,
#  'John McDonald': 1,
#  'Remo Adriani': 1,
#  'Dr. Leonard Read Tibbet': 1,
#  'Pedro Guzman': 1,
#  'Joseph Salengo': 1,
#  'Alfredo Aubone': 1,
#  'Annie Mills': 1,
#  'Bruce Bourke': 1,
#  'Eleanor Nelson': 1,
#  'Mr. Falah': 1,
#  'male,  from Laluoro': 1,
#  'Mr. Paniry': 1,
#  'Semesa Vasu': 1,
#  'Jim Kline': 1,
#  'William Bolster': 1,
#  'boat, occupant: Portuondo': 1,
#  'an infant': 1,
#  'R. Nauth': 1,
#  'F. L. Fernando': 1,
#  'Sydney Victor Williams': 1,
#  'R.P.L. Straughan': 1,
#  'Japanese male, one of crew of pearl culture survey ship': 1,
#  'David Carson': 1,
#  'Sami Bale': 1,
#  'Matthew Sonieva': 1,
#  'Omni (rescuer)': 1,
#  'Patterson (John) Nikuniko': 1,
#  'Titus Tiso': 1,
#  'P. Allen': 1,
#  'Douglas Clarke': 1,
#  'Bansie Koide': 1,
#  'Jose Alengo': 1,
#  'Tsira Native': 1,
#  'boat:  occupants: Nazzareno Zammit & Emmanuel': 1,
#  'Leslie Nye': 1,
#  'Richard Kirby': 1,
#  'Maximilliaan Roual Van Dam': 1,
#  'Lyle Davis': 1,
#  'Richard McKenzie': 1,
#  'Jose Luis Nufize Lago': 1,
#  'Kara Benagi, from Hula': 1,
#  'Goffredo Lombardo': 1,
#  'Joel Healy, Jr.': 1,
#  'k': 1,
#  'Bogana Sabati': 1,
#  'Graham Smith': 1,
#  'Tuisafua Nomoa': 1,
#  'Michael Carpenter': 1,
#  'Paul Wilson ': 1,
#  'Nan-Tien Chang': 1,
#  'Derek Garth Prinsloo': 1,
#  'Brian Henderson': 1,
#  'Ronald Kerwand': 1,
#  'U.S. Navy U.D.T. Diver trainee, Ronald Gerringer': 1,
#  'Kevin Blair': 1,
#  'Nicholaas Badenhorst ': 1,
#  'Fay Jones Bester': 1,
#  'Johnny Bower': 1,
#  'male x 3': 1,
#  'Gene Franken & Maurice McGregor': 1,
#  'Alva Colquhoun &  Ilsa Konrads': 1,
#  'B. Irving': 1,
#  'Frank A. Mahala': 1,
#  'Eric Napier Cockerill': 1,
#  '2 males admitted to Memorial Hospital emergency room this month': 1,
#  'Stanton Waterman': 1,
#  'Takai Otiai': 1,
#  'ski-boat': 1,
#  'Peter Savino': 1,
#  'Melanesian woman': 1,
#  'Elison Sevo': 1,
#  'Leonard Higgins': 1,
#  'Conwell Kris': 1,
#  'Rupert Wade': 1,
#  'Earl .A. Murray': 1,
#  'Philip Case & William B. Gray': 1,
#  'Walter L. Huges': 1,
#  'Matthew Keia, a Lord Howe native': 1,
#  'young Zulu male': 1,
#  '16-foot launch, occupants: George Casey, Jack Byrnes, Julian Reynolds & Denny Laverty': 1,
#  'Robert Wherley': 1,
#  'Allan Green': 1,
#  'Vernon James Berry': 1,
#  'Donald Webster': 1,
#  'Barry Bryan Reed': 1,
#  'Jack Evans': 1,
#  'Jack Smedley': 1,
#  'Eric Rawls': 1,
#  'Reg Fabrizius': 1,
#  'Kila': 1,
#  'second cook': 1,
#  'James L. Oetzel': 1,
#  'Graham Scott': 1,
#  'Leva Kailovo': 1,
#  'Lawrence David Burns': 1,
#  'Kosuo Mizokawa, Captain of a Japanese trawler': 1,
#  'Pakau': 1,
#  'Gabriel Echiavarria': 1,
#  'George Lawson': 1,
#  'Romilio': 1,
#  '2 incidents north of Vero Beach': 1,
#  'John Willis': 1,
#  "10' row boat occupants;  Douglas Richards & George Irwin": 1,
#  'racing scull, occupants: Bill Andrews on bow oar, Dick Brown on #2 oar ': 1,
#  'Nedugattan': 1,
#  'Bruno Aloysius Rautenberg': 1,
#  'James F. Jacobs': 1,
#  'John Butcher': 1,
#  'Boy clad in shirt & white linen pants': 1,
#  'Clyde Leeper': 1,
#  'a marine biology student from the University of Miami': 1,
#  'Jean Foucher-Createau': 1,
#  'Gordon S. Chun': 1,
#  'male, a native constable': 1,
#  'Naval Rating': 1,
#  'Morslem Aken': 1,
#  'Frank Donahue, a movie stuntman': 1,
#  'Sub-Lieut. Edwin Michael Marks, of H.M.S. Sheffield': 1,
#  'a Hungarian refugee': 1,
#  'James Cook, a seaman from HMS Comus': 1,
#  '10 crew': 1,
#  'C.B. Larkin, a Royal Navy diver': 1,
#  'Carl Dible': 1,
#  'Dr. H. Warmke': 1,
#  'Dr. D.H. Teas': 1,
#  'Aldo Campi': 1,
#  'Kapua Gutchen': 1,
#  'John Adams': 1,
#  'Theo Watts Brown': 1,
#  'Lidua, a male': 1,
#  'Stephen Conedo': 1,
#  'boat, occupants: P.D. Neilly & Charlton Anderson': 1,
#  'yacht Even': 1,
#  'Lamoman': 1,
#  'Josh Vaughan': 1,
#  'Margoulis': 1,
#  'Captain Eric Hunt, the cook & a French passenger': 1,
#  'Lester  Burton': 1,
#  'Brian Hamilton': 1,
#  'Noel Cross': 1,
#  'Barry Keith Antonini': 1,
#  'Theo Brown': 1,
#  'John Patrick Wishart': 1,
#  'Ian Nolan': 1,
#  'Russ Shearman': 1,
#  'multiple boats including B.J. C. Brunt': 1,
#  'Manuel Pereira': 1,
#  'Niu Bodu': 1,
#  'R.C. Olsen': 1,
#  'Noel Langford': 1,
#  'William Cashman': 1,
#  'Kanematsu Oshiro': 1,
#  'Kula': 1,
#  'Kairua Gairi': 1,
#  'Sindlin': 1,
#  'Robert C. Yeargin': 1,
#  'Mrs. W. F. Dixon': 1,
#  'Romasevic': 1,
#  'launch, occupant: Clarrie Whelan': 1,
#  'Robert C. Hightower': 1,
#  'Wolfgang Emrich': 1,
#  'Sailor from tuna vessel': 1,
#  'Carla Podzum': 1,
#  'Dale Strand': 1,
#  'Otamatsu H. Yoshii': 1,
#  'Eric Vaughters': 1,
#  'Philip C. Diez': 1,
#  'Clarence Anglin': 1,
#  'Nicolas Jimenez Nunez, a Catholic priest': 1,
#  '2.4 m rowboat, occupants: Edgar Brown, Jerry Welz & Cornelius  Stakenburg': 1,
#  "14' boat, occupant: Jonathan Leodorn": 1,
#  'Kenneth Murchison': 1,
#  'Gordon Johnson': 1,
#  'Eric Fotherby': 1,
#  'Mark Van Leer': 1,
#  'Yvonne Vladislavick': 1,
#  'Hans Kretschmer': 1,
#  'Barry Kumara': 1,
#  'Kenneth Hiles': 1,
#  'Rodney Temple': 1,
#  'Terry Cooper': 1,
#  'Norman Hargreaves': 1,
#  'R. Bartlett': 1,
#  'Mark Worman': 1,
#  'Johan Brink': 1,
#  'Gerald Soukoff': 1,
#  'Helmut Pfosse': 1,
#  'Charles Lubbe': 1,
#  'Ronald Kelly': 1,
#  'Richard Salick': 1,
#  'Helmut Himmrich': 1,
#  'Janie Pelser': 1,
#  'K. Tracy': 1,
#  'Chan Sze-king': 1,
#  'Gregory Carroll': 1,
#  'Cheryl Teague': 1,
#  'G. Byron': 1,
#  'Alan Titchenal': 1,
#  'Robert Richard': 1,
#  'Jacob Nkomo': 1,
#  'B.T.': 1,
#  'D. Trayling': 1,
#  'Stuart Rogers': 1,
#  'Adam Gomes, Jr.': 1,
#  'John Fairfax': 1,
#  'Richard  George Wilson': 1,
#  'Sonja Kuelsen': 1,
#  'Alan Banner,  Peace Corps volunteer': 1,
#  'Bill Curtsinger': 1,
#  'Mitchell Warner': 1,
#  'Robert Sterling': 1,
#  'Joe Kool': 1,
#  '2 Czech tourists': 1,
#  'Glen Tunbridge': 1,
#  'Oaulkurt-Pape': 1,
#  'Cornelius \x93Les\x94 Pyper': 1,
#  'Terry Manuel': 1,
#  'James Viljoen': 1,
#  'skiboat, occupants: Danie & Fanie Schoeman': 1,
#  'Damon Kendrick': 1,
#  'Hans Reiner': 1,
#  'James Arthur Gurr': 1,
#  'Anthony Kenneth Baker': 1,
#  'Stacie Alexander': 1,
#  'Simon Parkin': 1,
#  '5 men': 1,
#  'Leroy Hancock': 1,
#  'Olive Heaton': 1,
#  'Christiaan Weissig': 1,
#  'Ron Arney': 1,
#  'C. Thackwray': 1,
#  'Bruce Lawlor (or Lawler)': 1,
#  'Dr. Leo Ephraim Fischer': 1,
#  'Kevin Cole': 1,
#  'William C. Lamb': 1,
#  'Stuart Baddock': 1,
#  'John P.R. Nicholls': 1,
#  '2 youths': 1,
#  'Chris DeFord': 1,
#  'G. Cole': 1,
#  'Gary W. Floyd': 1,
#  'Soldier': 1,
#  'Al Schneppershoff': 1,
#  'Tsang Kai-shing': 1,
#  'Kevin G. Schlusemeyer': 1,
#  'a Solomon Islander': 1,
#  'Chip Trout': 1,
#  'Copley': 1,
#  'Walter E. Milford, Jr.': 1,
#  'Werner Bayer': 1,
#  'Calvin Ward': 1,
#  'Mr. Jurincic': 1,
#  'Robert Eleniefsky': 1,
#  'D.C. Barnes': 1,
#  'Donald Joslin': 1,
#  'Richard Hegeman': 1,
#  'A. Robson': 1,
#  'D.R. McGinnis': 1,
#  'Graham Cartwright': 1,
#  'Hiran Wickremartne': 1,
#  'Robert Wamser': 1,
#  'Mosley': 1,
#  'a fisherman': 1,
#  'Jack Kardell': 1,
#  'pilot of Israeli skyhawk': 1,
#  'Elissane Mobunda': 1,
#  'Mabua Mogadura': 1,
#  'Betual Tivane': 1,
#  'John. Wilson': 1,
#  'Rodney Hughes': 1,
#  'Sally Anne Irvine': 1,
#  'J. Gillies': 1,
#  'Kevin Deacon': 1,
#  'Elin Anderson': 1,
#  'George Pacey': 1,
#  'Licius Lee': 1,
#  'William Hill': 1,
#  'Jack Horner': 1,
#  'David Anderson': 1,
#  'Douglas Kuchn, Jr.': 1,
#  'Eric Brown': 1,
#  'Brian Martel': 1,
#  'Walter Barnett': 1,
#  'John Holmes, Jr.': 1,
#  'Dennis Washington': 1,
#  'Steven Benham': 1,
#  'Robert Colby': 1,
#  'Walter Griffin': 1,
#  'Zulu Soto': 1,
#  'Robert Fetterman': 1,
#  'J. Horner': 1,
#  'Theo Klein': 1,
#  'Tim Franklin': 1,
#  'Ralph Painter': 1,
#  'Barry Watkins': 1,
#  'Sailed with 23 crew, half survived the explosion': 1,
#  'Tarcisio Mayora': 1,
#  'Alberto Mayora ': 1,
#  'Jimmy Rowe': 1,
#  'a German tourist': 1,
#  'Mr. Kalantar': 1,
#  'Jimmy Johnson': 1,
#  'Gideon Scheltema': 1,
#  'Kenneth Gray': 1,
#  'Michael Prather': 1,
#  'Jim Allman': 1,
#  'Leslie Oswald Harris': 1,
#  'Stanislav Klepa': 1,
#  'Mr. Nagib': 1,
#  'Castigo Litura': 1,
#  'Ernie Reathaford': 1,
#  'Gary Kirakas': 1,
#  'David Vota': 1,
#  'Lionel Jarvis': 1,
#  'Rudolf Daily': 1,
#  'John Alpheus': 1,
#  'Lincoln Alpheus': 1,
#  'Anand Govindsamy': 1,
#  'William Faulkner': 1,
#  'David Cook': 1,
#  'Santiago Kapriel': 1,
#  'Reggie Hodgson': 1,
#  'Aismerael Samsel': 1,
#  'Mike Uramai': 1,
#  'Robbie Baker': 1,
#  'James C. Mattan': 1,
#  'Heinz Plotsky': 1,
#  'Dikios Leopold': 1,
#  'Billy Horne': 1,
#  'John Carter': 1,
#  'Robert Kehl': 1,
#  'Sharon Wolfe Cranston': 1,
#  '6 m skiboat, occupants: Alex Mamacos, Noel Glintenkamp, Tony Mountifield & Dillon Alexandra': 1,
#  'George Walter': 1,
#  'Philip Horley': 1,
#  'Kim Pearce': 1,
#  'Raymond Brockway': 1,
#  'Harold Corbett': 1,
#  'Vanuatu  Weekly Hebdomadaire': 1,
#  'Laurence Evans': 1,
#  'Michael Muradian': 1,
#  'Nicky Alberts': 1,
#  'The June, occupants Bunny Pendelbury and crew of 6': 1,
#  '6 m skiboat, occupants: P.A. Reeder & crew': 1,
#  'Colin Wrankmore': 1,
#  'Mike deGruy': 1,
#  'Philip Light': 1,
#  'Mack Shelton': 1,
#  'Glenn Friedman': 1,
#  'Steve Posey': 1,
#  'Harry Griffet': 1,
#  'Paul Howard': 1,
#  'Al Brenneka': 1,
#  'Albert van Ryseen': 1,
#  'Geoffrey Kirkam Spence': 1,
#  'Jay Worrell': 1,
#  'Graham Archall': 1,
#  'Mexican male': 1,
#  'Jean Blanchet': 1,
#  'Victor Beaver': 1,
#  'Willie White': 1,
#  'Verdon Harrison': 1,
#  'Dr. Rolf Johan Lund': 1,
#  'Ruskin Vest': 1,
#  'Gary Jones': 1,
#  'Gordon Gibbs': 1,
#  '5 m skiboat Graanjan, occupants: Rudy van Graan, Jan de Waal Lombard': 1,
#  'Dan Baen, Jr.': 1,
#  'Fred Dean Hunt': 1,
#  'Sam Boger': 1,
#  '7 m skiboat Alrehmah III, occupants: Adolph Schlechter & 3 friends': 1,
#  'Peter Lee': 1,
#  'Captain Tommy Edward Neel': 1,
#  'William Shaw': 1,
#  'John P. Seiner': 1,
#  'Michael Oliver': 1,
#  'Willie Dorfling': 1,
#  'skiboat, occupants: Gustav Boettger, Clive Mason, Keith Murrison & Sweis Olivier': 1,
#  'Kenny Doudt': 1,
#  'Fernando Branco de Abreu': 1,
#  'Alan Edly Symons': 1,
#  'Carl Shemaly': 1,
#  'A male from Muitoa': 1,
#  'Sean Mitchley': 1,
#  'Sidney Hallett': 1,
#  'Jose Larenas-Miranda': 1,
#  'Peter Clarke': 1,
#  'Les Winkworth': 1,
#  'Piet Boonzaaier': 1,
#  'Ferdinand Teanyouen': 1,
#  'Ramon Cordoba': 1,
#  "Phillip 'Flip' Steenkamp": 1,
#  'Pat DuNah': 1,
#  'Jim Scott': 1,
#  'Fabrizio Marini': 1,
#  'Erik Lombard': 1,
#  'Mr. Kuppasamy': 1,
#  'Jorge Alvarez': 1,
#  'Wendell Cabunoc': 1,
#  'Wayne Brown': 1,
#  'Mark Beekler': 1,
#  'elderly male': 1,
#  'Charles Kantor': 1,
#  'Manuel Teau': 1,
#  'Fishing boat': 1,
#  'Calvin Sloan': 1,
#  'Donald A. Stewart': 1,
#  'Robert Kennedy III': 1,
#  'Jimmy Jackson': 1,
#  'William Kennedy': 1,
#  'Robert Sanders': 1,
#  'Jeffrey Hanrahan': 1,
#  'Frans Swanepoel': 1,
#  'William Hookway': 1,
#  'William Hodges': 1,
#  'Kevin Thompson': 1,
#  'Walter Sansoni': 1,
#  'Cindy Jones': 1,
#  'Edward Bassett': 1,
#  'William Wayne Daniels': 1,
#  'hobiecat, occupants: Judy Lambert  & a friend': 1,
#  'Donna Hutson': 1,
#  'Jim Krents': 1,
#  'Robert Clark': 1,
#  'Dennis Thompson': 1,
#  'Beverly White': 1,
#  'Robert Revstock': 1,
#  'Gary Grace': 1,
#  'Bretton Russell Jones': 1,
#  'Wade Shipard': 1,
#  'Grace Conger ': 1,
#  'Beatrice Aharonowich': 1,
#  'Rolf Schneider': 1,
#  'Yee Wing Ping (male)': 1,
#  'Ho-Sin-Ming (male)': 1,
#  'Curt Brown': 1,
#  'Adrian Treveluwe': 1,
#  'Dale Webster': 1,
#  'Jack Greenlaw': 1,
#  'Jon Holcomb': 1,
#  'John Lear': 1,
#  'Kirk Johnston': 1,
#  'Dwayne W. Ortwine': 1,
#  'G. Allen': 1,
#  'Geeteh Toussaint': 1,
#  'David Barrowman': 1,
#  'Gerhard Visser': 1,
#  'M. Worman': 1,
#  'Robert Slack': 1,
#  'Gilbert Brown': 1,
#  'Marshall Flanagan': 1,
#  'Stephen Curtis Powell': 1,
#  'Glen Wright': 1,
#  '6 m skiboat, occupants: Terry McManus, Dan Clark and Blackie Swart': 1,
#  'Debbie McMillan': 1,
#  'Francisco Pelle': 1,
#  'Donald Gard': 1,
#  'Paul Maurer': 1,
#  'Bill Loughlin': 1,
#  'Travis Raigan': 1,
#  '5 m skiboat; Stephanie': 1,
#  'Mike Shook': 1,
#  'Randy Hall': 1,
#  'Peter Ferrer': 1,
#  'Ricky Karras, Jr.': 1,
#  'Michael  Karras, Jr.': 1,
#  'Darryl Richardson': 1,
#  'a small boat': 1,
#  'boat, occupants: Jacob Kruger & crew': 1,
#  '5 m skiboat Stephanie, occupants: Fanie Schoeman and Brigadier Bronkhorst': 1,
#  'Henry Peterson': 1,
#  'John Strand': 1,
#  ...}

# %%
if df['name'].item == 'female': df['sex_'][df['sex_'].isnull()] = 'F'
    
elif df['name'].item == 'male': df['sex_'][df['sex_'].isnull()] = 'M'
    
else: df['sex_'][df['sex_'].isnull()] = 'unknown'

df['sex_']= df['sex_'].str.replace(' ','').str.replace('N','unknown').str.replace('lli','unknown').str.replace('.','unknown')

getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
dict(df['sex_'].value_counts())
# Out:
# {'M': 5096, 'F': 637, 'unknown': 569}

# %%
df['age'] = df['age'].astype(str)

df['age'] = df.age.str.extract(r'(\d\d)')

df['age'] = df['age'].astype(float)

mean_age = df['age'].mean()

df['age'].fillna(np.round(mean_age), inplace = True)

getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
dict(df['age'].value_counts())
# Out:
# {28.0: 3063,
#  17.0: 156,
#  18.0: 153,
#  20.0: 151,
#  19.0: 143,
#  16.0: 139,
#  15.0: 139,
#  21.0: 122,
#  22.0: 117,
#  25.0: 110,
#  24.0: 106,
#  14.0: 102,
#  13.0: 96,
#  30.0: 87,
#  26.0: 83,
#  23.0: 82,
#  29.0: 78,
#  27.0: 78,
#  12.0: 75,
#  32.0: 70,
#  35.0: 69,
#  10.0: 60,
#  40.0: 59,
#  31.0: 54,
#  34.0: 51,
#  38.0: 48,
#  33.0: 48,
#  36.0: 45,
#  43.0: 44,
#  37.0: 43,
#  11.0: 38,
#  42.0: 38,
#  39.0: 38,
#  41.0: 38,
#  50.0: 37,
#  52.0: 35,
#  45.0: 33,
#  47.0: 30,
#  44.0: 29,
#  49.0: 28,
#  48.0: 28,
#  46.0: 28,
#  55.0: 23,
#  51.0: 20,
#  60.0: 18,
#  54.0: 17,
#  57.0: 16,
#  58.0: 15,
#  53.0: 13,
#  61.0: 13,
#  59.0: 11,
#  56.0: 10,
#  69.0: 10,
#  63.0: 9,
#  62.0: 8,
#  68.0: 7,
#  70.0: 6,
#  65.0: 5,
#  66.0: 4,
#  64.0: 4,
#  77.0: 3,
#  71.0: 3,
#  73.0: 3,
#  74.0: 2,
#  75.0: 2,
#  78.0: 2,
#  86.0: 1,
#  84.0: 1,
#  72.0: 1,
#  87.0: 1,
#  67.0: 1,
#  81.0: 1,
#  82.0: 1}

# %%
dict(df['fatal_yn'].value_counts())
# Out:
# {'N': 4301, 'Y': 1388, 'UNKNOWN': 613}

# %%
df['fatal_yn'].fillna('UNKNOWN', inplace = True)

df['fatal_yn'] = df['fatal_yn'].str.replace(' ','')

df['fatal_yn'][(df['fatal_yn']!='N') & (df['fatal_yn']!='Y')] = 'UNKNOWN'

getGraphic(df)
# Out:
# <AxesSubplot:>

# %%
getDic(df,'time')
# Out:
# {'Afternoon': 187,
#  '11h00': 128,
#  'Morning': 121,
#  '12h00': 109,
#  '15h00': 108,
#  '16h00': 101,
#  '14h00': 97,
#  '16h30': 74,
#  '14h30': 73,
#  '17h00': 73,
#  '13h00': 72,
#  '17h30': 70,
#  '18h00': 69,
#  '15h30': 66,
#  'Night': 62,
#  '11h30': 61,
#  '13h30': 60,
#  '10h00': 59,
#  '09h00': 50,
#  '10h30': 49,
#  '12h30': 36,
#  '09h30': 35,
#  'Late afternoon': 35,
#  'Evening': 34,
#  '07h30': 33,
#  '18h30': 32,
#  '08h00': 31,
#  '08h30': 26,
#  '19h00': 23,
#  '07h00': 22,
#  '17h15': 18,
#  '15h45': 17,
#  '13h20': 17,
#  '14h45': 17,
#  '16h45': 16,
#  '11h15': 15,
#  'Dusk': 15,
#  '11h45': 15,
#  '06h00': 13,
#  '08h45': 13,
#  '10h45': 13,
#  '20h00': 13,
#  '10h15': 12,
#  '09h45': 12,
#  '15h15': 12,
#  '20h30': 12,
#  'A.M.': 12,
#  '19h30': 12,
#  '13h45': 12,
#  'P.M.': 12,
#  '16h15': 11,
#  'Early morning': 11,
#  'Midday': 10,
#  '16h20': 10,
#  '12h15': 10,
#  '12h45': 9,
#  '10h55': 9,
#  '17h45': 8,
#  '14h10': 8,
#  '13h15': 8,
#  '14h20': 8,
#  'Early afternoon': 8,
#  '11h10': 8,
#  '06h30': 8,
#  '06h45': 7,
#  '18h45': 7,
#  '15h20': 7,
#  '10h20': 7,
#  '07h45': 6,
#  '14h40': 6,
#  '12h40': 6,
#  '11h20': 6,
#  '09h15': 6,
#  '03h00': 6,
#  '05h00': 5,
#  '14h15': 5,
#  '10h25': 5,
#  '16h40': 5,
#  '12h05': 5,
#  '12h20': 5,
#  '13h40': 5,
#  '15h35': 5,
#  '19h45': 5,
#  '16h05': 5,
#  '23h00': 5,
#  '16h10': 5,
#  '07h15': 5,
#  '10h40': 5,
#  '14h50': 5,
#  '04h00': 5,
#  '18h15': 5,
#  '02h00': 5,
#  '--': 5,
#  '22h00': 4,
#  '08h15': 4,
#  '08h10': 4,
#  '13h25': 4,
#  '16h50': 4,
#  '17h10': 4,
#  '15h40': 4,
#  '17h20': 4,
#  '10h35': 4,
#  'Sunset': 4,
#  '17h50': 4,
#  'Midnight': 4,
#  '11h50': 4,
#  '20h15': 4,
#  '18h40': 3,
#  '12h50': 3,
#  '09h40': 3,
#  '18h05': 3,
#  '08h50': 3,
#  '01h00': 3,
#  '09h50': 3,
#  '11h40': 3,
#  '13h50': 3,
#  '06h15': 3,
#  '14h35': 3,
#  '19h15': 3,
#  '15h50': 3,
#  '21h00': 3,
#  '14h55': 3,
#  '23h30': 3,
#  'Dawn': 2,
#  '07h05': 2,
#  '11h05': 2,
#  '09h55': 2,
#  '07h20': 2,
#  '12h48': 2,
#  '07h19': 2,
#  '17h55': 2,
#  '07h40': 2,
#  '12h33': 2,
#  '13h26': 2,
#  '16h35': 2,
#  'Dark': 2,
#  '18h20': 2,
#  'AM': 2,
#  '07h50': 2,
#  '08h05': 2,
#  '13h05': 2,
#  ' ': 2,
#  '18h50': 2,
#  '11h55': 2,
#  '09h35': 2,
#  '18h10': 2,
#  '14h25': 2,
#  '13h55': 2,
#  '14h16': 2,
#  '15h55': 2,
#  '05h30': 2,
#  '15h49': 2,
#  '19h20': 2,
#  '10h10': 2,
#  '12h10': 2,
#  '12h25': 2,
#  'After noon': 2,
#  '10h50': 2,
#  '03h30': 2,
#  '08h20': 2,
#  '17h35': 2,
#  'Late afternon': 2,
#  'Just before noon': 2,
#  '09h00 - 09h30': 2,
#  '1600': 2,
#  '2 hours after Opperman': 1,
#  'Between 06h00 & 07h20': 1,
#  '16h55': 1,
#  '09h30 ': 1,
#  '05h40': 1,
#  '15h05': 1,
#  '<07h30': 1,
#  '21h30': 1,
#  '08h58': 1,
#  '17h00 Sunset': 1,
#  '11h00 / 11h30': 1,
#  'Mid afternoon': 1,
#  'X': 1,
#  '08h57': 1,
#  '17h00-18h00': 1,
#  '18h30 (Sunset)': 1,
#  '06j00': 1,
#  '08h35': 1,
#  '10h22': 1,
#  '02h45': 1,
#  'Nightfall': 1,
#  '"Early evening"': 1,
#  '01h50': 1,
#  '12h54': 1,
#  '13h37': 1,
#  '11h06': 1,
#  '"Night"': 1,
#  '18h30?': 1,
#  '11h58': 1,
#  '11h51': 1,
#  '06h00 -- 07h00': 1,
#  'Before 10h30': 1,
#  '18h12': 1,
#  '11h48': 1,
#  'Mid morning': 1,
#  '07h10': 1,
#  'dusk': 1,
#  'Prior to 10h37': 1,
#  '30 minutes after 1992.07.08.a': 1,
#  '>06h45': 1,
#  '   ': 1,
#  '15h06': 1,
#  'Late Afternoon': 1,
#  'Before daybreak': 1,
#  '01h32': 1,
#  'Daybreak': 1,
#  '14h00 - 15h00': 1,
#  'night': 1,
#  '03h45 - 04h00': 1,
#  '13h10': 1,
#  '>17h30': 1,
#  '"shortly before dusk"': 1,
#  '1500': 1,
#  '18h15 to 21h30': 1,
#  '09h30 / 15h30': 1,
#  '2 hrs before sunset': 1,
#  '16h25': 1,
#  '19h10': 1,
#  '10h00 or 14h00': 1,
#  '08h00 / 09h30': 1,
#  '"After dark"': 1,
#  '19h35': 1,
#  'Midday.': 1,
#  '15h00j': 1,
#  '16h23': 1,
#  '12h00 to 14h00': 1,
#  '13h35': 1,
#  'Late night': 1,
#  '>14h30': 1,
#  '12h45 / 13h45': 1,
#  'After midnight': 1,
#  '19h00 / 20h00': 1,
#  '01h30': 1,
#  '>12h00': 1,
#  'Mid-morning': 1,
#  'FATAL  (Wire netting installed at local beaches after this incident.)': 1,
#  '10h30 or 13h30': 1,
#  '08h55': 1,
#  '16h30 or 18h00': 1,
#  'Just before dawn': 1,
#  '19h55': 1,
#  ' 14h00': 1,
#  'Ship aban-doned at 03h10': 1,
#  '11h01 -time of ship sinking': 1,
#  'Daytime': 1,
#  '06h50': 1,
#  'After 04h00': 1,
#  '10h00 / 11h00': 1,
#  '"After lunch"': 1,
#  'Between 11h00 & 12h00': 1,
#  '07h32': 1,
#  '15h00 or 15h45': 1,
#  '>17h00': 1,
#  'After dusk': 1,
#  '09h20': 1,
#  '10h28': 1,
#  '18h15-18h30': 1,
#  '09h57': 1,
#  '17h58': 1,
#  '15h19': 1,
#  '13h24': 1,
#  '0830': 1,
#  '15h56': 1,
#  '07h56': 1,
#  '17h17': 1,
#  '09h05': 1,
#  '19h28': 1,
#  '12h38': 1,
#  '05h50': 1,
#  '05h45': 1,
#  '09h11': 1,
#  '13h51': 1,
#  '15h44': 1,
#  'Lunchtime': 1,
#  '15j45': 1,
#  '10h27': 1,
#  '10h16': 1,
#  '0500': 1,
#  'Before 07h00': 1,
#  '14h00  -15h00': 1,
#  '17h01': 1,
#  '07h00 - 08h00': 1,
#  '18h25': 1,
#  '16h18': 1,
#  '21h50': 1,
#  '19h00, Dusk': 1,
#  '15h01': 1,
#  '10h44': 1,
#  '13h19': 1,
#  'Shortly before 12h00': 1,
#  '17h34': 1,
#  '9h00': 1,
#  '10h43': 1,
#  '19h05': 1,
#  '1300': 1,
#  '14h30 / 15h30': 1,
#  '14h34': 1,
#  '15h25': 1,
#  '17h46': 1,
#  'Morning ': 1,
#  '09h30 / 10h00': 1,
#  '10h45-11h15': 1,
#  '15h52': 1,
#  '11h41': 1,
#  '17h51': 1,
#  '16h12': 1,
#  'Sometime between 06h00 & 08hoo': 1,
#  '10h00 -- 11h00': 1,
#  '14h21': 1,
#  '15h53': 1,
#  '"Just before 11h00"': 1,
#  'Early Morning': 1,
#  'Shortly after midnight': 1,
#  '13h345': 1,
#  '\xa0 ': 1,
#  '06h47': 1,
#  '09h00 -10h00': 1,
#  '20h45 (Sunset)': 1,
#  'Late morning': 1,
#  '13h14': 1,
#  '13h06': 1,
#  'Shortly before 13h00': 1,
#  '12h34': 1,
#  '11h53': 1,
#  '8:04 pm': 1,
#  '12h46': 1,
#  '17h42': 1,
#  '12h35': 1,
#  'Possibly same incident as 2000.08.21': 1,
#  'After Dusk': 1,
#  '11h57': 1,
#  'Noon': 1,
#  '17h40': 1,
#  '11h25': 1,
#  '11h56': 1,
#  '08h40': 1,
#  '02h30': 1,
#  '07h08': 1,
#  '11h115': 1,
#  '13h42': 1,
#  '12h39': 1,
#  '  ': 1,
#  '"Evening"': 1,
#  'Just before sundown': 1,
#  '22h30': 1,
#  '11h30 ': 1,
#  '06h10': 1,
#  'Between 05h00 and 08h00': 1,
#  '17h00 or 17h40': 1,
#  'Just after 12h00': 1,
#  '>08h00': 1,
#  '12h02': 1,
#  '12h55': 1,
#  '16h14': 1,
#  '17h11': 1,
#  '00h30': 1,
#  '14h37': 1,
#  '10h07': 1,
#  '13h53': 1,
#  '13h23': 1,
#  '19h00-20h00': 1}

# %%
#df['time'] = df.time.str.extract(r'(\d\d[h]\d\d)')


#dict(df['time'].value_counts())

# %%
'''df['time'][df['time']=='Afternoon'] = '15h00'

df['time'][df['time']=='Morning'] = '11h00'

df['time'][df['time']=='Night'] = '23h00'

df['time'][df['time']=='--'] = 'unknown'

df['time'][df['time']=='Sunset'] = '19h00'

df['time'][df['time']=='Late afternoon'] = '18h00'

df['time'][df['time']=='Evening'] = '20h00'

df['time'][df['time']=='P.M.'] = '20h00'

df['time'][df['time']=='Evening'] = '20h00'

dict(df['time'].value_counts())'''
# Out:
# "df['time'][df['time']=='Afternoon'] = '15h00'\n\ndf['time'][df['time']=='Morning'] = '11h00'\n\ndf['time'][df['time']=='Night'] = '23h00'\n\ndf['time'][df['time']=='--'] = 'unknown'\n\ndf['time'][df['time']=='Sunset'] = '19h00'\n\ndf['time'][df['time']=='Late afternoon'] = '18h00'\n\ndf['time'][df['time']=='Evening'] = '20h00'\n\ndf['time'][df['time']=='P.M.'] = '20h00'\n\ndf['time'][df['time']=='Evening'] = '20h00'\n\ndict(df['time'].value_counts())"
